# %%
import matplotlib.pyplot as plt
import numpy as np
from fractions import Fraction

def primal_line_to_dual_point(p1, p2):
    denominator = p1[0] * p2[1] - p1[1] * p2[0]
    if denominator == 0:
        raise ValueError("Points are linearly dependent or degenerate (denominator = 0).")
    return (
        (p1[1] - p2[1]) / denominator, 
        (p2[0] - p1[0]) / denominator
    )

def orientation(p1, p2, p3):
    x1, y1 = p1
    x2, y2 = p2
    x3, y3 = p3
    
    # Using Fraction for exact rational arithmetic
    val = (Fraction(x2 - x1) * Fraction(y3 - y1)) - (Fraction(y2 - y1) * Fraction(x3 - x1))
    
    if val > 0:
        return "Counterclockwise"
    elif val < 0:
        return "Clockwise"
    else:
        return "Collinear"

# Blue
pl = [709402351/4383829060, 108722733433/68370872455]
pi = [13565295989/2031530540, -194185818775/19010437707]
pv = [-398306993/194730640, 592849531/303704902]
pj = [705774283/121706650, -303298786/151852451]
pu = [26640351/40433380, 436945273736/90176545745]
pk = [88115647/80866760, -24681211891/1261210430]









# Teal
# pu2 = (3, 2)
# pk2 = (3, 5)

# pu2 = (3, 5)
# pk2 = (4, 2)

# Compute dual points
# p_li = primal_line_to_dual_point(pl, pi)
# p_vj = primal_line_to_dual_point(pv, pj)
# p_uk = primal_line_to_dual_point(pu, pk)
# p_u2k2 = primal_line_to_dual_point(pu2, pk2)

print(f"The orientation is {orientation(p_li, p_vj, p_uk)}")

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Primal lines
ax1.plot([pl[0], pi[0]], [pl[1], pi[1]], marker='o', color='blue', markersize=10)
ax1.plot([pv[0], pj[0]], [pv[1], pj[1]], marker='o', color='orange', markersize=10)
ax1.plot([pu[0], pk[0]], [pu[1], pk[1]], marker='o', color='green', markersize=10)
# ax1.plot([pu2[0], pk2[0]], [pu2[1], pk2[1]], marker='o', color='teal', markersize=10)
# ax1.set_title("Primal Plane (Segments)")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax1.set_aspect('equal')
# ax1.set_xticklabels([])
# ax1.set_yticklabels([])
ax1.grid(True)



def draw_implicit_line(a, b, c, xlim=(-8, 3), **kwargs):
    x = np.linspace(*xlim, 500)
    if b != 0:
        y = (-a * x - c) / b
        plt.plot(x, y, **kwargs)
    else:
        x0 = -c / a
        plt.axvline(x0, **kwargs)

draw_implicit_line(pl[0], pl[1], 1, color='blue', linewidth=0.5)
draw_implicit_line(pi[0], pi[1], 1, color='blue', linewidth=0.5)

# draw_implicit_line(pu[0], pu[1], 1, color='gree', linewidth=0.5)
# draw_implicit_line(pk[0], pk[1], 1, color='green', linewidth=0.5)


# Dual points
# ax2.plot([p_li[0], p_vj[0]], [p_li[1], p_vj[1]], marker='o', color="black", linewidth=0.5)
# ax2.plot([p_li[0], p_uk[0]], [p_li[1], p_uk[1]], marker='o', color="black", linewidth=0.5)
# ax2.plot([p_li[0], p_u2k2[0]], [p_li[1], p_u2k2[1]], marker='o', color="black", linewidth=0.5)
# 
# ax2.plot([p_li[0]], [p_li[1]], marker='o', color='blue', markersize=10)
ax2.plot([p_vj[0]], [p_vj[1]], marker='o', color='orange', markersize=10)
ax2.plot([p_uk[0]], [p_uk[1]], marker='o', color='green', markersize=10)
# ax2.plot([p_u2k2[0]], [p_u2k2[1]], marker='o', color='teal', markersize=10)

# ax2.set_title("Dual Plane (Affine RP² Coordinates)")
# ax2.set_xlabel("x (dual)")
# ax2.set_ylabel("y (dual)")
ax2.set_aspect('equal')
ax2.grid(True)
# ax2.set_xticklabels([])
# ax2.set_yticklabels([])
plt.tight_layout()
plt.show()
# Out:
# The orientation is Clockwise

# %%
import matplotlib.pyplot as plt
import numpy as np
from fractions import Fraction

def primal_line_to_dual_point(p1, p2):
    denominator = p1[0] * p2[1] - p1[1] * p2[0]
    if denominator == 0:
        raise ValueError("Points are linearly dependent or degenerate (denominator = 0).")
    return (
        (p1[1] - p2[1]) / denominator, 
        (p2[0] - p1[0]) / denominator
    )

def orientation(p1, p2, p3):
    x1, y1 = p1
    x2, y2 = p2
    x3, y3 = p3
    
    # Using Fraction for exact rational arithmetic
    val = (Fraction(x2 - x1) * Fraction(y3 - y1)) - (Fraction(y2 - y1) * Fraction(x3 - x1))
    
    if val > 0:
        return "Counterclockwise"
    elif val < 0:
        return "Clockwise"
    else:
        return "Collinear"

# Blue
pl = (2, 9)
pi = (9, 2)

# Orange
pv = (2, 4)
pj = (10, 6)

# Green
pu = (4, 2)
pk = (9, 5)

# Teal
# pu2 = (3, 2)
# pk2 = (3, 5)

pu2 = (2, 6)
pk2 = (8, 7)

# Compute dual points
p_li = primal_line_to_dual_point(pl, pi)
p_vj = primal_line_to_dual_point(pv, pj)
p_uk = primal_line_to_dual_point(pu, pk)
p_u2k2 = primal_line_to_dual_point(pu2, pk2)

print(f"The orientation is {orientation(p_li, p_vj, p_uk)}")

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Primal lines
ax1.plot([pl[0], pi[0]], [pl[1], pi[1]], marker='o', color='blue', markersize=10)
ax1.plot([pv[0], pj[0]], [pv[1], pj[1]], marker='o', color='orange', markersize=10)
ax1.plot([pu[0], pk[0]], [pu[1], pk[1]], marker='o', color='green', markersize=10)
ax1.plot([pu2[0], pk2[0]], [pu2[1], pk2[1]], marker='o', color='teal', markersize=10)
# ax1.set_title("Primal Plane (Segments)")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax1.set_aspect('equal')
# ax1.set_xticklabels([])
# ax1.set_yticklabels([])
ax1.grid(True)



def draw_implicit_line(a, b, c, xlim=(-0.2, 0.1), **kwargs):
    x = np.linspace(*xlim, 500)
    if b != 0:
        y = (-a * x - c) / b
        plt.plot(x, y, **kwargs)
    else:
        x0 = -c / a
        plt.axvline(x0, **kwargs)

draw_implicit_line(pl[0], pl[1], 1, color='blue', linewidth=0.5)
draw_implicit_line(pi[0], pi[1], 1, color='blue', linewidth=0.5)

# draw_implicit_line(pu[0], pu[1], 1, color='gree', linewidth=0.5)
# draw_implicit_line(pk[0], pk[1], 1, color='green', linewidth=0.5)


# Dual points
ax2.plot([p_li[0], p_vj[0]], [p_li[1], p_vj[1]], marker='o', color="black", linewidth=0.5)
ax2.plot([p_li[0], p_uk[0]], [p_li[1], p_uk[1]], marker='o', color="black", linewidth=0.5)
ax2.plot([p_li[0], p_u2k2[0]], [p_li[1], p_u2k2[1]], marker='o', color="black", linewidth=0.5)
# 
ax2.plot([p_li[0]], [p_li[1]], marker='o', color='blue', markersize=10)
ax2.plot([p_vj[0]], [p_vj[1]], marker='o', color='orange', markersize=10)
ax2.plot([p_uk[0]], [p_uk[1]], marker='o', color='green', markersize=10)
ax2.plot([p_u2k2[0]], [p_u2k2[1]], marker='o', color='teal', markersize=10)

# ax2.set_title("Dual Plane (Affine RP² Coordinates)")
# ax2.set_xlabel("x (dual)")
# ax2.set_ylabel("y (dual)")
ax2.set_aspect('equal')
ax2.grid(True)
# ax2.set_xticklabels([])
# ax2.set_yticklabels([])
plt.tight_layout()
plt.show()
# Out:
# The orientation is Counterclockwise

# %%
import matplotlib.pyplot as plt
import numpy as np
from fractions import Fraction
from sympy import Point, Line
from ipywidgets import interact, FloatSlider
import ipywidgets as widgets

def primal_line_to_dual_point(p1, p2):
    denominator = p1[0] * p2[1] - p1[1] * p2[0]
    if denominator == 0:
        raise ValueError("Points are linearly dependent or degenerate (denominator = 0).")
    return (
        (p1[1] - p2[1]) / denominator, 
        (p2[0] - p1[0]) / denominator
    )

def line_intersection(p1, p2, q1, q2):
    """
    Return the intersection point of the infinite lines through (p1, p2) and (q1, q2),
    as a tuple of floats. Returns None if lines are parallel or identical.
    """
    # Convert input tuples to sympy Points
    p1, p2 = Point(p1), Point(p2)
    q1, q2 = Point(q1), Point(q2)
    
    line1 = Line(p1, p2)
    line2 = Line(q1, q2)
    
    inter = line1.intersection(line2)
    
    if not inter:
        return None  # No intersection (parallel or coincident)
    
    pt = inter[0].evalf()
    return float(pt.x), float(pt.y)

def orientation(p1, p2, p3):
    x1, y1 = p1
    x2, y2 = p2
    x3, y3 = p3
    
    # Using Fraction for exact rational arithmetic
    val = (Fraction(x2 - x1) * Fraction(y3 - y1)) - (Fraction(y2 - y1) * Fraction(x3 - x1))
    
    if val > 0:
        return "Counterclockwise"
    elif val < 0:
        return "Clockwise"
    else:
        return "Collinear"


def draw_implicit_line(a, b, c, painter, xlim=(-0.9, 0.4), **kwargs):
    x = np.linspace(*xlim, 500)
    if b != 0:
        y = (-a * x - c) / b
        painter.plot(x, y, **kwargs)
    else:
        x0 = -c / a
        painter.axvline(x0, **kwargs)


def plot_lines(t):
    xMin = 0
    xMax = 10
    yMin = 0
    yMax = 10
    
    xdMin = -2
    xdMax = 2
    ydMin = -2
    ydMax = 2
    
    
    # Blue
    pl = (1, 9)
    pi = (9, 1)
    
    # Orange
    pv = (2, 4)
    pj = (10, 6)
    
    # Green
    pu = (6, 9)
    pk = (7, 2)
    
    pt = (2, 2)
    
    # Get the point of intersection between the blue line and the orange line
    i_bo = line_intersection(pl, pi, pv, pj)
    
    # t = 0.1
    i_bo = (
        (1 - t) * pl[0] + t * pi[0],
        (1 - t) * pl[1] + t * pi[1],
    )
    
    
        
    # Compute dual points
    p_li = primal_line_to_dual_point(pl, pi)
    p_vj = primal_line_to_dual_point(pv, pj)
    p_uk = primal_line_to_dual_point(pu, pk)


     # y = (-a * x - c) / b
    
    # get endpoints of the line i_bo* in x \in [-0.9, 0.4]
    # x = (p_li[0] - (xdMax - xdMin), p_li[0] + (xdMax - xdMin))
    x = (p_li[0] - 50, p_li[0] + 50)
    i_bo_a = (x[0], (-1.0 * i_bo[0] * x[0] - 1) / i_bo[1])
    i_bo_b = (x[1], (-1.0 * i_bo[0] * x[1] - 1) / i_bo[1])

    
    print(f"The orientation is {orientation(p_li, p_vj, p_uk)}")
    
    # Create subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))


    
    for t in np.linspace(0, 1, 500):
        # pt = (1 - t) * i_bo_a[0] + t * i_bo_a[0]
        newP = (
            (1 - t) * i_bo_a[0] + t * p_li[0],
            (1 - t) * i_bo_a[1] + t * p_li[1]
        )
        # print(newP)
        ax2.plot([newP[0]], [newP[1]], marker='o', color='teal', markersize=5)    
        draw_implicit_line(newP[0], newP[1], 1, ax1, xlim=(xMin, xMax), color='teal', linewidth=0.3)
    
    for t in np.linspace(0, 1, 500):
        # pt = (1 - t) * i_bo_a[0] + t * i_bo_a[0]
        newP = (
            # (1 - t) * p_li[0] + t * i_bo_b[0],
            # (1 - t) * p_li[1] + t * i_bo_b[1]
    
            (1 - t) * i_bo_b[0] + t * p_li[0],
            (1 - t) * i_bo_b[1] + t * p_li[1]
        )
        # print(newP)
        ax2.plot([newP[0]], [newP[1]], marker='o', color='purple', markersize=5)    
        draw_implicit_line(newP[0], newP[1], 1, ax1, xlim=(xMin, xMax), color='purple', linewidth=0.3)



    # Primal lines
    ax1.plot([pl[0], pi[0]], [pl[1], pi[1]], marker='o', color='gray', markersize=10, linewidth=5.5)
    ax1.plot([pi[0]], [pi[1]], marker='o', color='green', markersize=10)
    ax1.plot([pl[0]], [pl[1]], marker='o', color='blue', markersize=10)

    # ax1.plot([i_bo[0]], [i_bo[1]], marker='o', color='red', markersize=10)
    
    # ax1.set_title("Primal Plane (Segments)")
    ax1.set_xlabel("x")
    ax1.set_ylabel("y")
    ax1.set_aspect('equal')
    ax1.set_xlim(xMin, xMax)
    ax1.set_ylim(yMin, yMax)
    # ax1.set_xticklabels([])
    # ax1.set_yticklabels([])
    ax1.grid(True)



     # Dual points
    
    # Draw the bounds of the edges
    draw_implicit_line(pi[0], pi[1], 1, ax2, xlim = (-10, 10), color='green', linewidth=2.5)
    draw_implicit_line(pl[0], pl[1], 1, ax2, xlim = (-10, 10), color='blue', linewidth=2.5)
    
    # draw_implicit_line(i_bo[0], i_bo[1], 1, ax2, xlim = (-10, 10), color='gra', linewidth=0.5)
    
    # draw_implicit_line(pt[0], pt[1], 1, ax2, xlim = (-10, 10), color='red', linewidth=0.5)
    
    # draw_implicit_line(pu[0], pu[1], 1, color='gree', linewidth=0.5)
    # draw_implicit_line(pk[0], pk[1], 1, color='green', linewidth=0.5)
    
    
    
    
    
    
    
    
    
    
   
    
    
    
    # ax2.plot([p_li[0], p_vj[0]], [p_li[1], p_vj[1]], marker='o', color="black", linewidth=0.5)
    # ax2.plot([p_li[0], p_uk[0]], [p_li[1], p_uk[1]], marker='o', color="black", linewidth=0.5)
    # ax2.plot([p_li[0], p_u2k2[0]], [p_li[1], p_u2k2[1]], marker='o', color="black", linewidth=0.5)
    ax2.plot([p_li[0]], [p_li[1]], marker='o', color='gray', markersize=12)
    # ax2.plot([p_vj[0]], [p_vj[1]], marker='o', color='orange', markersize=10)
    # ax2.plot([p_uk[0]], [p_uk[1]], marker='o', color='green', markersize=10)
    
    # ax2.plot([i_bo_a[0]], [i_bo_a[1]], marker='o', color='teal', markersize=20)
    # ax2.plot([i_bo_b[0]], [i_bo_b[1]], marker='o', color='purple', markersize=20)
    
    
    # ax2.set_title("Dual Plane (Affine RP² Coordinates)")
    # ax2.set_xlabel("x (dual)")
    # ax2.set_ylabel("y (dual)")
    ax2.set_aspect('equal')
    ax2.grid(True)
    ax2.set_xlim(xdMin, xdMax)
    ax2.set_ylim(ydMin, ydMax)
    # ax2.set_xticklabels([])
    # ax2.set_yticklabels([])
    plt.tight_layout()
    plt.show()

# plot_lines(0.5)

interact(plot_lines, t=FloatSlider(value=0.5, min=0.0, max=1.0, step=0.05));
# Out:
# interactive(children=(FloatSlider(value=0.5, description='t', max=1.0, step=0.05), Output()), _dom_classes=('w…

# %%
import matplotlib.pyplot as plt
import numpy as np
from fractions import Fraction
from sympy import Point, Line
from ipywidgets import interact, FloatSlider
import ipywidgets as widgets

def draw_line_from_slope(m, b, painter, xlim=(-0.9, 0.4), **kwargs):
    """
    Draws a line y = m*x + b using the provided painter object.

    Parameters:
        m: slope of the line
        b: y-intercept of the line
        painter: matplotlib Axes object or similar with .plot method
        xlim: (min, max) tuple defining x-range
        kwargs: passed to painter.plot (e.g., color, linewidth, linestyle)
    """
    x = np.linspace(*xlim, 2)
    y = m * x + b
    painter.plot(x, y, **kwargs)


def primal_line_to_dual_point(p1, p2):
    """
    Given two points (x1, y1) and (x2, y2),
    returns the dual line in slope-intercept form: y = m x + b,
    where m = slope between p1 and p2, and b = -y-intercept.

    In the dual space, the line becomes a point: (m, -b)
    """
    x1, y1 = p1
    x2, y2 = p2

    if x1 == x2:
        raise ValueError("Vertical line — slope undefined in affine duality.")

    m = (y2 - y1) / (x2 - x1)
    b = y1 - m * x1

    # In the dual space, the line y = mx + b becomes the point (m, -b)
    return (m, -b)



def plot_lines(t):
    xMin = 0
    xMax = 10
    yMin = 0
    yMax = 10

    # Dual plane bounds
    xdMin = -40
    xdMax = 40
    ydMin = -60
    ydMax = 20
    
    
    # Blue
    pl = (2, 2)
    pi = (8, 9)
    
    # Orange
    pv = (2, 4)
    pj = (9, 6)
    
    # Green
    pu = (6, 9)
    pk = (7, 2)

    # Point along p_li
    pt = (
        (1 - t) * pl[0] + t * pi[0],
        (1 - t) * pl[1] + t * pi[1],
    )
    

    # Lines to points in the dual
    p_li = primal_line_to_dual_point(pl, pi)
    p_vj = primal_line_to_dual_point(pv, pj)
    p_uk = primal_line_to_dual_point(pu, pk)


    # get endpoints of the line i_bo* in x \in [-0.9, 0.4]
    x = (p_li[0] - (xdMax - xdMin), p_li[0] + (xdMax - xdMin))
    y = (pt[0] * x[0] - pt[1], pt[0] * x[1] - pt[1])

    i_bo_a = (x[0], y[0]) 
    i_bo_b = (x[1], y[1]) 
    
    
    # i_bo_a = (x[0], (-1.0 * pt[0] * x[0] - 1) / pt[1])
    # i_bo_b = (x[1], (-1.0 * pt[0] * x[1] - 1) / pt[1])
    

    
    # Compute dual points
    # p_li = dual_line_from_points(pl, pi)
    # p_vj = dual_line_from_points(pv, pj)
    # p_uk = dual_line_from_points(pu, pk)

    
    # Create subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))




    for t in np.linspace(0, 1, 1000):
        # pt = (1 - t) * i_bo_a[0] + t * i_bo_a[0]
        newP = (
            (1 - t) * i_bo_a[0] + t * p_li[0],
            (1 - t) * i_bo_a[1] + t * p_li[1]
        )
        # print(newP)
        ax2.plot([newP[0]], [newP[1]], marker='o', color='teal', markersize=5)    
        draw_line_from_slope(newP[0], -newP[1], ax1, xlim=(xMin, xMax), color='teal', linewidth=0.3)
    
    for t in np.linspace(0, 1, 1000):
        # pt = (1 - t) * i_bo_a[0] + t * i_bo_a[0]
        newP = (
            # (1 - t) * p_li[0] + t * i_bo_b[0],
            # (1 - t) * p_li[1] + t * i_bo_b[1]
    
            (1 - t) * i_bo_b[0] + t * p_li[0],
            (1 - t) * i_bo_b[1] + t * p_li[1]
        )
        # print(newP)
        ax2.plot([newP[0]], [newP[1]], marker='o', color='purple', markersize=5)    
        draw_line_from_slope(newP[0], -newP[1], ax1, xlim=(xMin, xMax), color='purple', linewidth=0.3)
    








    
    
    # Primal lines
    ax1.plot([pl[0], pi[0]], [pl[1], pi[1]], marker='o', color='blue', markersize=10)
    # ax1.plot([pv[0], pj[0]], [pv[1], pj[1]], marker='o', color='orange', markersize=10)
    # ax1.plot([pu[0], pk[0]], [pu[1], pk[1]], marker='o', color='green', markersize=10)

    ax1.plot([pt[0]], [pt[1]], marker='o', color='red', markersize=10)
    
    
    # ax1.set_title("Primal Plane (Segments)")
    ax1.set_xlabel("x")
    ax1.set_ylabel("y")
    ax1.set_aspect('equal')
    ax1.set_xlim(xMin, xMax)
    ax1.set_ylim(yMin, yMax)
    # ax1.set_xticklabels([])
    # ax1.set_yticklabels([])
    ax1.grid(True)

    #
    # Dual  Plane
    #
    
    # Draw the bounds of the edges
    draw_line_from_slope(pl[0], -pl[1], ax2, xlim = (xdMin, xdMax), color='blue', linewidth=0.5)
    draw_line_from_slope(pi[0], -pi[1], ax2, xlim = (xdMin, xdMax), color='blue', linewidth=0.5)
    
    # draw_line_from_slope(pt[0], -pt[1], ax2, xlim = (xdMin, xdMax), color='red', linewidth=0.5)
    
    # draw_implicit_line(i_bo[0], i_bo[1], 1, ax2, xlim = (-10, 10), color='black', linewidth=0.5)
    # draw_implicit_line(pt[0], pt[1], 1, ax2, xlim = (-10, 10), color='red', linewidth=0.5)
    # draw_implicit_line(pu[0], pu[1], 1, color='gree', linewidth=0.5)
    # draw_implicit_line(pk[0], pk[1], 1, color='green', linewidth=0.5)
    # Dual points
    
    
    # ax2.plot([p_li[0], p_vj[0]], [p_li[1], p_vj[1]], marker='o', color="black", linewidth=0.5)
    # ax2.plot([p_li[0], p_uk[0]], [p_li[1], p_uk[1]], marker='o', color="black", linewidth=0.5)
    # ax2.plot([p_li[0], p_u2k2[0]], [p_li[1], p_u2k2[1]], marker='o', color="black", linewidth=0.5)
    ax2.plot([p_li[0]], [p_li[1]], marker='o', color='blue', markersize=10)
    # ax2.plot([p_vj[0]], [p_vj[1]], marker='o', color='orange', markersize=10)
    # ax2.plot([p_uk[0]], [p_uk[1]], marker='o', color='green', markersize=10)

    ax2.plot([i_bo_a[0]], [i_bo_a[1]], marker='o', color='teal', markersize=10)
    ax2.plot([i_bo_b[0]], [i_bo_b[1]], marker='o', color='purple', markersize=10)
    
    # ax2.plot([i_bo_a[0]], [i_bo_a[1]], marker='o', color='teal', markersize=10)
    # ax2.plot([i_bo_b[0]], [i_bo_b[1]], marker='o', color='purple', markersize=10)


    
    # ax2.set_title("Dual Plane (Affine RP² Coordinates)")
    # ax2.set_xlabel("x (dual)")
    # ax2.set_ylabel("y (dual)")
    ax2.set_aspect('equal')
    ax2.grid(True)
    ax2.set_xlim(xdMin, xdMax)
    ax2.set_ylim(ydMin, ydMax)
    # ax2.set_xticklabels([])
    # ax2.set_yticklabels([])
    plt.tight_layout()
    plt.show()


# plot_lines(0.2)
interact(plot_lines, t=FloatSlider(value=0.5, min=0.0, max=1.0, step=0.05));
# Out:
# interactive(children=(FloatSlider(value=0.5, description='t', max=1.0, step=0.05), Output()), _dom_classes=('w…

# %%
import matplotlib.pyplot as plt
import numpy as np
from fractions import Fraction

def primal_line_to_dual_point(p1, p2):
    denominator = p1[0] * p2[1] - p1[1] * p2[0]
    if denominator == 0:
        raise ValueError("Points are linearly dependent or degenerate (denominator = 0).")
    return (
        (p1[1] - p2[1]) / denominator, 
        (p2[0] - p1[0]) / denominator
    )

def orientation(p1, p2, p3):
    x1, y1 = p1
    x2, y2 = p2
    x3, y3 = p3
    
    # Using Fraction for exact rational arithmetic
    val = (Fraction(x2 - x1) * Fraction(y3 - y1)) - (Fraction(y2 - y1) * Fraction(x3 - x1))
    
    if val > 0:
        return "Counterclockwise"
    elif val < 0:
        return "Clockwise"
    else:
        return "Collinear"

# Blue
pl = [709402351/4383829060, 108722733433/68370872455]
pi = [13565295989/2031530540, -194185818775/19010437707]
pv = [-398306993/194730640, 592849531/303704902]
pj = [705774283/121706650, -303298786/151852451]
pu = [26640351/40433380, 436945273736/90176545745]
pk = [88115647/80866760, -24681211891/1261210430]


# Compute dual points
p_li = primal_line_to_dual_point(pl, pi)
p_vj = primal_line_to_dual_point(pv, pj)
p_uk = primal_line_to_dual_point(pu, pk)

print(f"The orientation is {orientation(p_li, p_vj, p_uk)}")

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Primal lines
ax1.plot([pl[0], pi[0]], [pl[1], pi[1]], marker='o', color='blue', markersize=10)
ax1.plot([pv[0], pj[0]], [pv[1], pj[1]], marker='o', color='orange', markersize=10)
ax1.plot([pu[0], pk[0]], [pu[1], pk[1]], marker='o', color='green', markersize=10)

# ax1.set_title("Primal Plane (Segments)")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax1.set_aspect('equal')
# ax1.set_xticklabels([])
# ax1.set_yticklabels([])
ax1.grid(True)



def draw_implicit_line(a, b, c, xlim=(-0.2, 0.1), **kwargs):
    x = np.linspace(*xlim, 500)
    if b != 0:
        y = (-a * x - c) / b
        plt.plot(x, y, **kwargs)
    else:
        x0 = -c / a
        plt.axvline(x0, **kwargs)

# draw_implicit_line(pl[0], pl[1], 1, color='blue', linewidth=0.5)
# draw_implicit_line(pi[0], pi[1], 1, color='blue', linewidth=0.5)

# draw_implicit_line(pi[0], pi[1], 1, ax2, xlim = (-10, 10), color='green', linewidth=2.5)
# draw_implicit_line(pl[0], pl[1], 1, ax2, xlim = (-10, 10), color='blue', linewidth=2.5)

draw_implicit_line(pl[0], pl[1], 1, xlim = (-10, 10), color='blue', linewidth=0.5)
draw_implicit_line(pi[0], pi[1], 1, xlim = (-10, 10), color='blue', linewidth=0.5)

# draw_implicit_line(pu[0], pu[1], 1, color='gree', linewidth=0.5)
# draw_implicit_line(pk[0], pk[1], 1, color='green', linewidth=0.5)


# Dual points
ax2.plot([p_li[0], p_vj[0]], [p_li[1], p_vj[1]], marker='o', color="black", linewidth=0.5)
ax2.plot([p_li[0], p_uk[0]], [p_li[1], p_uk[1]], marker='o', color="black", linewidth=0.5)

# 
ax2.plot([p_li[0]], [p_li[1]], marker='o', color='blue', markersize=10)
ax2.plot([p_vj[0]], [p_vj[1]], marker='o', color='orange', markersize=10)
ax2.plot([p_uk[0]], [p_uk[1]], marker='o', color='green', markersize=10)


# ax2.set_title("Dual Plane (Affine RP² Coordinates)")
# ax2.set_xlabel("x (dual)")
# ax2.set_ylabel("y (dual)")
ax2.set_aspect('equal')
ax2.grid(True)
# ax2.set_xticklabels([])
# ax2.set_yticklabels([])
plt.tight_layout()
plt.show()
# Out:
# The orientation is Clockwise

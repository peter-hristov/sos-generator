# %%
# Build the matrix
from sympy import symbols, Matrix, collect, expand, IndexedBase, Indexed, simplify, ccode

def isInArray(expression, expressionArray):
    for e in expressionArray:
        # print(f"comparing {expression} and {e}")
        if expression == e or -expression == e:
            return True
    return False

def orientationTest(p1, p2, p3):
    M = Matrix([
        [p1[0], p1[1], 1],
        [p2[0], p2[1], 1],
        [p3[0], p3[1], 1],
    ])

    return M.det()

def orientationTestHomogenious(p1, p2, p3):
    M = Matrix([
        [p1[0], p1[1], p1[2]],
        [p2[0], p2[1], p2[2]],
        [p3[0], p3[1], p3[2]],
    ])

    return M.det()

def orientationTestHomogenious4D(p1, p2, p3, p4):
    M = Matrix([
        [p1[0], p1[1], p1[2], p1[3]],
        [p2[0], p2[1], p2[2], p2[3]],
        [p3[0], p3[1], p3[2], p3[3]],
        [p4[0], p4[1], p4[2], p4[3]],
    ])

    return M.det()

def count_indexed_with_base(term, base):
    """Return the number of Indexed objects in a term with the given base."""
    return sum(1 for atom in term.atoms(Indexed) if atom.base == base)

def generate_sequence(varNames, dimensions=(1, 2)):
    sequence = []
    # sequence.append([f"e[{varNames[0]}, {dimensions[1]}]", f"e[{varNames[0]}, {dimensions[0]}]"])

    firstRow = []
    for j in reversed(range(len(dimensions))):
        firstRow.append(e[varNames[0], dimensions[j]])

    sequence.append(firstRow)
    # sequence.append([e[varNames[0], dimensions[1]], e[varNames[0], dimensions[0]]])

    for i in range(1, len(varNames)):
        currentSequence = []
        for j in reversed(range(len(dimensions))):
            # currentSequence.append(f"e[{varNames[i]}, {dimensions[j]}]")
            currentSequence.append(e[varNames[i], dimensions[j]])
            for s in range(len(sequence)):
                previousSequence = sequence[s]
                for k in range(len(previousSequence)):
                    # appendString = f"e[{varNames[i]}, {dimensions[j]}]"
                    appendProduct = e[varNames[i], dimensions[j]] * previousSequence[k]
                    # if previousSequence[k] != "":
                    # appendProduct *= previousSequence[k]
                    currentSequence.append(appendProduct)
        sequence.append(currentSequence)
                    
                    

    return sequence

def dualizeAndOrient():
    # Homogenious

    # p_li
    p_l = (p[l, 1] + e[l, 1], p[l, 2] + e[l, 2])
    p_i = (p[i, 1] + e[i, 1], p[i, 2] + e[i, 2])

    # p_vj
    p_v = (p[v, 1] + e[v, 1], p[v, 2] + e[v, 2])
    p_j = (p[j, 1] + e[j, 1], p[j, 2] + e[j, 2])

    # p_uk
    p_u = (p[u, 1] + e[u, 1], p[u, 2] + e[u, 2])
    p_k = (p[k, 1] + e[k, 1], p[k, 2] + e[k, 2])


    # p_li homogenious
    p_li = (
        p_l[1] - p_i[1],
        p_i[0] - p_l[0],
        p_l[0] * p_i[1] - p_l[1] * p_i[0]
    )

    # p_vj homogenious
    p_vj = (
        p_v[1] - p_j[1],
        p_j[0] - p_v[0],
        p_v[0] * p_j[1] - p_v[1] * p_j[0]
    )

    # p_uk
    p_uk = (
        p_u[1] - p_k[1],
        p_k[0] - p_u[0],
        p_u[0] * p_k[1] - p_u[1] * p_k[0]
    )

    return orientationTestHomogenious(p_li, p_vj, p_uk)


def parametrizeAndOrder():

    # p_l -> p_i
    r = Matrix([p[i,1] - p[l,1] + e[i,1] - e[l,1], p[i,2] - p[l,2] + e[i,2] - e[l,2]])

    # p_v -> p_j
    s1 = Matrix([p[j,1] - p[v,1] + e[j,1] - e[v,1], p[j,2] - p[v,2] + e[j,2] - e[v,2]])
    # p_u -> p_k
    s2 = Matrix([p[k,1] - p[u,1] + e[k,1] - e[u,1], p[k,2] - p[u,2] + e[k,2] - e[u,2]])

    # p_v -> p_l
    q1 = Matrix([p[l,1] - p[v,1] + e[l,1] - e[v,1], p[l,2] - p[v,2] + e[l,2] - e[v,2]])
    # p_u -> p_l
    q2 = Matrix([p[l,1] - p[u,1] + e[l,1] - e[u,1], p[l,2] - p[u,2] + e[l,2] - e[u,2]])


    q1xs1 = Matrix([
        q1.T.tolist()[0],  # convert row matrix to flat list
        s1.T.tolist()[0]
    ]).det()

    q2xs2 = Matrix([
        q2.T.tolist()[0],  # convert row matrix to flat list
        s2.T.tolist()[0]
    ]).det()

    q1xr = Matrix([
        q1.T.tolist()[0],  # convert row matrix to flat list
        r.T.tolist()[0]
    ]).det()

    q2xr = Matrix([
        q2.T.tolist()[0],  # convert row matrix to flat list
        r.T.tolist()[0]
    ]).det()

    rxs1 = Matrix([
        r.T.tolist()[0],  # convert row matrix to flat list
        s1.T.tolist()[0]
    ]).det()

    rxs2 = Matrix([
        r.T.tolist()[0],  # convert row matrix to flat list
        s2.T.tolist()[0]
    ]).det()


    return expand(q1xs1 * rxs2 - q2xs2 * rxs1)





p = IndexedBase('p', shape=(6, 2))
e = IndexedBase('e', shape=(6, 2))


# p = IndexedBase('p')
# e = IndexedBase('e')

# Symbolic indices
variables = symbols('i j k l u v')
i, j, k, l, u, v = variables


# a = p[i, 1] * p[j, 2] - 1
# b = -p[j, 2] - p[i, 1]

# print (a == -b)


# print(type(a).__name__)

# exit()

print("Computing initial expression...")
# Affine
# det = orientationTestHomogenious(
        # (p[i, 1] + e[i, 1], p[i, 2] + e[i, 2], p[i, 3] + e[i, 3]), 
        # (p[j, 1] + e[j, 1], p[j, 2] + e[j, 2], p[j, 3] + e[j, 3]), 
        # (p[k, 1] + e[k, 1], p[k, 2] + e[k, 2], p[k, 3] + e[k, 3])
        # )

# det = orientationTestHomogenious4D(
        # (p[i, 1] + e[i, 1], p[i, 2] + e[i, 2], p[i, 3] + e[i, 3], p[i, 4] + e[i, 4]), 
        # (p[j, 1] + e[j, 1], p[j, 2] + e[j, 2], p[j, 3] + e[j, 3], p[j, 4] + e[j, 4]), 
        # (p[k, 1] + e[k, 1], p[k, 2] + e[k, 2], p[k, 3] + e[k, 3], p[k, 4] + e[k, 4]),
        # (p[l, 1] + e[l, 1], p[l, 2] + e[l, 2], p[l, 3] + e[l, 3], p[l, 4] + e[l, 4])
        # )

det = dualizeAndOrient()
# det = parametrizeAndOrder()


expression = simplify(expand(det))
expressionTermsOrdered = expression.as_ordered_terms()

print(f"Total terms {len(expressionTermsOrdered)}")


print("Arranging terms into different levels...")
allTerms = []
# the upper limit on the range is an arbitrary large number, the loops really is only supposed to stop when we break
for i in range(0, 100000):
    terms = sum([
        t for t in expressionTermsOrdered
        if count_indexed_with_base(t, e) == i
    ])

    if (terms == 0):
        break

    allTerms.append(terms)

# print("Here are all the terms in the expression:")
# for t in expressionTermsOrdered:
#     print(t)

# print("\n\nHere are all the terms grouped by the number of epsilons:")
# for i in range(0, len(allTerms)):
#     print(i)
#     print(allTerms[i])

print(f"We have this many types of mixed expressions {len(allTerms)}")

def printSosTable():
    print("\n\nHere are all the sequences:")
    depth = 0
    pExpressions = [allTerms[0]]
    eExpressions = [[]]

    seq = generate_sequence(variables)
    for line in seq:
        for eProduct in line:
            num_factors = len(eProduct.args) if eProduct.is_Mul else 1

            if (num_factors > len(allTerms) - 1):
                continue

            # # print(num_factors)

            collectionTerm = eProduct
            collectionExpression = allTerms[num_factors]
            depth+=1
            collected_expr = collect(collectionExpression, collectionTerm).coeff(collectionTerm)


            # Skip if it's not in the expression
            if not collectionExpression.has(collectionTerm):
                print(f"\n\nThe epsilon product with order {depth}: {(eProduct)}")
                # print(f"The number of factors is {num_factors}")
                # print(f"The collection expressions is {collectionExpression}")
                # print(f"The p-term of that product has {len(collected_expr.as_ordered_terms())} terms:")
                # print((collected_expr))
                # print(f"Here it is simplified...")
                # print(simplify(collected_expr))
                print("------------------------------------- Skipping")
                continue

            # if collectionExpression in s or (-1 * collectionExpression) in s:
            # if any(collectionExpression.equals(e) or (-collectionExpression).equals(e) for e in s):
                # print(f"\n\nThe epsilon product with order {depth}: {(eProduct)}")
                # print("------------------------------------- Skipping p-term is already there")


            if isInArray(collected_expr, pExpressions):
                print(f"\n\nThe epsilon product with order {depth}: {(eProduct)}")
                print(f"------------------------------------- Skipping {collected_expr} p-term is already there")
                continue

            pExpressions.append(collected_expr)
            eExpressions.append(eProduct)

            # print(f"\n\nThe current depth is {depth}.")
            # print("The current e-product is:")
            # print(eProduct)
            # print("The collected expression is:")
            # print(collected_expr)
            # print(f"Current num_factors = {num_factors}, compared to {len(allTerms) - 1}")

            print(f"\n\nThe epsilon product with order {depth}: {(eProduct)}")
            print(f"The p-term of that product has {len(collected_expr.as_ordered_terms())} terms:")
            print((collected_expr))
            print(f"Here it is simplified...")
            print(simplify(collected_expr))

            if (num_factors == len(allTerms) - 1):
                print("FOUND THE CONSTANT FACTOR!!!")
                return (pExpressions, eExpressions)

    return (pExpressions, eExpressions)

pExpressions, eExpressions = printSosTable()
# Out:
# Computing initial expression...
# Total terms 768
# Arranging terms into different levels...
# Here are all the terms in the expression:
# -e[i, 1]*e[j, 1]*e[k, 2]*e[l, 2]
# e[i, 1]*e[j, 1]*e[k, 2]*e[v, 2]
# -e[i, 1]*e[j, 1]*e[k, 2]*p[l, 2]
# e[i, 1]*e[j, 1]*e[k, 2]*p[v, 2]
# e[i, 1]*e[j, 1]*e[l, 2]*e[u, 2]
# -e[i, 1]*e[j, 1]*e[l, 2]*p[k, 2]
# e[i, 1]*e[j, 1]*e[l, 2]*p[u, 2]
# -e[i, 1]*e[j, 1]*e[u, 2]*e[v, 2]
# e[i, 1]*e[j, 1]*e[u, 2]*p[l, 2]
# -e[i, 1]*e[j, 1]*e[u, 2]*p[v, 2]
# e[i, 1]*e[j, 1]*e[v, 2]*p[k, 2]
# -e[i, 1]*e[j, 1]*e[v, 2]*p[u, 2]
# -e[i, 1]*e[j, 1]*p[k, 2]*p[l, 2]
# e[i, 1]*e[j, 1]*p[k, 2]*p[v, 2]
# e[i, 1]*e[j, 1]*p[l, 2]*p[u, 2]
# -e[i, 1]*e[j, 1]*p[u, 2]*p[v, 2]
# e[i, 1]*e[j, 2]*e[k, 1]*e[l, 2]
# -e[i, 1]*e[j, 2]*e[k, 1]*e[u, 2]
# e[i, 1]*e[j, 2]*e[k, 1]*p[l, 2]
# -e[i, 1]*e[j, 2]*e[k, 1]*p[u, 2]
# e[i, 1]*e[j, 2]*e[k, 2]*e[u, 1]
# -e[i, 1]*e[j, 2]*e[k, 2]*e[v, 1]
# e[i, 1]*e[j, 2]*e[k, 2]*p[u, 1]
# -e[i, 1]*e[j, 2]*e[k, 2]*p[v, 1]
# -e[i, 1]*e[j, 2]*e[l, 2]*e[u, 1]
# e[i, 1]*e[j, 2]*e[l, 2]*p[k, 1]
# -e[i, 1]*e[j, 2]*e[l, 2]*p[u, 1]
# e[i, 1]*e[j, 2]*e[u, 1]*p[k, 2]
# -e[i, 1]*e[j, 2]*e[u, 1]*p[l, 2]
# e[i, 1]*e[j, 2]*e[u, 2]*e[v, 1]
# -e[i, 1]*e[j, 2]*e[u, 2]*p[k, 1]
# e[i, 1]*e[j, 2]*e[u, 2]*p[v, 1]
# -e[i, 1]*e[j, 2]*e[v, 1]*p[k, 2]
# e[i, 1]*e[j, 2]*e[v, 1]*p[u, 2]
# e[i, 1]*e[j, 2]*p[k, 1]*p[l, 2]
# -e[i, 1]*e[j, 2]*p[k, 1]*p[u, 2]
# e[i, 1]*e[j, 2]*p[k, 2]*p[u, 1]
# -e[i, 1]*e[j, 2]*p[k, 2]*p[v, 1]
# -e[i, 1]*e[j, 2]*p[l, 2]*p[u, 1]
# e[i, 1]*e[j, 2]*p[u, 2]*p[v, 1]
# -e[i, 1]*e[k, 1]*e[l, 2]*e[v, 2]
# e[i, 1]*e[k, 1]*e[l, 2]*p[j, 2]
# -e[i, 1]*e[k, 1]*e[l, 2]*p[v, 2]
# e[i, 1]*e[k, 1]*e[u, 2]*e[v, 2]
# -e[i, 1]*e[k, 1]*e[u, 2]*p[j, 2]
# e[i, 1]*e[k, 1]*e[u, 2]*p[v, 2]
# -e[i, 1]*e[k, 1]*e[v, 2]*p[l, 2]
# e[i, 1]*e[k, 1]*e[v, 2]*p[u, 2]
# e[i, 1]*e[k, 1]*p[j, 2]*p[l, 2]
# -e[i, 1]*e[k, 1]*p[j, 2]*p[u, 2]
# -e[i, 1]*e[k, 1]*p[l, 2]*p[v, 2]
# e[i, 1]*e[k, 1]*p[u, 2]*p[v, 2]
# e[i, 1]*e[k, 2]*e[l, 2]*e[v, 1]
# -e[i, 1]*e[k, 2]*e[l, 2]*p[j, 1]
# e[i, 1]*e[k, 2]*e[l, 2]*p[v, 1]
# -e[i, 1]*e[k, 2]*e[u, 1]*e[v, 2]
# e[i, 1]*e[k, 2]*e[u, 1]*p[j, 2]
# -e[i, 1]*e[k, 2]*e[u, 1]*p[v, 2]
# -e[i, 1]*e[k, 2]*e[v, 1]*p[j, 2]
# e[i, 1]*e[k, 2]*e[v, 1]*p[l, 2]
# e[i, 1]*e[k, 2]*e[v, 2]*p[j, 1]
# -e[i, 1]*e[k, 2]*e[v, 2]*p[u, 1]
# -e[i, 1]*e[k, 2]*p[j, 1]*p[l, 2]
# e[i, 1]*e[k, 2]*p[j, 1]*p[v, 2]
# e[i, 1]*e[k, 2]*p[j, 2]*p[u, 1]
# -e[i, 1]*e[k, 2]*p[j, 2]*p[v, 1]
# e[i, 1]*e[k, 2]*p[l, 2]*p[v, 1]
# -e[i, 1]*e[k, 2]*p[u, 1]*p[v, 2]
# e[i, 1]*e[l, 2]*e[u, 1]*e[v, 2]
# -e[i, 1]*e[l, 2]*e[u, 1]*p[j, 2]
# e[i, 1]*e[l, 2]*e[u, 1]*p[v, 2]
# -e[i, 1]*e[l, 2]*e[u, 2]*e[v, 1]
# e[i, 1]*e[l, 2]*e[u, 2]*p[j, 1]
# -e[i, 1]*e[l, 2]*e[u, 2]*p[v, 1]
# e[i, 1]*e[l, 2]*e[v, 1]*p[k, 2]
# -e[i, 1]*e[l, 2]*e[v, 1]*p[u, 2]
# -e[i, 1]*e[l, 2]*e[v, 2]*p[k, 1]
# e[i, 1]*e[l, 2]*e[v, 2]*p[u, 1]
# -e[i, 1]*e[l, 2]*p[j, 1]*p[k, 2]
# e[i, 1]*e[l, 2]*p[j, 1]*p[u, 2]
# e[i, 1]*e[l, 2]*p[j, 2]*p[k, 1]
# -e[i, 1]*e[l, 2]*p[j, 2]*p[u, 1]
# -e[i, 1]*e[l, 2]*p[k, 1]*p[v, 2]
# e[i, 1]*e[l, 2]*p[k, 2]*p[v, 1]
# e[i, 1]*e[l, 2]*p[u, 1]*p[v, 2]
# -e[i, 1]*e[l, 2]*p[u, 2]*p[v, 1]
# -e[i, 1]*e[u, 1]*e[v, 2]*p[k, 2]
# e[i, 1]*e[u, 1]*e[v, 2]*p[l, 2]
# e[i, 1]*e[u, 1]*p[j, 2]*p[k, 2]
# -e[i, 1]*e[u, 1]*p[j, 2]*p[l, 2]
# -e[i, 1]*e[u, 1]*p[k, 2]*p[v, 2]
# e[i, 1]*e[u, 1]*p[l, 2]*p[v, 2]
# e[i, 1]*e[u, 2]*e[v, 1]*p[j, 2]
# -e[i, 1]*e[u, 2]*e[v, 1]*p[l, 2]
# -e[i, 1]*e[u, 2]*e[v, 2]*p[j, 1]
# e[i, 1]*e[u, 2]*e[v, 2]*p[k, 1]
# e[i, 1]*e[u, 2]*p[j, 1]*p[l, 2]
# -e[i, 1]*e[u, 2]*p[j, 1]*p[v, 2]
# -e[i, 1]*e[u, 2]*p[j, 2]*p[k, 1]
# e[i, 1]*e[u, 2]*p[j, 2]*p[v, 1]
# e[i, 1]*e[u, 2]*p[k, 1]*p[v, 2]
# -e[i, 1]*e[u, 2]*p[l, 2]*p[v, 1]
# -e[i, 1]*e[v, 1]*p[j, 2]*p[k, 2]
# e[i, 1]*e[v, 1]*p[j, 2]*p[u, 2]
# e[i, 1]*e[v, 1]*p[k, 2]*p[l, 2]
# -e[i, 1]*e[v, 1]*p[l, 2]*p[u, 2]
# e[i, 1]*e[v, 2]*p[j, 1]*p[k, 2]
# -e[i, 1]*e[v, 2]*p[j, 1]*p[u, 2]
# -e[i, 1]*e[v, 2]*p[k, 1]*p[l, 2]
# e[i, 1]*e[v, 2]*p[k, 1]*p[u, 2]
# -e[i, 1]*e[v, 2]*p[k, 2]*p[u, 1]
# e[i, 1]*e[v, 2]*p[l, 2]*p[u, 1]
# -e[i, 1]*p[j, 1]*p[k, 2]*p[l, 2]
# e[i, 1]*p[j, 1]*p[k, 2]*p[v, 2]
# e[i, 1]*p[j, 1]*p[l, 2]*p[u, 2]
# -e[i, 1]*p[j, 1]*p[u, 2]*p[v, 2]
# e[i, 1]*p[j, 2]*p[k, 1]*p[l, 2]
# -e[i, 1]*p[j, 2]*p[k, 1]*p[u, 2]
# e[i, 1]*p[j, 2]*p[k, 2]*p[u, 1]
# -e[i, 1]*p[j, 2]*p[k, 2]*p[v, 1]
# -e[i, 1]*p[j, 2]*p[l, 2]*p[u, 1]
# e[i, 1]*p[j, 2]*p[u, 2]*p[v, 1]
# -e[i, 1]*p[k, 1]*p[l, 2]*p[v, 2]
# e[i, 1]*p[k, 1]*p[u, 2]*p[v, 2]
# e[i, 1]*p[k, 2]*p[l, 2]*p[v, 1]
# -e[i, 1]*p[k, 2]*p[u, 1]*p[v, 2]
# e[i, 1]*p[l, 2]*p[u, 1]*p[v, 2]
# -e[i, 1]*p[l, 2]*p[u, 2]*p[v, 1]
# e[i, 2]*e[j, 1]*e[k, 1]*e[u, 2]
# -e[i, 2]*e[j, 1]*e[k, 1]*e[v, 2]
# e[i, 2]*e[j, 1]*e[k, 1]*p[u, 2]
# -e[i, 2]*e[j, 1]*e[k, 1]*p[v, 2]
# e[i, 2]*e[j, 1]*e[k, 2]*e[l, 1]
# -e[i, 2]*e[j, 1]*e[k, 2]*e[u, 1]
# e[i, 2]*e[j, 1]*e[k, 2]*p[l, 1]
# -e[i, 2]*e[j, 1]*e[k, 2]*p[u, 1]
# -e[i, 2]*e[j, 1]*e[l, 1]*e[u, 2]
# e[i, 2]*e[j, 1]*e[l, 1]*p[k, 2]
# -e[i, 2]*e[j, 1]*e[l, 1]*p[u, 2]
# e[i, 2]*e[j, 1]*e[u, 1]*e[v, 2]
# -e[i, 2]*e[j, 1]*e[u, 1]*p[k, 2]
# e[i, 2]*e[j, 1]*e[u, 1]*p[v, 2]
# e[i, 2]*e[j, 1]*e[u, 2]*p[k, 1]
# -e[i, 2]*e[j, 1]*e[u, 2]*p[l, 1]
# -e[i, 2]*e[j, 1]*e[v, 2]*p[k, 1]
# e[i, 2]*e[j, 1]*e[v, 2]*p[u, 1]
# e[i, 2]*e[j, 1]*p[k, 1]*p[u, 2]
# -e[i, 2]*e[j, 1]*p[k, 1]*p[v, 2]
# e[i, 2]*e[j, 1]*p[k, 2]*p[l, 1]
# -e[i, 2]*e[j, 1]*p[k, 2]*p[u, 1]
# -e[i, 2]*e[j, 1]*p[l, 1]*p[u, 2]
# e[i, 2]*e[j, 1]*p[u, 1]*p[v, 2]
# -e[i, 2]*e[j, 2]*e[k, 1]*e[l, 1]
# e[i, 2]*e[j, 2]*e[k, 1]*e[v, 1]
# -e[i, 2]*e[j, 2]*e[k, 1]*p[l, 1]
# e[i, 2]*e[j, 2]*e[k, 1]*p[v, 1]
# e[i, 2]*e[j, 2]*e[l, 1]*e[u, 1]
# -e[i, 2]*e[j, 2]*e[l, 1]*p[k, 1]
# e[i, 2]*e[j, 2]*e[l, 1]*p[u, 1]
# -e[i, 2]*e[j, 2]*e[u, 1]*e[v, 1]
# e[i, 2]*e[j, 2]*e[u, 1]*p[l, 1]
# -e[i, 2]*e[j, 2]*e[u, 1]*p[v, 1]
# e[i, 2]*e[j, 2]*e[v, 1]*p[k, 1]
# -e[i, 2]*e[j, 2]*e[v, 1]*p[u, 1]
# -e[i, 2]*e[j, 2]*p[k, 1]*p[l, 1]
# e[i, 2]*e[j, 2]*p[k, 1]*p[v, 1]
# e[i, 2]*e[j, 2]*p[l, 1]*p[u, 1]
# -e[i, 2]*e[j, 2]*p[u, 1]*p[v, 1]
# e[i, 2]*e[k, 1]*e[l, 1]*e[v, 2]
# -e[i, 2]*e[k, 1]*e[l, 1]*p[j, 2]
# e[i, 2]*e[k, 1]*e[l, 1]*p[v, 2]
# -e[i, 2]*e[k, 1]*e[u, 2]*e[v, 1]
# e[i, 2]*e[k, 1]*e[u, 2]*p[j, 1]
# -e[i, 2]*e[k, 1]*e[u, 2]*p[v, 1]
# e[i, 2]*e[k, 1]*e[v, 1]*p[j, 2]
# -e[i, 2]*e[k, 1]*e[v, 1]*p[u, 2]
# -e[i, 2]*e[k, 1]*e[v, 2]*p[j, 1]
# e[i, 2]*e[k, 1]*e[v, 2]*p[l, 1]
# e[i, 2]*e[k, 1]*p[j, 1]*p[u, 2]
# -e[i, 2]*e[k, 1]*p[j, 1]*p[v, 2]
# -e[i, 2]*e[k, 1]*p[j, 2]*p[l, 1]
# e[i, 2]*e[k, 1]*p[j, 2]*p[v, 1]
# e[i, 2]*e[k, 1]*p[l, 1]*p[v, 2]
# -e[i, 2]*e[k, 1]*p[u, 2]*p[v, 1]
# -e[i, 2]*e[k, 2]*e[l, 1]*e[v, 1]
# e[i, 2]*e[k, 2]*e[l, 1]*p[j, 1]
# -e[i, 2]*e[k, 2]*e[l, 1]*p[v, 1]
# e[i, 2]*e[k, 2]*e[u, 1]*e[v, 1]
# -e[i, 2]*e[k, 2]*e[u, 1]*p[j, 1]
# e[i, 2]*e[k, 2]*e[u, 1]*p[v, 1]
# -e[i, 2]*e[k, 2]*e[v, 1]*p[l, 1]
# e[i, 2]*e[k, 2]*e[v, 1]*p[u, 1]
# e[i, 2]*e[k, 2]*p[j, 1]*p[l, 1]
# -e[i, 2]*e[k, 2]*p[j, 1]*p[u, 1]
# -e[i, 2]*e[k, 2]*p[l, 1]*p[v, 1]
# e[i, 2]*e[k, 2]*p[u, 1]*p[v, 1]
# -e[i, 2]*e[l, 1]*e[u, 1]*e[v, 2]
# e[i, 2]*e[l, 1]*e[u, 1]*p[j, 2]
# -e[i, 2]*e[l, 1]*e[u, 1]*p[v, 2]
# e[i, 2]*e[l, 1]*e[u, 2]*e[v, 1]
# -e[i, 2]*e[l, 1]*e[u, 2]*p[j, 1]
# e[i, 2]*e[l, 1]*e[u, 2]*p[v, 1]
# -e[i, 2]*e[l, 1]*e[v, 1]*p[k, 2]
# e[i, 2]*e[l, 1]*e[v, 1]*p[u, 2]
# e[i, 2]*e[l, 1]*e[v, 2]*p[k, 1]
# -e[i, 2]*e[l, 1]*e[v, 2]*p[u, 1]
# e[i, 2]*e[l, 1]*p[j, 1]*p[k, 2]
# -e[i, 2]*e[l, 1]*p[j, 1]*p[u, 2]
# -e[i, 2]*e[l, 1]*p[j, 2]*p[k, 1]
# e[i, 2]*e[l, 1]*p[j, 2]*p[u, 1]
# e[i, 2]*e[l, 1]*p[k, 1]*p[v, 2]
# -e[i, 2]*e[l, 1]*p[k, 2]*p[v, 1]
# -e[i, 2]*e[l, 1]*p[u, 1]*p[v, 2]
# e[i, 2]*e[l, 1]*p[u, 2]*p[v, 1]
# -e[i, 2]*e[u, 1]*e[v, 1]*p[j, 2]
# e[i, 2]*e[u, 1]*e[v, 1]*p[k, 2]
# e[i, 2]*e[u, 1]*e[v, 2]*p[j, 1]
# -e[i, 2]*e[u, 1]*e[v, 2]*p[l, 1]
# -e[i, 2]*e[u, 1]*p[j, 1]*p[k, 2]
# e[i, 2]*e[u, 1]*p[j, 1]*p[v, 2]
# e[i, 2]*e[u, 1]*p[j, 2]*p[l, 1]
# -e[i, 2]*e[u, 1]*p[j, 2]*p[v, 1]
# e[i, 2]*e[u, 1]*p[k, 2]*p[v, 1]
# -e[i, 2]*e[u, 1]*p[l, 1]*p[v, 2]
# -e[i, 2]*e[u, 2]*e[v, 1]*p[k, 1]
# e[i, 2]*e[u, 2]*e[v, 1]*p[l, 1]
# e[i, 2]*e[u, 2]*p[j, 1]*p[k, 1]
# -e[i, 2]*e[u, 2]*p[j, 1]*p[l, 1]
# -e[i, 2]*e[u, 2]*p[k, 1]*p[v, 1]
# e[i, 2]*e[u, 2]*p[l, 1]*p[v, 1]
# e[i, 2]*e[v, 1]*p[j, 2]*p[k, 1]
# -e[i, 2]*e[v, 1]*p[j, 2]*p[u, 1]
# -e[i, 2]*e[v, 1]*p[k, 1]*p[u, 2]
# -e[i, 2]*e[v, 1]*p[k, 2]*p[l, 1]
# e[i, 2]*e[v, 1]*p[k, 2]*p[u, 1]
# e[i, 2]*e[v, 1]*p[l, 1]*p[u, 2]
# -e[i, 2]*e[v, 2]*p[j, 1]*p[k, 1]
# e[i, 2]*e[v, 2]*p[j, 1]*p[u, 1]
# e[i, 2]*e[v, 2]*p[k, 1]*p[l, 1]
# -e[i, 2]*e[v, 2]*p[l, 1]*p[u, 1]
# e[i, 2]*p[j, 1]*p[k, 1]*p[u, 2]
# -e[i, 2]*p[j, 1]*p[k, 1]*p[v, 2]
# e[i, 2]*p[j, 1]*p[k, 2]*p[l, 1]
# -e[i, 2]*p[j, 1]*p[k, 2]*p[u, 1]
# -e[i, 2]*p[j, 1]*p[l, 1]*p[u, 2]
# e[i, 2]*p[j, 1]*p[u, 1]*p[v, 2]
# -e[i, 2]*p[j, 2]*p[k, 1]*p[l, 1]
# e[i, 2]*p[j, 2]*p[k, 1]*p[v, 1]
# e[i, 2]*p[j, 2]*p[l, 1]*p[u, 1]
# -e[i, 2]*p[j, 2]*p[u, 1]*p[v, 1]
# e[i, 2]*p[k, 1]*p[l, 1]*p[v, 2]
# -e[i, 2]*p[k, 1]*p[u, 2]*p[v, 1]
# -e[i, 2]*p[k, 2]*p[l, 1]*p[v, 1]
# e[i, 2]*p[k, 2]*p[u, 1]*p[v, 1]
# -e[i, 2]*p[l, 1]*p[u, 1]*p[v, 2]
# e[i, 2]*p[l, 1]*p[u, 2]*p[v, 1]
# -e[j, 1]*e[k, 1]*e[l, 2]*e[u, 2]
# e[j, 1]*e[k, 1]*e[l, 2]*e[v, 2]
# -e[j, 1]*e[k, 1]*e[l, 2]*p[u, 2]
# e[j, 1]*e[k, 1]*e[l, 2]*p[v, 2]
# e[j, 1]*e[k, 1]*e[u, 2]*p[i, 2]
# -e[j, 1]*e[k, 1]*e[u, 2]*p[l, 2]
# -e[j, 1]*e[k, 1]*e[v, 2]*p[i, 2]
# e[j, 1]*e[k, 1]*e[v, 2]*p[l, 2]
# e[j, 1]*e[k, 1]*p[i, 2]*p[u, 2]
# -e[j, 1]*e[k, 1]*p[i, 2]*p[v, 2]
# -e[j, 1]*e[k, 1]*p[l, 2]*p[u, 2]
# e[j, 1]*e[k, 1]*p[l, 2]*p[v, 2]
# -e[j, 1]*e[k, 2]*e[l, 1]*e[v, 2]
# e[j, 1]*e[k, 2]*e[l, 1]*p[i, 2]
# -e[j, 1]*e[k, 2]*e[l, 1]*p[v, 2]
# e[j, 1]*e[k, 2]*e[l, 2]*e[u, 1]
# -e[j, 1]*e[k, 2]*e[l, 2]*p[i, 1]
# e[j, 1]*e[k, 2]*e[l, 2]*p[u, 1]
# -e[j, 1]*e[k, 2]*e[u, 1]*p[i, 2]
# e[j, 1]*e[k, 2]*e[u, 1]*p[l, 2]
# e[j, 1]*e[k, 2]*e[v, 2]*p[i, 1]
# -e[j, 1]*e[k, 2]*e[v, 2]*p[l, 1]
# -e[j, 1]*e[k, 2]*p[i, 1]*p[l, 2]
# e[j, 1]*e[k, 2]*p[i, 1]*p[v, 2]
# e[j, 1]*e[k, 2]*p[i, 2]*p[l, 1]
# -e[j, 1]*e[k, 2]*p[i, 2]*p[u, 1]
# -e[j, 1]*e[k, 2]*p[l, 1]*p[v, 2]
# e[j, 1]*e[k, 2]*p[l, 2]*p[u, 1]
# e[j, 1]*e[l, 1]*e[u, 2]*e[v, 2]
# -e[j, 1]*e[l, 1]*e[u, 2]*p[i, 2]
# e[j, 1]*e[l, 1]*e[u, 2]*p[v, 2]
# -e[j, 1]*e[l, 1]*e[v, 2]*p[k, 2]
# e[j, 1]*e[l, 1]*e[v, 2]*p[u, 2]
# e[j, 1]*e[l, 1]*p[i, 2]*p[k, 2]
# -e[j, 1]*e[l, 1]*p[i, 2]*p[u, 2]
# -e[j, 1]*e[l, 1]*p[k, 2]*p[v, 2]
# e[j, 1]*e[l, 1]*p[u, 2]*p[v, 2]
# -e[j, 1]*e[l, 2]*e[u, 1]*e[v, 2]
# e[j, 1]*e[l, 2]*e[u, 1]*p[k, 2]
# -e[j, 1]*e[l, 2]*e[u, 1]*p[v, 2]
# e[j, 1]*e[l, 2]*e[u, 2]*p[i, 1]
# -e[j, 1]*e[l, 2]*e[u, 2]*p[k, 1]
# e[j, 1]*e[l, 2]*e[v, 2]*p[k, 1]
# -e[j, 1]*e[l, 2]*e[v, 2]*p[u, 1]
# -e[j, 1]*e[l, 2]*p[i, 1]*p[k, 2]
# e[j, 1]*e[l, 2]*p[i, 1]*p[u, 2]
# -e[j, 1]*e[l, 2]*p[k, 1]*p[u, 2]
# e[j, 1]*e[l, 2]*p[k, 1]*p[v, 2]
# e[j, 1]*e[l, 2]*p[k, 2]*p[u, 1]
# -e[j, 1]*e[l, 2]*p[u, 1]*p[v, 2]
# e[j, 1]*e[u, 1]*e[v, 2]*p[i, 2]
# -e[j, 1]*e[u, 1]*e[v, 2]*p[l, 2]
# -e[j, 1]*e[u, 1]*p[i, 2]*p[k, 2]
# e[j, 1]*e[u, 1]*p[i, 2]*p[v, 2]
# e[j, 1]*e[u, 1]*p[k, 2]*p[l, 2]
# -e[j, 1]*e[u, 1]*p[l, 2]*p[v, 2]
# -e[j, 1]*e[u, 2]*e[v, 2]*p[i, 1]
# e[j, 1]*e[u, 2]*e[v, 2]*p[l, 1]
# e[j, 1]*e[u, 2]*p[i, 1]*p[l, 2]
# -e[j, 1]*e[u, 2]*p[i, 1]*p[v, 2]
# e[j, 1]*e[u, 2]*p[i, 2]*p[k, 1]
# -e[j, 1]*e[u, 2]*p[i, 2]*p[l, 1]
# -e[j, 1]*e[u, 2]*p[k, 1]*p[l, 2]
# e[j, 1]*e[u, 2]*p[l, 1]*p[v, 2]
# e[j, 1]*e[v, 2]*p[i, 1]*p[k, 2]
# -e[j, 1]*e[v, 2]*p[i, 1]*p[u, 2]
# -e[j, 1]*e[v, 2]*p[i, 2]*p[k, 1]
# e[j, 1]*e[v, 2]*p[i, 2]*p[u, 1]
# e[j, 1]*e[v, 2]*p[k, 1]*p[l, 2]
# -e[j, 1]*e[v, 2]*p[k, 2]*p[l, 1]
# e[j, 1]*e[v, 2]*p[l, 1]*p[u, 2]
# -e[j, 1]*e[v, 2]*p[l, 2]*p[u, 1]
# -e[j, 1]*p[i, 1]*p[k, 2]*p[l, 2]
# e[j, 1]*p[i, 1]*p[k, 2]*p[v, 2]
# e[j, 1]*p[i, 1]*p[l, 2]*p[u, 2]
# -e[j, 1]*p[i, 1]*p[u, 2]*p[v, 2]
# e[j, 1]*p[i, 2]*p[k, 1]*p[u, 2]
# -e[j, 1]*p[i, 2]*p[k, 1]*p[v, 2]
# e[j, 1]*p[i, 2]*p[k, 2]*p[l, 1]
# -e[j, 1]*p[i, 2]*p[k, 2]*p[u, 1]
# -e[j, 1]*p[i, 2]*p[l, 1]*p[u, 2]
# e[j, 1]*p[i, 2]*p[u, 1]*p[v, 2]
# -e[j, 1]*p[k, 1]*p[l, 2]*p[u, 2]
# e[j, 1]*p[k, 1]*p[l, 2]*p[v, 2]
# -e[j, 1]*p[k, 2]*p[l, 1]*p[v, 2]
# e[j, 1]*p[k, 2]*p[l, 2]*p[u, 1]
# e[j, 1]*p[l, 1]*p[u, 2]*p[v, 2]
# -e[j, 1]*p[l, 2]*p[u, 1]*p[v, 2]
# e[j, 2]*e[k, 1]*e[l, 1]*e[u, 2]
# -e[j, 2]*e[k, 1]*e[l, 1]*p[i, 2]
# e[j, 2]*e[k, 1]*e[l, 1]*p[u, 2]
# -e[j, 2]*e[k, 1]*e[l, 2]*e[v, 1]
# e[j, 2]*e[k, 1]*e[l, 2]*p[i, 1]
# -e[j, 2]*e[k, 1]*e[l, 2]*p[v, 1]
# -e[j, 2]*e[k, 1]*e[u, 2]*p[i, 1]
# e[j, 2]*e[k, 1]*e[u, 2]*p[l, 1]
# e[j, 2]*e[k, 1]*e[v, 1]*p[i, 2]
# -e[j, 2]*e[k, 1]*e[v, 1]*p[l, 2]
# e[j, 2]*e[k, 1]*p[i, 1]*p[l, 2]
# -e[j, 2]*e[k, 1]*p[i, 1]*p[u, 2]
# -e[j, 2]*e[k, 1]*p[i, 2]*p[l, 1]
# e[j, 2]*e[k, 1]*p[i, 2]*p[v, 1]
# e[j, 2]*e[k, 1]*p[l, 1]*p[u, 2]
# -e[j, 2]*e[k, 1]*p[l, 2]*p[v, 1]
# -e[j, 2]*e[k, 2]*e[l, 1]*e[u, 1]
# e[j, 2]*e[k, 2]*e[l, 1]*e[v, 1]
# -e[j, 2]*e[k, 2]*e[l, 1]*p[u, 1]
# e[j, 2]*e[k, 2]*e[l, 1]*p[v, 1]
# e[j, 2]*e[k, 2]*e[u, 1]*p[i, 1]
# -e[j, 2]*e[k, 2]*e[u, 1]*p[l, 1]
# -e[j, 2]*e[k, 2]*e[v, 1]*p[i, 1]
# e[j, 2]*e[k, 2]*e[v, 1]*p[l, 1]
# e[j, 2]*e[k, 2]*p[i, 1]*p[u, 1]
# -e[j, 2]*e[k, 2]*p[i, 1]*p[v, 1]
# -e[j, 2]*e[k, 2]*p[l, 1]*p[u, 1]
# e[j, 2]*e[k, 2]*p[l, 1]*p[v, 1]
# e[j, 2]*e[l, 1]*e[u, 1]*p[i, 2]
# -e[j, 2]*e[l, 1]*e[u, 1]*p[k, 2]
# -e[j, 2]*e[l, 1]*e[u, 2]*e[v, 1]
# e[j, 2]*e[l, 1]*e[u, 2]*p[k, 1]
# -e[j, 2]*e[l, 1]*e[u, 2]*p[v, 1]
# e[j, 2]*e[l, 1]*e[v, 1]*p[k, 2]
# -e[j, 2]*e[l, 1]*e[v, 1]*p[u, 2]
# -e[j, 2]*e[l, 1]*p[i, 2]*p[k, 1]
# e[j, 2]*e[l, 1]*p[i, 2]*p[u, 1]
# e[j, 2]*e[l, 1]*p[k, 1]*p[u, 2]
# -e[j, 2]*e[l, 1]*p[k, 2]*p[u, 1]
# e[j, 2]*e[l, 1]*p[k, 2]*p[v, 1]
# -e[j, 2]*e[l, 1]*p[u, 2]*p[v, 1]
# e[j, 2]*e[l, 2]*e[u, 1]*e[v, 1]
# -e[j, 2]*e[l, 2]*e[u, 1]*p[i, 1]
# e[j, 2]*e[l, 2]*e[u, 1]*p[v, 1]
# -e[j, 2]*e[l, 2]*e[v, 1]*p[k, 1]
# e[j, 2]*e[l, 2]*e[v, 1]*p[u, 1]
# e[j, 2]*e[l, 2]*p[i, 1]*p[k, 1]
# -e[j, 2]*e[l, 2]*p[i, 1]*p[u, 1]
# -e[j, 2]*e[l, 2]*p[k, 1]*p[v, 1]
# e[j, 2]*e[l, 2]*p[u, 1]*p[v, 1]
# -e[j, 2]*e[u, 1]*e[v, 1]*p[i, 2]
# e[j, 2]*e[u, 1]*e[v, 1]*p[l, 2]
# e[j, 2]*e[u, 1]*p[i, 1]*p[k, 2]
# -e[j, 2]*e[u, 1]*p[i, 1]*p[l, 2]
# e[j, 2]*e[u, 1]*p[i, 2]*p[l, 1]
# -e[j, 2]*e[u, 1]*p[i, 2]*p[v, 1]
# -e[j, 2]*e[u, 1]*p[k, 2]*p[l, 1]
# e[j, 2]*e[u, 1]*p[l, 2]*p[v, 1]
# e[j, 2]*e[u, 2]*e[v, 1]*p[i, 1]
# -e[j, 2]*e[u, 2]*e[v, 1]*p[l, 1]
# -e[j, 2]*e[u, 2]*p[i, 1]*p[k, 1]
# e[j, 2]*e[u, 2]*p[i, 1]*p[v, 1]
# e[j, 2]*e[u, 2]*p[k, 1]*p[l, 1]
# -e[j, 2]*e[u, 2]*p[l, 1]*p[v, 1]
# -e[j, 2]*e[v, 1]*p[i, 1]*p[k, 2]
# e[j, 2]*e[v, 1]*p[i, 1]*p[u, 2]
# e[j, 2]*e[v, 1]*p[i, 2]*p[k, 1]
# -e[j, 2]*e[v, 1]*p[i, 2]*p[u, 1]
# -e[j, 2]*e[v, 1]*p[k, 1]*p[l, 2]
# e[j, 2]*e[v, 1]*p[k, 2]*p[l, 1]
# -e[j, 2]*e[v, 1]*p[l, 1]*p[u, 2]
# e[j, 2]*e[v, 1]*p[l, 2]*p[u, 1]
# e[j, 2]*p[i, 1]*p[k, 1]*p[l, 2]
# -e[j, 2]*p[i, 1]*p[k, 1]*p[u, 2]
# e[j, 2]*p[i, 1]*p[k, 2]*p[u, 1]
# -e[j, 2]*p[i, 1]*p[k, 2]*p[v, 1]
# -e[j, 2]*p[i, 1]*p[l, 2]*p[u, 1]
# e[j, 2]*p[i, 1]*p[u, 2]*p[v, 1]
# -e[j, 2]*p[i, 2]*p[k, 1]*p[l, 1]
# e[j, 2]*p[i, 2]*p[k, 1]*p[v, 1]
# e[j, 2]*p[i, 2]*p[l, 1]*p[u, 1]
# -e[j, 2]*p[i, 2]*p[u, 1]*p[v, 1]
# e[j, 2]*p[k, 1]*p[l, 1]*p[u, 2]
# -e[j, 2]*p[k, 1]*p[l, 2]*p[v, 1]
# -e[j, 2]*p[k, 2]*p[l, 1]*p[u, 1]
# e[j, 2]*p[k, 2]*p[l, 1]*p[v, 1]
# -e[j, 2]*p[l, 1]*p[u, 2]*p[v, 1]
# e[j, 2]*p[l, 2]*p[u, 1]*p[v, 1]
# -e[k, 1]*e[l, 1]*e[u, 2]*e[v, 2]
# e[k, 1]*e[l, 1]*e[u, 2]*p[j, 2]
# -e[k, 1]*e[l, 1]*e[u, 2]*p[v, 2]
# e[k, 1]*e[l, 1]*e[v, 2]*p[i, 2]
# -e[k, 1]*e[l, 1]*e[v, 2]*p[u, 2]
# -e[k, 1]*e[l, 1]*p[i, 2]*p[j, 2]
# e[k, 1]*e[l, 1]*p[i, 2]*p[v, 2]
# e[k, 1]*e[l, 1]*p[j, 2]*p[u, 2]
# -e[k, 1]*e[l, 1]*p[u, 2]*p[v, 2]
# e[k, 1]*e[l, 2]*e[u, 2]*e[v, 1]
# -e[k, 1]*e[l, 2]*e[u, 2]*p[j, 1]
# e[k, 1]*e[l, 2]*e[u, 2]*p[v, 1]
# -e[k, 1]*e[l, 2]*e[v, 1]*p[j, 2]
# e[k, 1]*e[l, 2]*e[v, 1]*p[u, 2]
# -e[k, 1]*e[l, 2]*e[v, 2]*p[i, 1]
# e[k, 1]*e[l, 2]*e[v, 2]*p[j, 1]
# e[k, 1]*e[l, 2]*p[i, 1]*p[j, 2]
# -e[k, 1]*e[l, 2]*p[i, 1]*p[v, 2]
# -e[k, 1]*e[l, 2]*p[j, 1]*p[u, 2]
# e[k, 1]*e[l, 2]*p[j, 1]*p[v, 2]
# -e[k, 1]*e[l, 2]*p[j, 2]*p[v, 1]
# e[k, 1]*e[l, 2]*p[u, 2]*p[v, 1]
# -e[k, 1]*e[u, 2]*e[v, 1]*p[i, 2]
# e[k, 1]*e[u, 2]*e[v, 1]*p[l, 2]
# e[k, 1]*e[u, 2]*e[v, 2]*p[i, 1]
# -e[k, 1]*e[u, 2]*e[v, 2]*p[l, 1]
# -e[k, 1]*e[u, 2]*p[i, 1]*p[j, 2]
# e[k, 1]*e[u, 2]*p[i, 1]*p[v, 2]
# e[k, 1]*e[u, 2]*p[i, 2]*p[j, 1]
# -e[k, 1]*e[u, 2]*p[i, 2]*p[v, 1]
# -e[k, 1]*e[u, 2]*p[j, 1]*p[l, 2]
# e[k, 1]*e[u, 2]*p[j, 2]*p[l, 1]
# -e[k, 1]*e[u, 2]*p[l, 1]*p[v, 2]
# e[k, 1]*e[u, 2]*p[l, 2]*p[v, 1]
# e[k, 1]*e[v, 1]*p[i, 2]*p[j, 2]
# -e[k, 1]*e[v, 1]*p[i, 2]*p[u, 2]
# -e[k, 1]*e[v, 1]*p[j, 2]*p[l, 2]
# e[k, 1]*e[v, 1]*p[l, 2]*p[u, 2]
# -e[k, 1]*e[v, 2]*p[i, 1]*p[l, 2]
# e[k, 1]*e[v, 2]*p[i, 1]*p[u, 2]
# -e[k, 1]*e[v, 2]*p[i, 2]*p[j, 1]
# e[k, 1]*e[v, 2]*p[i, 2]*p[l, 1]
# e[k, 1]*e[v, 2]*p[j, 1]*p[l, 2]
# -e[k, 1]*e[v, 2]*p[l, 1]*p[u, 2]
# e[k, 1]*p[i, 1]*p[j, 2]*p[l, 2]
# -e[k, 1]*p[i, 1]*p[j, 2]*p[u, 2]
# -e[k, 1]*p[i, 1]*p[l, 2]*p[v, 2]
# e[k, 1]*p[i, 1]*p[u, 2]*p[v, 2]
# e[k, 1]*p[i, 2]*p[j, 1]*p[u, 2]
# -e[k, 1]*p[i, 2]*p[j, 1]*p[v, 2]
# -e[k, 1]*p[i, 2]*p[j, 2]*p[l, 1]
# e[k, 1]*p[i, 2]*p[j, 2]*p[v, 1]
# e[k, 1]*p[i, 2]*p[l, 1]*p[v, 2]
# -e[k, 1]*p[i, 2]*p[u, 2]*p[v, 1]
# -e[k, 1]*p[j, 1]*p[l, 2]*p[u, 2]
# e[k, 1]*p[j, 1]*p[l, 2]*p[v, 2]
# e[k, 1]*p[j, 2]*p[l, 1]*p[u, 2]
# -e[k, 1]*p[j, 2]*p[l, 2]*p[v, 1]
# -e[k, 1]*p[l, 1]*p[u, 2]*p[v, 2]
# e[k, 1]*p[l, 2]*p[u, 2]*p[v, 1]
# e[k, 2]*e[l, 1]*e[u, 1]*e[v, 2]
# -e[k, 2]*e[l, 1]*e[u, 1]*p[j, 2]
# e[k, 2]*e[l, 1]*e[u, 1]*p[v, 2]
# -e[k, 2]*e[l, 1]*e[v, 1]*p[i, 2]
# e[k, 2]*e[l, 1]*e[v, 1]*p[j, 2]
# -e[k, 2]*e[l, 1]*e[v, 2]*p[j, 1]
# e[k, 2]*e[l, 1]*e[v, 2]*p[u, 1]
# e[k, 2]*e[l, 1]*p[i, 2]*p[j, 1]
# -e[k, 2]*e[l, 1]*p[i, 2]*p[v, 1]
# -e[k, 2]*e[l, 1]*p[j, 1]*p[v, 2]
# -e[k, 2]*e[l, 1]*p[j, 2]*p[u, 1]
# e[k, 2]*e[l, 1]*p[j, 2]*p[v, 1]
# e[k, 2]*e[l, 1]*p[u, 1]*p[v, 2]
# -e[k, 2]*e[l, 2]*e[u, 1]*e[v, 1]
# e[k, 2]*e[l, 2]*e[u, 1]*p[j, 1]
# -e[k, 2]*e[l, 2]*e[u, 1]*p[v, 1]
# e[k, 2]*e[l, 2]*e[v, 1]*p[i, 1]
# -e[k, 2]*e[l, 2]*e[v, 1]*p[u, 1]
# -e[k, 2]*e[l, 2]*p[i, 1]*p[j, 1]
# e[k, 2]*e[l, 2]*p[i, 1]*p[v, 1]
# e[k, 2]*e[l, 2]*p[j, 1]*p[u, 1]
# -e[k, 2]*e[l, 2]*p[u, 1]*p[v, 1]
# e[k, 2]*e[u, 1]*e[v, 1]*p[i, 2]
# -e[k, 2]*e[u, 1]*e[v, 1]*p[l, 2]
# -e[k, 2]*e[u, 1]*e[v, 2]*p[i, 1]
# e[k, 2]*e[u, 1]*e[v, 2]*p[l, 1]
# e[k, 2]*e[u, 1]*p[i, 1]*p[j, 2]
# -e[k, 2]*e[u, 1]*p[i, 1]*p[v, 2]
# -e[k, 2]*e[u, 1]*p[i, 2]*p[j, 1]
# e[k, 2]*e[u, 1]*p[i, 2]*p[v, 1]
# e[k, 2]*e[u, 1]*p[j, 1]*p[l, 2]
# -e[k, 2]*e[u, 1]*p[j, 2]*p[l, 1]
# e[k, 2]*e[u, 1]*p[l, 1]*p[v, 2]
# -e[k, 2]*e[u, 1]*p[l, 2]*p[v, 1]
# -e[k, 2]*e[v, 1]*p[i, 1]*p[j, 2]
# e[k, 2]*e[v, 1]*p[i, 1]*p[l, 2]
# -e[k, 2]*e[v, 1]*p[i, 2]*p[l, 1]
# e[k, 2]*e[v, 1]*p[i, 2]*p[u, 1]
# e[k, 2]*e[v, 1]*p[j, 2]*p[l, 1]
# -e[k, 2]*e[v, 1]*p[l, 2]*p[u, 1]
# e[k, 2]*e[v, 2]*p[i, 1]*p[j, 1]
# -e[k, 2]*e[v, 2]*p[i, 1]*p[u, 1]
# -e[k, 2]*e[v, 2]*p[j, 1]*p[l, 1]
# e[k, 2]*e[v, 2]*p[l, 1]*p[u, 1]
# -e[k, 2]*p[i, 1]*p[j, 1]*p[l, 2]
# e[k, 2]*p[i, 1]*p[j, 1]*p[v, 2]
# e[k, 2]*p[i, 1]*p[j, 2]*p[u, 1]
# -e[k, 2]*p[i, 1]*p[j, 2]*p[v, 1]
# e[k, 2]*p[i, 1]*p[l, 2]*p[v, 1]
# -e[k, 2]*p[i, 1]*p[u, 1]*p[v, 2]
# e[k, 2]*p[i, 2]*p[j, 1]*p[l, 1]
# -e[k, 2]*p[i, 2]*p[j, 1]*p[u, 1]
# -e[k, 2]*p[i, 2]*p[l, 1]*p[v, 1]
# e[k, 2]*p[i, 2]*p[u, 1]*p[v, 1]
# -e[k, 2]*p[j, 1]*p[l, 1]*p[v, 2]
# e[k, 2]*p[j, 1]*p[l, 2]*p[u, 1]
# -e[k, 2]*p[j, 2]*p[l, 1]*p[u, 1]
# e[k, 2]*p[j, 2]*p[l, 1]*p[v, 1]
# e[k, 2]*p[l, 1]*p[u, 1]*p[v, 2]
# -e[k, 2]*p[l, 2]*p[u, 1]*p[v, 1]
# -e[l, 1]*e[u, 1]*e[v, 2]*p[i, 2]
# e[l, 1]*e[u, 1]*e[v, 2]*p[k, 2]
# e[l, 1]*e[u, 1]*p[i, 2]*p[j, 2]
# -e[l, 1]*e[u, 1]*p[i, 2]*p[v, 2]
# -e[l, 1]*e[u, 1]*p[j, 2]*p[k, 2]
# e[l, 1]*e[u, 1]*p[k, 2]*p[v, 2]
# e[l, 1]*e[u, 2]*e[v, 1]*p[i, 2]
# -e[l, 1]*e[u, 2]*e[v, 1]*p[j, 2]
# e[l, 1]*e[u, 2]*e[v, 2]*p[j, 1]
# -e[l, 1]*e[u, 2]*e[v, 2]*p[k, 1]
# -e[l, 1]*e[u, 2]*p[i, 2]*p[j, 1]
# e[l, 1]*e[u, 2]*p[i, 2]*p[v, 1]
# e[l, 1]*e[u, 2]*p[j, 1]*p[v, 2]
# e[l, 1]*e[u, 2]*p[j, 2]*p[k, 1]
# -e[l, 1]*e[u, 2]*p[j, 2]*p[v, 1]
# -e[l, 1]*e[u, 2]*p[k, 1]*p[v, 2]
# -e[l, 1]*e[v, 1]*p[i, 2]*p[k, 2]
# e[l, 1]*e[v, 1]*p[i, 2]*p[u, 2]
# e[l, 1]*e[v, 1]*p[j, 2]*p[k, 2]
# -e[l, 1]*e[v, 1]*p[j, 2]*p[u, 2]
# e[l, 1]*e[v, 2]*p[i, 2]*p[k, 1]
# -e[l, 1]*e[v, 2]*p[i, 2]*p[u, 1]
# -e[l, 1]*e[v, 2]*p[j, 1]*p[k, 2]
# e[l, 1]*e[v, 2]*p[j, 1]*p[u, 2]
# -e[l, 1]*e[v, 2]*p[k, 1]*p[u, 2]
# e[l, 1]*e[v, 2]*p[k, 2]*p[u, 1]
# e[l, 1]*p[i, 2]*p[j, 1]*p[k, 2]
# -e[l, 1]*p[i, 2]*p[j, 1]*p[u, 2]
# -e[l, 1]*p[i, 2]*p[j, 2]*p[k, 1]
# e[l, 1]*p[i, 2]*p[j, 2]*p[u, 1]
# e[l, 1]*p[i, 2]*p[k, 1]*p[v, 2]
# -e[l, 1]*p[i, 2]*p[k, 2]*p[v, 1]
# -e[l, 1]*p[i, 2]*p[u, 1]*p[v, 2]
# e[l, 1]*p[i, 2]*p[u, 2]*p[v, 1]
# -e[l, 1]*p[j, 1]*p[k, 2]*p[v, 2]
# e[l, 1]*p[j, 1]*p[u, 2]*p[v, 2]
# e[l, 1]*p[j, 2]*p[k, 1]*p[u, 2]
# -e[l, 1]*p[j, 2]*p[k, 2]*p[u, 1]
# e[l, 1]*p[j, 2]*p[k, 2]*p[v, 1]
# -e[l, 1]*p[j, 2]*p[u, 2]*p[v, 1]
# -e[l, 1]*p[k, 1]*p[u, 2]*p[v, 2]
# e[l, 1]*p[k, 2]*p[u, 1]*p[v, 2]
# e[l, 2]*e[u, 1]*e[v, 1]*p[j, 2]
# -e[l, 2]*e[u, 1]*e[v, 1]*p[k, 2]
# e[l, 2]*e[u, 1]*e[v, 2]*p[i, 1]
# -e[l, 2]*e[u, 1]*e[v, 2]*p[j, 1]
# -e[l, 2]*e[u, 1]*p[i, 1]*p[j, 2]
# e[l, 2]*e[u, 1]*p[i, 1]*p[v, 2]
# e[l, 2]*e[u, 1]*p[j, 1]*p[k, 2]
# -e[l, 2]*e[u, 1]*p[j, 1]*p[v, 2]
# e[l, 2]*e[u, 1]*p[j, 2]*p[v, 1]
# -e[l, 2]*e[u, 1]*p[k, 2]*p[v, 1]
# -e[l, 2]*e[u, 2]*e[v, 1]*p[i, 1]
# e[l, 2]*e[u, 2]*e[v, 1]*p[k, 1]
# e[l, 2]*e[u, 2]*p[i, 1]*p[j, 1]
# -e[l, 2]*e[u, 2]*p[i, 1]*p[v, 1]
# -e[l, 2]*e[u, 2]*p[j, 1]*p[k, 1]
# e[l, 2]*e[u, 2]*p[k, 1]*p[v, 1]
# e[l, 2]*e[v, 1]*p[i, 1]*p[k, 2]
# -e[l, 2]*e[v, 1]*p[i, 1]*p[u, 2]
# -e[l, 2]*e[v, 1]*p[j, 2]*p[k, 1]
# e[l, 2]*e[v, 1]*p[j, 2]*p[u, 1]
# e[l, 2]*e[v, 1]*p[k, 1]*p[u, 2]
# -e[l, 2]*e[v, 1]*p[k, 2]*p[u, 1]
# -e[l, 2]*e[v, 2]*p[i, 1]*p[k, 1]
# e[l, 2]*e[v, 2]*p[i, 1]*p[u, 1]
# e[l, 2]*e[v, 2]*p[j, 1]*p[k, 1]
# -e[l, 2]*e[v, 2]*p[j, 1]*p[u, 1]
# -e[l, 2]*p[i, 1]*p[j, 1]*p[k, 2]
# e[l, 2]*p[i, 1]*p[j, 1]*p[u, 2]
# e[l, 2]*p[i, 1]*p[j, 2]*p[k, 1]
# -e[l, 2]*p[i, 1]*p[j, 2]*p[u, 1]
# -e[l, 2]*p[i, 1]*p[k, 1]*p[v, 2]
# e[l, 2]*p[i, 1]*p[k, 2]*p[v, 1]
# e[l, 2]*p[i, 1]*p[u, 1]*p[v, 2]
# -e[l, 2]*p[i, 1]*p[u, 2]*p[v, 1]
# -e[l, 2]*p[j, 1]*p[k, 1]*p[u, 2]
# e[l, 2]*p[j, 1]*p[k, 1]*p[v, 2]
# e[l, 2]*p[j, 1]*p[k, 2]*p[u, 1]
# -e[l, 2]*p[j, 1]*p[u, 1]*p[v, 2]
# -e[l, 2]*p[j, 2]*p[k, 1]*p[v, 1]
# e[l, 2]*p[j, 2]*p[u, 1]*p[v, 1]
# e[l, 2]*p[k, 1]*p[u, 2]*p[v, 1]
# -e[l, 2]*p[k, 2]*p[u, 1]*p[v, 1]
# -e[u, 1]*e[v, 1]*p[i, 2]*p[j, 2]
# e[u, 1]*e[v, 1]*p[i, 2]*p[k, 2]
# e[u, 1]*e[v, 1]*p[j, 2]*p[l, 2]
# -e[u, 1]*e[v, 1]*p[k, 2]*p[l, 2]
# -e[u, 1]*e[v, 2]*p[i, 1]*p[k, 2]
# e[u, 1]*e[v, 2]*p[i, 1]*p[l, 2]
# e[u, 1]*e[v, 2]*p[i, 2]*p[j, 1]
# -e[u, 1]*e[v, 2]*p[i, 2]*p[l, 1]
# -e[u, 1]*e[v, 2]*p[j, 1]*p[l, 2]
# e[u, 1]*e[v, 2]*p[k, 2]*p[l, 1]
# e[u, 1]*p[i, 1]*p[j, 2]*p[k, 2]
# -e[u, 1]*p[i, 1]*p[j, 2]*p[l, 2]
# -e[u, 1]*p[i, 1]*p[k, 2]*p[v, 2]
# e[u, 1]*p[i, 1]*p[l, 2]*p[v, 2]
# -e[u, 1]*p[i, 2]*p[j, 1]*p[k, 2]
# e[u, 1]*p[i, 2]*p[j, 1]*p[v, 2]
# e[u, 1]*p[i, 2]*p[j, 2]*p[l, 1]
# -e[u, 1]*p[i, 2]*p[j, 2]*p[v, 1]
# e[u, 1]*p[i, 2]*p[k, 2]*p[v, 1]
# -e[u, 1]*p[i, 2]*p[l, 1]*p[v, 2]
# e[u, 1]*p[j, 1]*p[k, 2]*p[l, 2]
# -e[u, 1]*p[j, 1]*p[l, 2]*p[v, 2]
# -e[u, 1]*p[j, 2]*p[k, 2]*p[l, 1]
# e[u, 1]*p[j, 2]*p[l, 2]*p[v, 1]
# e[u, 1]*p[k, 2]*p[l, 1]*p[v, 2]
# -e[u, 1]*p[k, 2]*p[l, 2]*p[v, 1]
# e[u, 2]*e[v, 1]*p[i, 1]*p[j, 2]
# -e[u, 2]*e[v, 1]*p[i, 1]*p[l, 2]
# -e[u, 2]*e[v, 1]*p[i, 2]*p[k, 1]
# e[u, 2]*e[v, 1]*p[i, 2]*p[l, 1]
# -e[u, 2]*e[v, 1]*p[j, 2]*p[l, 1]
# e[u, 2]*e[v, 1]*p[k, 1]*p[l, 2]
# -e[u, 2]*e[v, 2]*p[i, 1]*p[j, 1]
# e[u, 2]*e[v, 2]*p[i, 1]*p[k, 1]
# e[u, 2]*e[v, 2]*p[j, 1]*p[l, 1]
# -e[u, 2]*e[v, 2]*p[k, 1]*p[l, 1]
# e[u, 2]*p[i, 1]*p[j, 1]*p[l, 2]
# -e[u, 2]*p[i, 1]*p[j, 1]*p[v, 2]
# -e[u, 2]*p[i, 1]*p[j, 2]*p[k, 1]
# e[u, 2]*p[i, 1]*p[j, 2]*p[v, 1]
# e[u, 2]*p[i, 1]*p[k, 1]*p[v, 2]
# -e[u, 2]*p[i, 1]*p[l, 2]*p[v, 1]
# e[u, 2]*p[i, 2]*p[j, 1]*p[k, 1]
# -e[u, 2]*p[i, 2]*p[j, 1]*p[l, 1]
# -e[u, 2]*p[i, 2]*p[k, 1]*p[v, 1]
# e[u, 2]*p[i, 2]*p[l, 1]*p[v, 1]
# -e[u, 2]*p[j, 1]*p[k, 1]*p[l, 2]
# e[u, 2]*p[j, 1]*p[l, 1]*p[v, 2]
# e[u, 2]*p[j, 2]*p[k, 1]*p[l, 1]
# -e[u, 2]*p[j, 2]*p[l, 1]*p[v, 1]
# -e[u, 2]*p[k, 1]*p[l, 1]*p[v, 2]
# e[u, 2]*p[k, 1]*p[l, 2]*p[v, 1]
# -e[v, 1]*p[i, 1]*p[j, 2]*p[k, 2]
# e[v, 1]*p[i, 1]*p[j, 2]*p[u, 2]
# e[v, 1]*p[i, 1]*p[k, 2]*p[l, 2]
# -e[v, 1]*p[i, 1]*p[l, 2]*p[u, 2]
# e[v, 1]*p[i, 2]*p[j, 2]*p[k, 1]
# -e[v, 1]*p[i, 2]*p[j, 2]*p[u, 1]
# -e[v, 1]*p[i, 2]*p[k, 1]*p[u, 2]
# -e[v, 1]*p[i, 2]*p[k, 2]*p[l, 1]
# e[v, 1]*p[i, 2]*p[k, 2]*p[u, 1]
# e[v, 1]*p[i, 2]*p[l, 1]*p[u, 2]
# -e[v, 1]*p[j, 2]*p[k, 1]*p[l, 2]
# e[v, 1]*p[j, 2]*p[k, 2]*p[l, 1]
# -e[v, 1]*p[j, 2]*p[l, 1]*p[u, 2]
# e[v, 1]*p[j, 2]*p[l, 2]*p[u, 1]
# e[v, 1]*p[k, 1]*p[l, 2]*p[u, 2]
# -e[v, 1]*p[k, 2]*p[l, 2]*p[u, 1]
# e[v, 2]*p[i, 1]*p[j, 1]*p[k, 2]
# -e[v, 2]*p[i, 1]*p[j, 1]*p[u, 2]
# -e[v, 2]*p[i, 1]*p[k, 1]*p[l, 2]
# e[v, 2]*p[i, 1]*p[k, 1]*p[u, 2]
# -e[v, 2]*p[i, 1]*p[k, 2]*p[u, 1]
# e[v, 2]*p[i, 1]*p[l, 2]*p[u, 1]
# -e[v, 2]*p[i, 2]*p[j, 1]*p[k, 1]
# e[v, 2]*p[i, 2]*p[j, 1]*p[u, 1]
# e[v, 2]*p[i, 2]*p[k, 1]*p[l, 1]
# -e[v, 2]*p[i, 2]*p[l, 1]*p[u, 1]
# e[v, 2]*p[j, 1]*p[k, 1]*p[l, 2]
# -e[v, 2]*p[j, 1]*p[k, 2]*p[l, 1]
# e[v, 2]*p[j, 1]*p[l, 1]*p[u, 2]
# -e[v, 2]*p[j, 1]*p[l, 2]*p[u, 1]
# -e[v, 2]*p[k, 1]*p[l, 1]*p[u, 2]
# e[v, 2]*p[k, 2]*p[l, 1]*p[u, 1]
# -p[i, 1]*p[j, 1]*p[k, 2]*p[l, 2]
# p[i, 1]*p[j, 1]*p[k, 2]*p[v, 2]
# p[i, 1]*p[j, 1]*p[l, 2]*p[u, 2]
# -p[i, 1]*p[j, 1]*p[u, 2]*p[v, 2]
# p[i, 1]*p[j, 2]*p[k, 1]*p[l, 2]
# -p[i, 1]*p[j, 2]*p[k, 1]*p[u, 2]
# p[i, 1]*p[j, 2]*p[k, 2]*p[u, 1]
# -p[i, 1]*p[j, 2]*p[k, 2]*p[v, 1]
# -p[i, 1]*p[j, 2]*p[l, 2]*p[u, 1]
# p[i, 1]*p[j, 2]*p[u, 2]*p[v, 1]
# -p[i, 1]*p[k, 1]*p[l, 2]*p[v, 2]
# p[i, 1]*p[k, 1]*p[u, 2]*p[v, 2]
# p[i, 1]*p[k, 2]*p[l, 2]*p[v, 1]
# -p[i, 1]*p[k, 2]*p[u, 1]*p[v, 2]
# p[i, 1]*p[l, 2]*p[u, 1]*p[v, 2]
# -p[i, 1]*p[l, 2]*p[u, 2]*p[v, 1]
# p[i, 2]*p[j, 1]*p[k, 1]*p[u, 2]
# -p[i, 2]*p[j, 1]*p[k, 1]*p[v, 2]
# p[i, 2]*p[j, 1]*p[k, 2]*p[l, 1]
# -p[i, 2]*p[j, 1]*p[k, 2]*p[u, 1]
# -p[i, 2]*p[j, 1]*p[l, 1]*p[u, 2]
# p[i, 2]*p[j, 1]*p[u, 1]*p[v, 2]
# -p[i, 2]*p[j, 2]*p[k, 1]*p[l, 1]
# p[i, 2]*p[j, 2]*p[k, 1]*p[v, 1]
# p[i, 2]*p[j, 2]*p[l, 1]*p[u, 1]
# -p[i, 2]*p[j, 2]*p[u, 1]*p[v, 1]
# p[i, 2]*p[k, 1]*p[l, 1]*p[v, 2]
# -p[i, 2]*p[k, 1]*p[u, 2]*p[v, 1]
# -p[i, 2]*p[k, 2]*p[l, 1]*p[v, 1]
# p[i, 2]*p[k, 2]*p[u, 1]*p[v, 1]
# -p[i, 2]*p[l, 1]*p[u, 1]*p[v, 2]
# p[i, 2]*p[l, 1]*p[u, 2]*p[v, 1]
# -p[j, 1]*p[k, 1]*p[l, 2]*p[u, 2]
# p[j, 1]*p[k, 1]*p[l, 2]*p[v, 2]
# -p[j, 1]*p[k, 2]*p[l, 1]*p[v, 2]
# p[j, 1]*p[k, 2]*p[l, 2]*p[u, 1]
# p[j, 1]*p[l, 1]*p[u, 2]*p[v, 2]
# -p[j, 1]*p[l, 2]*p[u, 1]*p[v, 2]
# p[j, 2]*p[k, 1]*p[l, 1]*p[u, 2]
# -p[j, 2]*p[k, 1]*p[l, 2]*p[v, 1]
# -p[j, 2]*p[k, 2]*p[l, 1]*p[u, 1]
# p[j, 2]*p[k, 2]*p[l, 1]*p[v, 1]
# -p[j, 2]*p[l, 1]*p[u, 2]*p[v, 1]
# p[j, 2]*p[l, 2]*p[u, 1]*p[v, 1]
# -p[k, 1]*p[l, 1]*p[u, 2]*p[v, 2]
# p[k, 1]*p[l, 2]*p[u, 2]*p[v, 1]
# p[k, 2]*p[l, 1]*p[u, 1]*p[v, 2]
# -p[k, 2]*p[l, 2]*p[u, 1]*p[v, 1]
#
#
# Here are all the terms grouped by the number of epsilons:
# 0
# -p[i, 1]*p[j, 1]*p[k, 2]*p[l, 2] + p[i, 1]*p[j, 1]*p[k, 2]*p[v, 2] + p[i, 1]*p[j, 1]*p[l, 2]*p[u, 2] - p[i, 1]*p[j, 1]*p[u, 2]*p[v, 2] + p[i, 1]*p[j, 2]*p[k, 1]*p[l, 2] - p[i, 1]*p[j, 2]*p[k, 1]*p[u, 2] + p[i, 1]*p[j, 2]*p[k, 2]*p[u, 1] - p[i, 1]*p[j, 2]*p[k, 2]*p[v, 1] - p[i, 1]*p[j, 2]*p[l, 2]*p[u, 1] + p[i, 1]*p[j, 2]*p[u, 2]*p[v, 1] - p[i, 1]*p[k, 1]*p[l, 2]*p[v, 2] + p[i, 1]*p[k, 1]*p[u, 2]*p[v, 2] + p[i, 1]*p[k, 2]*p[l, 2]*p[v, 1] - p[i, 1]*p[k, 2]*p[u, 1]*p[v, 2] + p[i, 1]*p[l, 2]*p[u, 1]*p[v, 2] - p[i, 1]*p[l, 2]*p[u, 2]*p[v, 1] + p[i, 2]*p[j, 1]*p[k, 1]*p[u, 2] - p[i, 2]*p[j, 1]*p[k, 1]*p[v, 2] + p[i, 2]*p[j, 1]*p[k, 2]*p[l, 1] - p[i, 2]*p[j, 1]*p[k, 2]*p[u, 1] - p[i, 2]*p[j, 1]*p[l, 1]*p[u, 2] + p[i, 2]*p[j, 1]*p[u, 1]*p[v, 2] - p[i, 2]*p[j, 2]*p[k, 1]*p[l, 1] + p[i, 2]*p[j, 2]*p[k, 1]*p[v, 1] + p[i, 2]*p[j, 2]*p[l, 1]*p[u, 1] - p[i, 2]*p[j, 2]*p[u, 1]*p[v, 1] + p[i, 2]*p[k, 1]*p[l, 1]*p[v, 2] - p[i, 2]*p[k, 1]*p[u, 2]*p[v, 1] - p[i, 2]*p[k, 2]*p[l, 1]*p[v, 1] + p[i, 2]*p[k, 2]*p[u, 1]*p[v, 1] - p[i, 2]*p[l, 1]*p[u, 1]*p[v, 2] + p[i, 2]*p[l, 1]*p[u, 2]*p[v, 1] - p[j, 1]*p[k, 1]*p[l, 2]*p[u, 2] + p[j, 1]*p[k, 1]*p[l, 2]*p[v, 2] - p[j, 1]*p[k, 2]*p[l, 1]*p[v, 2] + p[j, 1]*p[k, 2]*p[l, 2]*p[u, 1] + p[j, 1]*p[l, 1]*p[u, 2]*p[v, 2] - p[j, 1]*p[l, 2]*p[u, 1]*p[v, 2] + p[j, 2]*p[k, 1]*p[l, 1]*p[u, 2] - p[j, 2]*p[k, 1]*p[l, 2]*p[v, 1] - p[j, 2]*p[k, 2]*p[l, 1]*p[u, 1] + p[j, 2]*p[k, 2]*p[l, 1]*p[v, 1] - p[j, 2]*p[l, 1]*p[u, 2]*p[v, 1] + p[j, 2]*p[l, 2]*p[u, 1]*p[v, 1] - p[k, 1]*p[l, 1]*p[u, 2]*p[v, 2] + p[k, 1]*p[l, 2]*p[u, 2]*p[v, 1] + p[k, 2]*p[l, 1]*p[u, 1]*p[v, 2] - p[k, 2]*p[l, 2]*p[u, 1]*p[v, 1]
# 1
# -e[i, 1]*p[j, 1]*p[k, 2]*p[l, 2] + e[i, 1]*p[j, 1]*p[k, 2]*p[v, 2] + e[i, 1]*p[j, 1]*p[l, 2]*p[u, 2] - e[i, 1]*p[j, 1]*p[u, 2]*p[v, 2] + e[i, 1]*p[j, 2]*p[k, 1]*p[l, 2] - e[i, 1]*p[j, 2]*p[k, 1]*p[u, 2] + e[i, 1]*p[j, 2]*p[k, 2]*p[u, 1] - e[i, 1]*p[j, 2]*p[k, 2]*p[v, 1] - e[i, 1]*p[j, 2]*p[l, 2]*p[u, 1] + e[i, 1]*p[j, 2]*p[u, 2]*p[v, 1] - e[i, 1]*p[k, 1]*p[l, 2]*p[v, 2] + e[i, 1]*p[k, 1]*p[u, 2]*p[v, 2] + e[i, 1]*p[k, 2]*p[l, 2]*p[v, 1] - e[i, 1]*p[k, 2]*p[u, 1]*p[v, 2] + e[i, 1]*p[l, 2]*p[u, 1]*p[v, 2] - e[i, 1]*p[l, 2]*p[u, 2]*p[v, 1] + e[i, 2]*p[j, 1]*p[k, 1]*p[u, 2] - e[i, 2]*p[j, 1]*p[k, 1]*p[v, 2] + e[i, 2]*p[j, 1]*p[k, 2]*p[l, 1] - e[i, 2]*p[j, 1]*p[k, 2]*p[u, 1] - e[i, 2]*p[j, 1]*p[l, 1]*p[u, 2] + e[i, 2]*p[j, 1]*p[u, 1]*p[v, 2] - e[i, 2]*p[j, 2]*p[k, 1]*p[l, 1] + e[i, 2]*p[j, 2]*p[k, 1]*p[v, 1] + e[i, 2]*p[j, 2]*p[l, 1]*p[u, 1] - e[i, 2]*p[j, 2]*p[u, 1]*p[v, 1] + e[i, 2]*p[k, 1]*p[l, 1]*p[v, 2] - e[i, 2]*p[k, 1]*p[u, 2]*p[v, 1] - e[i, 2]*p[k, 2]*p[l, 1]*p[v, 1] + e[i, 2]*p[k, 2]*p[u, 1]*p[v, 1] - e[i, 2]*p[l, 1]*p[u, 1]*p[v, 2] + e[i, 2]*p[l, 1]*p[u, 2]*p[v, 1] - e[j, 1]*p[i, 1]*p[k, 2]*p[l, 2] + e[j, 1]*p[i, 1]*p[k, 2]*p[v, 2] + e[j, 1]*p[i, 1]*p[l, 2]*p[u, 2] - e[j, 1]*p[i, 1]*p[u, 2]*p[v, 2] + e[j, 1]*p[i, 2]*p[k, 1]*p[u, 2] - e[j, 1]*p[i, 2]*p[k, 1]*p[v, 2] + e[j, 1]*p[i, 2]*p[k, 2]*p[l, 1] - e[j, 1]*p[i, 2]*p[k, 2]*p[u, 1] - e[j, 1]*p[i, 2]*p[l, 1]*p[u, 2] + e[j, 1]*p[i, 2]*p[u, 1]*p[v, 2] - e[j, 1]*p[k, 1]*p[l, 2]*p[u, 2] + e[j, 1]*p[k, 1]*p[l, 2]*p[v, 2] - e[j, 1]*p[k, 2]*p[l, 1]*p[v, 2] + e[j, 1]*p[k, 2]*p[l, 2]*p[u, 1] + e[j, 1]*p[l, 1]*p[u, 2]*p[v, 2] - e[j, 1]*p[l, 2]*p[u, 1]*p[v, 2] + e[j, 2]*p[i, 1]*p[k, 1]*p[l, 2] - e[j, 2]*p[i, 1]*p[k, 1]*p[u, 2] + e[j, 2]*p[i, 1]*p[k, 2]*p[u, 1] - e[j, 2]*p[i, 1]*p[k, 2]*p[v, 1] - e[j, 2]*p[i, 1]*p[l, 2]*p[u, 1] + e[j, 2]*p[i, 1]*p[u, 2]*p[v, 1] - e[j, 2]*p[i, 2]*p[k, 1]*p[l, 1] + e[j, 2]*p[i, 2]*p[k, 1]*p[v, 1] + e[j, 2]*p[i, 2]*p[l, 1]*p[u, 1] - e[j, 2]*p[i, 2]*p[u, 1]*p[v, 1] + e[j, 2]*p[k, 1]*p[l, 1]*p[u, 2] - e[j, 2]*p[k, 1]*p[l, 2]*p[v, 1] - e[j, 2]*p[k, 2]*p[l, 1]*p[u, 1] + e[j, 2]*p[k, 2]*p[l, 1]*p[v, 1] - e[j, 2]*p[l, 1]*p[u, 2]*p[v, 1] + e[j, 2]*p[l, 2]*p[u, 1]*p[v, 1] + e[k, 1]*p[i, 1]*p[j, 2]*p[l, 2] - e[k, 1]*p[i, 1]*p[j, 2]*p[u, 2] - e[k, 1]*p[i, 1]*p[l, 2]*p[v, 2] + e[k, 1]*p[i, 1]*p[u, 2]*p[v, 2] + e[k, 1]*p[i, 2]*p[j, 1]*p[u, 2] - e[k, 1]*p[i, 2]*p[j, 1]*p[v, 2] - e[k, 1]*p[i, 2]*p[j, 2]*p[l, 1] + e[k, 1]*p[i, 2]*p[j, 2]*p[v, 1] + e[k, 1]*p[i, 2]*p[l, 1]*p[v, 2] - e[k, 1]*p[i, 2]*p[u, 2]*p[v, 1] - e[k, 1]*p[j, 1]*p[l, 2]*p[u, 2] + e[k, 1]*p[j, 1]*p[l, 2]*p[v, 2] + e[k, 1]*p[j, 2]*p[l, 1]*p[u, 2] - e[k, 1]*p[j, 2]*p[l, 2]*p[v, 1] - e[k, 1]*p[l, 1]*p[u, 2]*p[v, 2] + e[k, 1]*p[l, 2]*p[u, 2]*p[v, 1] - e[k, 2]*p[i, 1]*p[j, 1]*p[l, 2] + e[k, 2]*p[i, 1]*p[j, 1]*p[v, 2] + e[k, 2]*p[i, 1]*p[j, 2]*p[u, 1] - e[k, 2]*p[i, 1]*p[j, 2]*p[v, 1] + e[k, 2]*p[i, 1]*p[l, 2]*p[v, 1] - e[k, 2]*p[i, 1]*p[u, 1]*p[v, 2] + e[k, 2]*p[i, 2]*p[j, 1]*p[l, 1] - e[k, 2]*p[i, 2]*p[j, 1]*p[u, 1] - e[k, 2]*p[i, 2]*p[l, 1]*p[v, 1] + e[k, 2]*p[i, 2]*p[u, 1]*p[v, 1] - e[k, 2]*p[j, 1]*p[l, 1]*p[v, 2] + e[k, 2]*p[j, 1]*p[l, 2]*p[u, 1] - e[k, 2]*p[j, 2]*p[l, 1]*p[u, 1] + e[k, 2]*p[j, 2]*p[l, 1]*p[v, 1] + e[k, 2]*p[l, 1]*p[u, 1]*p[v, 2] - e[k, 2]*p[l, 2]*p[u, 1]*p[v, 1] + e[l, 1]*p[i, 2]*p[j, 1]*p[k, 2] - e[l, 1]*p[i, 2]*p[j, 1]*p[u, 2] - e[l, 1]*p[i, 2]*p[j, 2]*p[k, 1] + e[l, 1]*p[i, 2]*p[j, 2]*p[u, 1] + e[l, 1]*p[i, 2]*p[k, 1]*p[v, 2] - e[l, 1]*p[i, 2]*p[k, 2]*p[v, 1] - e[l, 1]*p[i, 2]*p[u, 1]*p[v, 2] + e[l, 1]*p[i, 2]*p[u, 2]*p[v, 1] - e[l, 1]*p[j, 1]*p[k, 2]*p[v, 2] + e[l, 1]*p[j, 1]*p[u, 2]*p[v, 2] + e[l, 1]*p[j, 2]*p[k, 1]*p[u, 2] - e[l, 1]*p[j, 2]*p[k, 2]*p[u, 1] + e[l, 1]*p[j, 2]*p[k, 2]*p[v, 1] - e[l, 1]*p[j, 2]*p[u, 2]*p[v, 1] - e[l, 1]*p[k, 1]*p[u, 2]*p[v, 2] + e[l, 1]*p[k, 2]*p[u, 1]*p[v, 2] - e[l, 2]*p[i, 1]*p[j, 1]*p[k, 2] + e[l, 2]*p[i, 1]*p[j, 1]*p[u, 2] + e[l, 2]*p[i, 1]*p[j, 2]*p[k, 1] - e[l, 2]*p[i, 1]*p[j, 2]*p[u, 1] - e[l, 2]*p[i, 1]*p[k, 1]*p[v, 2] + e[l, 2]*p[i, 1]*p[k,  ...
# 2
# -e[i, 1]*e[j, 1]*p[k, 2]*p[l, 2] + e[i, 1]*e[j, 1]*p[k, 2]*p[v, 2] + e[i, 1]*e[j, 1]*p[l, 2]*p[u, 2] - e[i, 1]*e[j, 1]*p[u, 2]*p[v, 2] + e[i, 1]*e[j, 2]*p[k, 1]*p[l, 2] - e[i, 1]*e[j, 2]*p[k, 1]*p[u, 2] + e[i, 1]*e[j, 2]*p[k, 2]*p[u, 1] - e[i, 1]*e[j, 2]*p[k, 2]*p[v, 1] - e[i, 1]*e[j, 2]*p[l, 2]*p[u, 1] + e[i, 1]*e[j, 2]*p[u, 2]*p[v, 1] + e[i, 1]*e[k, 1]*p[j, 2]*p[l, 2] - e[i, 1]*e[k, 1]*p[j, 2]*p[u, 2] - e[i, 1]*e[k, 1]*p[l, 2]*p[v, 2] + e[i, 1]*e[k, 1]*p[u, 2]*p[v, 2] - e[i, 1]*e[k, 2]*p[j, 1]*p[l, 2] + e[i, 1]*e[k, 2]*p[j, 1]*p[v, 2] + e[i, 1]*e[k, 2]*p[j, 2]*p[u, 1] - e[i, 1]*e[k, 2]*p[j, 2]*p[v, 1] + e[i, 1]*e[k, 2]*p[l, 2]*p[v, 1] - e[i, 1]*e[k, 2]*p[u, 1]*p[v, 2] - e[i, 1]*e[l, 2]*p[j, 1]*p[k, 2] + e[i, 1]*e[l, 2]*p[j, 1]*p[u, 2] + e[i, 1]*e[l, 2]*p[j, 2]*p[k, 1] - e[i, 1]*e[l, 2]*p[j, 2]*p[u, 1] - e[i, 1]*e[l, 2]*p[k, 1]*p[v, 2] + e[i, 1]*e[l, 2]*p[k, 2]*p[v, 1] + e[i, 1]*e[l, 2]*p[u, 1]*p[v, 2] - e[i, 1]*e[l, 2]*p[u, 2]*p[v, 1] + e[i, 1]*e[u, 1]*p[j, 2]*p[k, 2] - e[i, 1]*e[u, 1]*p[j, 2]*p[l, 2] - e[i, 1]*e[u, 1]*p[k, 2]*p[v, 2] + e[i, 1]*e[u, 1]*p[l, 2]*p[v, 2] + e[i, 1]*e[u, 2]*p[j, 1]*p[l, 2] - e[i, 1]*e[u, 2]*p[j, 1]*p[v, 2] - e[i, 1]*e[u, 2]*p[j, 2]*p[k, 1] + e[i, 1]*e[u, 2]*p[j, 2]*p[v, 1] + e[i, 1]*e[u, 2]*p[k, 1]*p[v, 2] - e[i, 1]*e[u, 2]*p[l, 2]*p[v, 1] - e[i, 1]*e[v, 1]*p[j, 2]*p[k, 2] + e[i, 1]*e[v, 1]*p[j, 2]*p[u, 2] + e[i, 1]*e[v, 1]*p[k, 2]*p[l, 2] - e[i, 1]*e[v, 1]*p[l, 2]*p[u, 2] + e[i, 1]*e[v, 2]*p[j, 1]*p[k, 2] - e[i, 1]*e[v, 2]*p[j, 1]*p[u, 2] - e[i, 1]*e[v, 2]*p[k, 1]*p[l, 2] + e[i, 1]*e[v, 2]*p[k, 1]*p[u, 2] - e[i, 1]*e[v, 2]*p[k, 2]*p[u, 1] + e[i, 1]*e[v, 2]*p[l, 2]*p[u, 1] + e[i, 2]*e[j, 1]*p[k, 1]*p[u, 2] - e[i, 2]*e[j, 1]*p[k, 1]*p[v, 2] + e[i, 2]*e[j, 1]*p[k, 2]*p[l, 1] - e[i, 2]*e[j, 1]*p[k, 2]*p[u, 1] - e[i, 2]*e[j, 1]*p[l, 1]*p[u, 2] + e[i, 2]*e[j, 1]*p[u, 1]*p[v, 2] - e[i, 2]*e[j, 2]*p[k, 1]*p[l, 1] + e[i, 2]*e[j, 2]*p[k, 1]*p[v, 1] + e[i, 2]*e[j, 2]*p[l, 1]*p[u, 1] - e[i, 2]*e[j, 2]*p[u, 1]*p[v, 1] + e[i, 2]*e[k, 1]*p[j, 1]*p[u, 2] - e[i, 2]*e[k, 1]*p[j, 1]*p[v, 2] - e[i, 2]*e[k, 1]*p[j, 2]*p[l, 1] + e[i, 2]*e[k, 1]*p[j, 2]*p[v, 1] + e[i, 2]*e[k, 1]*p[l, 1]*p[v, 2] - e[i, 2]*e[k, 1]*p[u, 2]*p[v, 1] + e[i, 2]*e[k, 2]*p[j, 1]*p[l, 1] - e[i, 2]*e[k, 2]*p[j, 1]*p[u, 1] - e[i, 2]*e[k, 2]*p[l, 1]*p[v, 1] + e[i, 2]*e[k, 2]*p[u, 1]*p[v, 1] + e[i, 2]*e[l, 1]*p[j, 1]*p[k, 2] - e[i, 2]*e[l, 1]*p[j, 1]*p[u, 2] - e[i, 2]*e[l, 1]*p[j, 2]*p[k, 1] + e[i, 2]*e[l, 1]*p[j, 2]*p[u, 1] + e[i, 2]*e[l, 1]*p[k, 1]*p[v, 2] - e[i, 2]*e[l, 1]*p[k, 2]*p[v, 1] - e[i, 2]*e[l, 1]*p[u, 1]*p[v, 2] + e[i, 2]*e[l, 1]*p[u, 2]*p[v, 1] - e[i, 2]*e[u, 1]*p[j, 1]*p[k, 2] + e[i, 2]*e[u, 1]*p[j, 1]*p[v, 2] + e[i, 2]*e[u, 1]*p[j, 2]*p[l, 1] - e[i, 2]*e[u, 1]*p[j, 2]*p[v, 1] + e[i, 2]*e[u, 1]*p[k, 2]*p[v, 1] - e[i, 2]*e[u, 1]*p[l, 1]*p[v, 2] + e[i, 2]*e[u, 2]*p[j, 1]*p[k, 1] - e[i, 2]*e[u, 2]*p[j, 1]*p[l, 1] - e[i, 2]*e[u, 2]*p[k, 1]*p[v, 1] + e[i, 2]*e[u, 2]*p[l, 1]*p[v, 1] + e[i, 2]*e[v, 1]*p[j, 2]*p[k, 1] - e[i, 2]*e[v, 1]*p[j, 2]*p[u, 1] - e[i, 2]*e[v, 1]*p[k, 1]*p[u, 2] - e[i, 2]*e[v, 1]*p[k, 2]*p[l, 1] + e[i, 2]*e[v, 1]*p[k, 2]*p[u, 1] + e[i, 2]*e[v, 1]*p[l, 1]*p[u, 2] - e[i, 2]*e[v, 2]*p[j, 1]*p[k, 1] + e[i, 2]*e[v, 2]*p[j, 1]*p[u, 1] + e[i, 2]*e[v, 2]*p[k, 1]*p[l, 1] - e[i, 2]*e[v, 2]*p[l, 1]*p[u, 1] + e[j, 1]*e[k, 1]*p[i, 2]*p[u, 2] - e[j, 1]*e[k, 1]*p[i, 2]*p[v, 2] - e[j, 1]*e[k, 1]*p[l, 2]*p[u, 2] + e[j, 1]*e[k, 1]*p[l, 2]*p[v, 2] - e[j, 1]*e[k, 2]*p[i, 1]*p[l, 2] + e[j, 1]*e[k, 2]*p[i, 1]*p[v, 2] + e[j, 1]*e[k, 2]*p[i, 2]*p[l, 1] - e[j, 1]*e[k, 2]*p[i, 2]*p[u, 1] - e[j, 1]*e[k, 2]*p[l, 1]*p[v, 2] + e[j, 1]*e[k, 2]*p[l, 2]*p[u, 1] + e[j, 1]*e[l, 1]*p[i, 2]*p[k, 2] - e[j, 1]*e[l, 1]*p[i, 2]*p[u, 2] - e[j, 1]*e[l, 1]*p[k, 2]*p[v, 2] + e[j, 1]*e[l, 1]*p[u, 2]*p[v, 2] - e[j, 1]*e[l, 2]*p[i, 1]*p[k, 2] + e[j, 1]*e[l, 2]*p[i, 1]*p[u, 2] - e[j, 1]*e[l, 2]*p[k, 1]*p[u, 2] + e[j, 1]*e[l, 2]*p[k, 1]*p[v, 2] + e[j, 1]*e[l, 2]*p[k, 2]*p[u, 1] - e[j, 1]*e[l, 2]*p[u, 1]*p[v, 2] - e[j, 1]*e[u, 1]*p[i, 2]*p[k, 2] + e[j, 1]*e[u, 1]*p[i,  ...
# 3
# -e[i, 1]*e[j, 1]*e[k, 2]*p[l, 2] + e[i, 1]*e[j, 1]*e[k, 2]*p[v, 2] - e[i, 1]*e[j, 1]*e[l, 2]*p[k, 2] + e[i, 1]*e[j, 1]*e[l, 2]*p[u, 2] + e[i, 1]*e[j, 1]*e[u, 2]*p[l, 2] - e[i, 1]*e[j, 1]*e[u, 2]*p[v, 2] + e[i, 1]*e[j, 1]*e[v, 2]*p[k, 2] - e[i, 1]*e[j, 1]*e[v, 2]*p[u, 2] + e[i, 1]*e[j, 2]*e[k, 1]*p[l, 2] - e[i, 1]*e[j, 2]*e[k, 1]*p[u, 2] + e[i, 1]*e[j, 2]*e[k, 2]*p[u, 1] - e[i, 1]*e[j, 2]*e[k, 2]*p[v, 1] + e[i, 1]*e[j, 2]*e[l, 2]*p[k, 1] - e[i, 1]*e[j, 2]*e[l, 2]*p[u, 1] + e[i, 1]*e[j, 2]*e[u, 1]*p[k, 2] - e[i, 1]*e[j, 2]*e[u, 1]*p[l, 2] - e[i, 1]*e[j, 2]*e[u, 2]*p[k, 1] + e[i, 1]*e[j, 2]*e[u, 2]*p[v, 1] - e[i, 1]*e[j, 2]*e[v, 1]*p[k, 2] + e[i, 1]*e[j, 2]*e[v, 1]*p[u, 2] + e[i, 1]*e[k, 1]*e[l, 2]*p[j, 2] - e[i, 1]*e[k, 1]*e[l, 2]*p[v, 2] - e[i, 1]*e[k, 1]*e[u, 2]*p[j, 2] + e[i, 1]*e[k, 1]*e[u, 2]*p[v, 2] - e[i, 1]*e[k, 1]*e[v, 2]*p[l, 2] + e[i, 1]*e[k, 1]*e[v, 2]*p[u, 2] - e[i, 1]*e[k, 2]*e[l, 2]*p[j, 1] + e[i, 1]*e[k, 2]*e[l, 2]*p[v, 1] + e[i, 1]*e[k, 2]*e[u, 1]*p[j, 2] - e[i, 1]*e[k, 2]*e[u, 1]*p[v, 2] - e[i, 1]*e[k, 2]*e[v, 1]*p[j, 2] + e[i, 1]*e[k, 2]*e[v, 1]*p[l, 2] + e[i, 1]*e[k, 2]*e[v, 2]*p[j, 1] - e[i, 1]*e[k, 2]*e[v, 2]*p[u, 1] - e[i, 1]*e[l, 2]*e[u, 1]*p[j, 2] + e[i, 1]*e[l, 2]*e[u, 1]*p[v, 2] + e[i, 1]*e[l, 2]*e[u, 2]*p[j, 1] - e[i, 1]*e[l, 2]*e[u, 2]*p[v, 1] + e[i, 1]*e[l, 2]*e[v, 1]*p[k, 2] - e[i, 1]*e[l, 2]*e[v, 1]*p[u, 2] - e[i, 1]*e[l, 2]*e[v, 2]*p[k, 1] + e[i, 1]*e[l, 2]*e[v, 2]*p[u, 1] - e[i, 1]*e[u, 1]*e[v, 2]*p[k, 2] + e[i, 1]*e[u, 1]*e[v, 2]*p[l, 2] + e[i, 1]*e[u, 2]*e[v, 1]*p[j, 2] - e[i, 1]*e[u, 2]*e[v, 1]*p[l, 2] - e[i, 1]*e[u, 2]*e[v, 2]*p[j, 1] + e[i, 1]*e[u, 2]*e[v, 2]*p[k, 1] + e[i, 2]*e[j, 1]*e[k, 1]*p[u, 2] - e[i, 2]*e[j, 1]*e[k, 1]*p[v, 2] + e[i, 2]*e[j, 1]*e[k, 2]*p[l, 1] - e[i, 2]*e[j, 1]*e[k, 2]*p[u, 1] + e[i, 2]*e[j, 1]*e[l, 1]*p[k, 2] - e[i, 2]*e[j, 1]*e[l, 1]*p[u, 2] - e[i, 2]*e[j, 1]*e[u, 1]*p[k, 2] + e[i, 2]*e[j, 1]*e[u, 1]*p[v, 2] + e[i, 2]*e[j, 1]*e[u, 2]*p[k, 1] - e[i, 2]*e[j, 1]*e[u, 2]*p[l, 1] - e[i, 2]*e[j, 1]*e[v, 2]*p[k, 1] + e[i, 2]*e[j, 1]*e[v, 2]*p[u, 1] - e[i, 2]*e[j, 2]*e[k, 1]*p[l, 1] + e[i, 2]*e[j, 2]*e[k, 1]*p[v, 1] - e[i, 2]*e[j, 2]*e[l, 1]*p[k, 1] + e[i, 2]*e[j, 2]*e[l, 1]*p[u, 1] + e[i, 2]*e[j, 2]*e[u, 1]*p[l, 1] - e[i, 2]*e[j, 2]*e[u, 1]*p[v, 1] + e[i, 2]*e[j, 2]*e[v, 1]*p[k, 1] - e[i, 2]*e[j, 2]*e[v, 1]*p[u, 1] - e[i, 2]*e[k, 1]*e[l, 1]*p[j, 2] + e[i, 2]*e[k, 1]*e[l, 1]*p[v, 2] + e[i, 2]*e[k, 1]*e[u, 2]*p[j, 1] - e[i, 2]*e[k, 1]*e[u, 2]*p[v, 1] + e[i, 2]*e[k, 1]*e[v, 1]*p[j, 2] - e[i, 2]*e[k, 1]*e[v, 1]*p[u, 2] - e[i, 2]*e[k, 1]*e[v, 2]*p[j, 1] + e[i, 2]*e[k, 1]*e[v, 2]*p[l, 1] + e[i, 2]*e[k, 2]*e[l, 1]*p[j, 1] - e[i, 2]*e[k, 2]*e[l, 1]*p[v, 1] - e[i, 2]*e[k, 2]*e[u, 1]*p[j, 1] + e[i, 2]*e[k, 2]*e[u, 1]*p[v, 1] - e[i, 2]*e[k, 2]*e[v, 1]*p[l, 1] + e[i, 2]*e[k, 2]*e[v, 1]*p[u, 1] + e[i, 2]*e[l, 1]*e[u, 1]*p[j, 2] - e[i, 2]*e[l, 1]*e[u, 1]*p[v, 2] - e[i, 2]*e[l, 1]*e[u, 2]*p[j, 1] + e[i, 2]*e[l, 1]*e[u, 2]*p[v, 1] - e[i, 2]*e[l, 1]*e[v, 1]*p[k, 2] + e[i, 2]*e[l, 1]*e[v, 1]*p[u, 2] + e[i, 2]*e[l, 1]*e[v, 2]*p[k, 1] - e[i, 2]*e[l, 1]*e[v, 2]*p[u, 1] - e[i, 2]*e[u, 1]*e[v, 1]*p[j, 2] + e[i, 2]*e[u, 1]*e[v, 1]*p[k, 2] + e[i, 2]*e[u, 1]*e[v, 2]*p[j, 1] - e[i, 2]*e[u, 1]*e[v, 2]*p[l, 1] - e[i, 2]*e[u, 2]*e[v, 1]*p[k, 1] + e[i, 2]*e[u, 2]*e[v, 1]*p[l, 1] - e[j, 1]*e[k, 1]*e[l, 2]*p[u, 2] + e[j, 1]*e[k, 1]*e[l, 2]*p[v, 2] + e[j, 1]*e[k, 1]*e[u, 2]*p[i, 2] - e[j, 1]*e[k, 1]*e[u, 2]*p[l, 2] - e[j, 1]*e[k, 1]*e[v, 2]*p[i, 2] + e[j, 1]*e[k, 1]*e[v, 2]*p[l, 2] + e[j, 1]*e[k, 2]*e[l, 1]*p[i, 2] - e[j, 1]*e[k, 2]*e[l, 1]*p[v, 2] - e[j, 1]*e[k, 2]*e[l, 2]*p[i, 1] + e[j, 1]*e[k, 2]*e[l, 2]*p[u, 1] - e[j, 1]*e[k, 2]*e[u, 1]*p[i, 2] + e[j, 1]*e[k, 2]*e[u, 1]*p[l, 2] + e[j, 1]*e[k, 2]*e[v, 2]*p[i, 1] - e[j, 1]*e[k, 2]*e[v, 2]*p[l, 1] - e[j, 1]*e[l, 1]*e[u, 2]*p[i, 2] + e[j, 1]*e[l, 1]*e[u, 2]*p[v, 2] - e[j, 1]*e[l, 1]*e[v, 2]*p[k, 2] + e[j, 1]*e[l, 1]*e[v, 2]*p[u, 2] + e[j, 1]*e[l, 2]*e[u, 1]*p[k, 2] - e[j, 1]*e[l, 2]*e[u, 1]*p[v, 2] + e[j, 1]*e[l, 2]*e[u, 2]*p[i, 1] - e[j, 1]*e[l, 2]*e[u,  ...
# 4
# -e[i, 1]*e[j, 1]*e[k, 2]*e[l, 2] + e[i, 1]*e[j, 1]*e[k, 2]*e[v, 2] + e[i, 1]*e[j, 1]*e[l, 2]*e[u, 2] - e[i, 1]*e[j, 1]*e[u, 2]*e[v, 2] + e[i, 1]*e[j, 2]*e[k, 1]*e[l, 2] - e[i, 1]*e[j, 2]*e[k, 1]*e[u, 2] + e[i, 1]*e[j, 2]*e[k, 2]*e[u, 1] - e[i, 1]*e[j, 2]*e[k, 2]*e[v, 1] - e[i, 1]*e[j, 2]*e[l, 2]*e[u, 1] + e[i, 1]*e[j, 2]*e[u, 2]*e[v, 1] - e[i, 1]*e[k, 1]*e[l, 2]*e[v, 2] + e[i, 1]*e[k, 1]*e[u, 2]*e[v, 2] + e[i, 1]*e[k, 2]*e[l, 2]*e[v, 1] - e[i, 1]*e[k, 2]*e[u, 1]*e[v, 2] + e[i, 1]*e[l, 2]*e[u, 1]*e[v, 2] - e[i, 1]*e[l, 2]*e[u, 2]*e[v, 1] + e[i, 2]*e[j, 1]*e[k, 1]*e[u, 2] - e[i, 2]*e[j, 1]*e[k, 1]*e[v, 2] + e[i, 2]*e[j, 1]*e[k, 2]*e[l, 1] - e[i, 2]*e[j, 1]*e[k, 2]*e[u, 1] - e[i, 2]*e[j, 1]*e[l, 1]*e[u, 2] + e[i, 2]*e[j, 1]*e[u, 1]*e[v, 2] - e[i, 2]*e[j, 2]*e[k, 1]*e[l, 1] + e[i, 2]*e[j, 2]*e[k, 1]*e[v, 1] + e[i, 2]*e[j, 2]*e[l, 1]*e[u, 1] - e[i, 2]*e[j, 2]*e[u, 1]*e[v, 1] + e[i, 2]*e[k, 1]*e[l, 1]*e[v, 2] - e[i, 2]*e[k, 1]*e[u, 2]*e[v, 1] - e[i, 2]*e[k, 2]*e[l, 1]*e[v, 1] + e[i, 2]*e[k, 2]*e[u, 1]*e[v, 1] - e[i, 2]*e[l, 1]*e[u, 1]*e[v, 2] + e[i, 2]*e[l, 1]*e[u, 2]*e[v, 1] - e[j, 1]*e[k, 1]*e[l, 2]*e[u, 2] + e[j, 1]*e[k, 1]*e[l, 2]*e[v, 2] - e[j, 1]*e[k, 2]*e[l, 1]*e[v, 2] + e[j, 1]*e[k, 2]*e[l, 2]*e[u, 1] + e[j, 1]*e[l, 1]*e[u, 2]*e[v, 2] - e[j, 1]*e[l, 2]*e[u, 1]*e[v, 2] + e[j, 2]*e[k, 1]*e[l, 1]*e[u, 2] - e[j, 2]*e[k, 1]*e[l, 2]*e[v, 1] - e[j, 2]*e[k, 2]*e[l, 1]*e[u, 1] + e[j, 2]*e[k, 2]*e[l, 1]*e[v, 1] - e[j, 2]*e[l, 1]*e[u, 2]*e[v, 1] + e[j, 2]*e[l, 2]*e[u, 1]*e[v, 1] - e[k, 1]*e[l, 1]*e[u, 2]*e[v, 2] + e[k, 1]*e[l, 2]*e[u, 2]*e[v, 1] + e[k, 2]*e[l, 1]*e[u, 1]*e[v, 2] - e[k, 2]*e[l, 2]*e[u, 1]*e[v, 1]
# We have this many types of mixed expressions 5
#
#
# Here are all the sequences:
#
#
# The epsilon product with order 1: e[i, 2]
# The p-term of that product has 16 terms:
# p[j, 1]*p[k, 1]*p[u, 2] - p[j, 1]*p[k, 1]*p[v, 2] + p[j, 1]*p[k, 2]*p[l, 1] - p[j, 1]*p[k, 2]*p[u, 1] - p[j, 1]*p[l, 1]*p[u, 2] + p[j, 1]*p[u, 1]*p[v, 2] - p[j, 2]*p[k, 1]*p[l, 1] + p[j, 2]*p[k, 1]*p[v, 1] + p[j, 2]*p[l, 1]*p[u, 1] - p[j, 2]*p[u, 1]*p[v, 1] + p[k, 1]*p[l, 1]*p[v, 2] - p[k, 1]*p[u, 2]*p[v, 1] - p[k, 2]*p[l, 1]*p[v, 1] + p[k, 2]*p[u, 1]*p[v, 1] - p[l, 1]*p[u, 1]*p[v, 2] + p[l, 1]*p[u, 2]*p[v, 1]
# Here it is simplified...
# p[j, 1]*p[k, 1]*p[u, 2] - p[j, 1]*p[k, 1]*p[v, 2] + p[j, 1]*p[k, 2]*p[l, 1] - p[j, 1]*p[k, 2]*p[u, 1] - p[j, 1]*p[l, 1]*p[u, 2] + p[j, 1]*p[u, 1]*p[v, 2] - p[j, 2]*p[k, 1]*p[l, 1] + p[j, 2]*p[k, 1]*p[v, 1] + p[j, 2]*p[l, 1]*p[u, 1] - p[j, 2]*p[u, 1]*p[v, 1] + p[k, 1]*p[l, 1]*p[v, 2] - p[k, 1]*p[u, 2]*p[v, 1] - p[k, 2]*p[l, 1]*p[v, 1] + p[k, 2]*p[u, 1]*p[v, 1] - p[l, 1]*p[u, 1]*p[v, 2] + p[l, 1]*p[u, 2]*p[v, 1]
#
#
# The epsilon product with order 2: e[i, 1]
# The p-term of that product has 16 terms:
# -p[j, 1]*p[k, 2]*p[l, 2] + p[j, 1]*p[k, 2]*p[v, 2] + p[j, 1]*p[l, 2]*p[u, 2] - p[j, 1]*p[u, 2]*p[v, 2] + p[j, 2]*p[k, 1]*p[l, 2] - p[j, 2]*p[k, 1]*p[u, 2] + p[j, 2]*p[k, 2]*p[u, 1] - p[j, 2]*p[k, 2]*p[v, 1] - p[j, 2]*p[l, 2]*p[u, 1] + p[j, 2]*p[u, 2]*p[v, 1] - p[k, 1]*p[l, 2]*p[v, 2] + p[k, 1]*p[u, 2]*p[v, 2] + p[k, 2]*p[l, 2]*p[v, 1] - p[k, 2]*p[u, 1]*p[v, 2] + p[l, 2]*p[u, 1]*p[v, 2] - p[l, 2]*p[u, 2]*p[v, 1]
# Here it is simplified...
# -p[j, 1]*p[k, 2]*p[l, 2] + p[j, 1]*p[k, 2]*p[v, 2] + p[j, 1]*p[l, 2]*p[u, 2] - p[j, 1]*p[u, 2]*p[v, 2] + p[j, 2]*p[k, 1]*p[l, 2] - p[j, 2]*p[k, 1]*p[u, 2] + p[j, 2]*p[k, 2]*p[u, 1] - p[j, 2]*p[k, 2]*p[v, 1] - p[j, 2]*p[l, 2]*p[u, 1] + p[j, 2]*p[u, 2]*p[v, 1] - p[k, 1]*p[l, 2]*p[v, 2] + p[k, 1]*p[u, 2]*p[v, 2] + p[k, 2]*p[l, 2]*p[v, 1] - p[k, 2]*p[u, 1]*p[v, 2] + p[l, 2]*p[u, 1]*p[v, 2] - p[l, 2]*p[u, 2]*p[v, 1]
#
#
# The epsilon product with order 3: e[j, 2]
# The p-term of that product has 16 terms:
# p[i, 1]*p[k, 1]*p[l, 2] - p[i, 1]*p[k, 1]*p[u, 2] + p[i, 1]*p[k, 2]*p[u, 1] - p[i, 1]*p[k, 2]*p[v, 1] - p[i, 1]*p[l, 2]*p[u, 1] + p[i, 1]*p[u, 2]*p[v, 1] - p[i, 2]*p[k, 1]*p[l, 1] + p[i, 2]*p[k, 1]*p[v, 1] + p[i, 2]*p[l, 1]*p[u, 1] - p[i, 2]*p[u, 1]*p[v, 1] + p[k, 1]*p[l, 1]*p[u, 2] - p[k, 1]*p[l, 2]*p[v, 1] - p[k, 2]*p[l, 1]*p[u, 1] + p[k, 2]*p[l, 1]*p[v, 1] - p[l, 1]*p[u, 2]*p[v, 1] + p[l, 2]*p[u, 1]*p[v, 1]
# Here it is simplified...
# p[i, 1]*p[k, 1]*p[l, 2] - p[i, 1]*p[k, 1]*p[u, 2] + p[i, 1]*p[k, 2]*p[u, 1] - p[i, 1]*p[k, 2]*p[v, 1] - p[i, 1]*p[l, 2]*p[u, 1] + p[i, 1]*p[u, 2]*p[v, 1] - p[i, 2]*p[k, 1]*p[l, 1] + p[i, 2]*p[k, 1]*p[v, 1] + p[i, 2]*p[l, 1]*p[u, 1] - p[i, 2]*p[u, 1]*p[v, 1] + p[k, 1]*p[l, 1]*p[u, 2] - p[k, 1]*p[l, 2]*p[v, 1] - p[k, 2]*p[l, 1]*p[u, 1] + p[k, 2]*p[l, 1]*p[v, 1] - p[l, 1]*p[u, 2]*p[v, 1] + p[l, 2]*p[u, 1]*p[v, 1]
#
#
# The epsilon product with order 4: e[i, 2]*e[j, 2]
# The p-term of that product has 4 terms:
# -p[k, 1]*p[l, 1] + p[k, 1]*p[v, 1] + p[l, 1]*p[u, 1] - p[u, 1]*p[v, 1]
# Here it is simplified...
# -p[k, 1]*p[l, 1] + p[k, 1]*p[v, 1] + p[l, 1]*p[u, 1] - p[u, 1]*p[v, 1]
#
#
# The epsilon product with order 5: e[i, 1]*e[j, 2]
# The p-term of that product has 6 terms:
# p[k, 1]*p[l, 2] - p[k, 1]*p[u, 2] + p[k, 2]*p[u, 1] - p[k, 2]*p[v, 1] - p[l, 2]*p[u, 1] + p[u, 2]*p[v, 1]
# Here it is simplified...
# p[k, 1]*p[l, 2] - p[k, 1]*p[u, 2] + p[k, 2]*p[u, 1] - p[k, 2]*p[v, 1] - p[l, 2]*p[u, 1] + p[u, 2]*p[v, 1]
#
#
# The epsilon product with order 6: e[j, 1]
# The p-term of that product has 16 terms:
# -p[i, 1]*p[k, 2]*p[l, 2] + p[i, 1]*p[k, 2]*p[v, 2] + p[i, 1]*p[l, 2]*p[u, 2] - p[i, 1]*p[u, 2]*p[v, 2] + p[i, 2]*p[k, 1]*p[u, 2] - p[i, 2]*p[k, 1]*p[v, 2] + p[i, 2]*p[k, 2]*p[l, 1] - p[i, 2]*p[k, 2]*p[u, 1] - p[i, 2]*p[l, 1]*p[u, 2] + p[i, 2]*p[u, 1]*p[v, 2] - p[k, 1]*p[l, 2]*p[u, 2] + p[k, 1]*p[l, 2]*p[v, 2] - p[k, 2]*p[l, 1]*p[v, 2] + p[k, 2]*p[l, 2]*p[u, 1] + p[l, 1]*p[u, 2]*p[v, 2] - p[l, 2]*p[u, 1]*p[v, 2]
# Here it is simplified...
# -p[i, 1]*p[k, 2]*p[l, 2] + p[i, 1]*p[k, 2]*p[v, 2] + p[i, 1]*p[l, 2]*p[u, 2] - p[i, 1]*p[u, 2]*p[v, 2] + p[i, 2]*p[k, 1]*p[u, 2] - p[i, 2]*p[k, 1]*p[v, 2] + p[i, 2]*p[k, 2]*p[l, 1] - p[i, 2]*p[k, 2]*p[u, 1] - p[i, 2]*p[l, 1]*p[u, 2] + p[i, 2]*p[u, 1]*p[v, 2] - p[k, 1]*p[l, 2]*p[u, 2] + p[k, 1]*p[l, 2]*p[v, 2] - p[k, 2]*p[l, 1]*p[v, 2] + p[k, 2]*p[l, 2]*p[u, 1] + p[l, 1]*p[u, 2]*p[v, 2] - p[l, 2]*p[u, 1]*p[v, 2]
#
#
# The epsilon product with order 7: e[i, 2]*e[j, 1]
# The p-term of that product has 6 terms:
# p[k, 1]*p[u, 2] - p[k, 1]*p[v, 2] + p[k, 2]*p[l, 1] - p[k, 2]*p[u, 1] - p[l, 1]*p[u, 2] + p[u, 1]*p[v, 2]
# Here it is simplified...
# p[k, 1]*p[u, 2] - p[k, 1]*p[v, 2] + p[k, 2]*p[l, 1] - p[k, 2]*p[u, 1] - p[l, 1]*p[u, 2] + p[u, 1]*p[v, 2]
#
#
# The epsilon product with order 8: e[i, 1]*e[j, 1]
# The p-term of that product has 4 terms:
# -p[k, 2]*p[l, 2] + p[k, 2]*p[v, 2] + p[l, 2]*p[u, 2] - p[u, 2]*p[v, 2]
# Here it is simplified...
# -p[k, 2]*p[l, 2] + p[k, 2]*p[v, 2] + p[l, 2]*p[u, 2] - p[u, 2]*p[v, 2]
#
#
# The epsilon product with order 9: e[k, 2]
# The p-term of that product has 16 terms:
# -p[i, 1]*p[j, 1]*p[l, 2] + p[i, 1]*p[j, 1]*p[v, 2] + p[i, 1]*p[j, 2]*p[u, 1] - p[i, 1]*p[j, 2]*p[v, 1] + p[i, 1]*p[l, 2]*p[v, 1] - p[i, 1]*p[u, 1]*p[v, 2] + p[i, 2]*p[j, 1]*p[l, 1] - p[i, 2]*p[j, 1]*p[u, 1] - p[i, 2]*p[l, 1]*p[v, 1] + p[i, 2]*p[u, 1]*p[v, 1] - p[j, 1]*p[l, 1]*p[v, 2] + p[j, 1]*p[l, 2]*p[u, 1] - p[j, 2]*p[l, 1]*p[u, 1] + p[j, 2]*p[l, 1]*p[v, 1] + p[l, 1]*p[u, 1]*p[v, 2] - p[l, 2]*p[u, 1]*p[v, 1]
# Here it is simplified...
# -p[i, 1]*p[j, 1]*p[l, 2] + p[i, 1]*p[j, 1]*p[v, 2] + p[i, 1]*p[j, 2]*p[u, 1] - p[i, 1]*p[j, 2]*p[v, 1] + p[i, 1]*p[l, 2]*p[v, 1] - p[i, 1]*p[u, 1]*p[v, 2] + p[i, 2]*p[j, 1]*p[l, 1] - p[i, 2]*p[j, 1]*p[u, 1] - p[i, 2]*p[l, 1]*p[v, 1] + p[i, 2]*p[u, 1]*p[v, 1] - p[j, 1]*p[l, 1]*p[v, 2] + p[j, 1]*p[l, 2]*p[u, 1] - p[j, 2]*p[l, 1]*p[u, 1] + p[j, 2]*p[l, 1]*p[v, 1] + p[l, 1]*p[u, 1]*p[v, 2] - p[l, 2]*p[u, 1]*p[v, 1]
#
#
# The epsilon product with order 10: e[i, 2]*e[k, 2]
# The p-term of that product has 4 terms:
# p[j, 1]*p[l, 1] - p[j, 1]*p[u, 1] - p[l, 1]*p[v, 1] + p[u, 1]*p[v, 1]
# Here it is simplified...
# p[j, 1]*p[l, 1] - p[j, 1]*p[u, 1] - p[l, 1]*p[v, 1] + p[u, 1]*p[v, 1]
#
#
# The epsilon product with order 11: e[i, 1]*e[k, 2]
# The p-term of that product has 6 terms:
# -p[j, 1]*p[l, 2] + p[j, 1]*p[v, 2] + p[j, 2]*p[u, 1] - p[j, 2]*p[v, 1] + p[l, 2]*p[v, 1] - p[u, 1]*p[v, 2]
# Here it is simplified...
# -p[j, 1]*p[l, 2] + p[j, 1]*p[v, 2] + p[j, 2]*p[u, 1] - p[j, 2]*p[v, 1] + p[l, 2]*p[v, 1] - p[u, 1]*p[v, 2]
#
#
# The epsilon product with order 12: e[j, 2]*e[k, 2]
# The p-term of that product has 4 terms:
# p[i, 1]*p[u, 1] - p[i, 1]*p[v, 1] - p[l, 1]*p[u, 1] + p[l, 1]*p[v, 1]
# Here it is simplified...
# p[i, 1]*p[u, 1] - p[i, 1]*p[v, 1] - p[l, 1]*p[u, 1] + p[l, 1]*p[v, 1]
#
#
# The epsilon product with order 13: e[i, 2]*e[j, 2]*e[k, 2]
# ------------------------------------- Skipping
#
#
# The epsilon product with order 14: e[i, 1]*e[j, 2]*e[k, 2]
# The p-term of that product has 2 terms:
# p[u, 1] - p[v, 1]
# Here it is simplified...
# p[u, 1] - p[v, 1]
#
#
# The epsilon product with order 15: e[j, 1]*e[k, 2]
# The p-term of that product has 6 terms:
# -p[i, 1]*p[l, 2] + p[i, 1]*p[v, 2] + p[i, 2]*p[l, 1] - p[i, 2]*p[u, 1] - p[l, 1]*p[v, 2] + p[l, 2]*p[u, 1]
# Here it is simplified...
# -p[i, 1]*p[l, 2] + p[i, 1]*p[v, 2] + p[i, 2]*p[l, 1] - p[i, 2]*p[u, 1] - p[l, 1]*p[v, 2] + p[l, 2]*p[u, 1]
#
#
# The epsilon product with order 16: e[i, 2]*e[j, 1]*e[k, 2]
# The p-term of that product has 2 terms:
# p[l, 1] - p[u, 1]
# Here it is simplified...
# p[l, 1] - p[u, 1]
#
#
# The epsilon product with order 17: e[i, 1]*e[j, 1]*e[k, 2]
# The p-term of that product has 2 terms:
# -p[l, 2] + p[v, 2]
# Here it is simplified...
# -p[l, 2] + p[v, 2]
#
#
# The epsilon product with order 18: e[k, 1]
# The p-term of that product has 16 terms:
# p[i, 1]*p[j, 2]*p[l, 2] - p[i, 1]*p[j, 2]*p[u, 2] - p[i, 1]*p[l, 2]*p[v, 2] + p[i, 1]*p[u, 2]*p[v, 2] + p[i, 2]*p[j, 1]*p[u, 2] - p[i, 2]*p[j, 1]*p[v, 2] - p[i, 2]*p[j, 2]*p[l, 1] + p[i, 2]*p[j, 2]*p[v, 1] + p[i, 2]*p[l, 1]*p[v, 2] - p[i, 2]*p[u, 2]*p[v, 1] - p[j, 1]*p[l, 2]*p[u, 2] + p[j, 1]*p[l, 2]*p[v, 2] + p[j, 2]*p[l, 1]*p[u, 2] - p[j, 2]*p[l, 2]*p[v, 1] - p[l, 1]*p[u, 2]*p[v, 2] + p[l, 2]*p[u, 2]*p[v, 1]
# Here it is simplified...
# p[i, 1]*p[j, 2]*p[l, 2] - p[i, 1]*p[j, 2]*p[u, 2] - p[i, 1]*p[l, 2]*p[v, 2] + p[i, 1]*p[u, 2]*p[v, 2] + p[i, 2]*p[j, 1]*p[u, 2] - p[i, 2]*p[j, 1]*p[v, 2] - p[i, 2]*p[j, 2]*p[l, 1] + p[i, 2]*p[j, 2]*p[v, 1] + p[i, 2]*p[l, 1]*p[v, 2] - p[i, 2]*p[u, 2]*p[v, 1] - p[j, 1]*p[l, 2]*p[u, 2] + p[j, 1]*p[l, 2]*p[v, 2] + p[j, 2]*p[l, 1]*p[u, 2] - p[j, 2]*p[l, 2]*p[v, 1] - p[l, 1]*p[u, 2]*p[v, 2] + p[l, 2]*p[u, 2]*p[v, 1]
#
#
# The epsilon product with order 19: e[i, 2]*e[k, 1]
# The p-term of that product has 6 terms:
# p[j, 1]*p[u, 2] - p[j, 1]*p[v, 2] - p[j, 2]*p[l, 1] + p[j, 2]*p[v, 1] + p[l, 1]*p[v, 2] - p[u, 2]*p[v, 1]
# Here it is simplified...
# p[j, 1]*p[u, 2] - p[j, 1]*p[v, 2] - p[j, 2]*p[l, 1] + p[j, 2]*p[v, 1] + p[l, 1]*p[v, 2] - p[u, 2]*p[v, 1]
#
#
# The epsilon product with order 20: e[i, 1]*e[k, 1]
# The p-term of that product has 4 terms:
# p[j, 2]*p[l, 2] - p[j, 2]*p[u, 2] - p[l, 2]*p[v, 2] + p[u, 2]*p[v, 2]
# Here it is simplified...
# p[j, 2]*p[l, 2] - p[j, 2]*p[u, 2] - p[l, 2]*p[v, 2] + p[u, 2]*p[v, 2]
#
#
# The epsilon product with order 21: e[j, 2]*e[k, 1]
# The p-term of that product has 6 terms:
# p[i, 1]*p[l, 2] - p[i, 1]*p[u, 2] - p[i, 2]*p[l, 1] + p[i, 2]*p[v, 1] + p[l, 1]*p[u, 2] - p[l, 2]*p[v, 1]
# Here it is simplified...
# p[i, 1]*p[l, 2] - p[i, 1]*p[u, 2] - p[i, 2]*p[l, 1] + p[i, 2]*p[v, 1] + p[l, 1]*p[u, 2] - p[l, 2]*p[v, 1]
#
#
# The epsilon product with order 22: e[i, 2]*e[j, 2]*e[k, 1]
# The p-term of that product has 2 terms:
# -p[l, 1] + p[v, 1]
# Here it is simplified...
# -p[l, 1] + p[v, 1]
#
#
# The epsilon product with order 23: e[i, 1]*e[j, 2]*e[k, 1]
# The p-term of that product has 2 terms:
# p[l, 2] - p[u, 2]
# Here it is simplified...
# p[l, 2] - p[u, 2]
#
#
# The epsilon product with order 24: e[j, 1]*e[k, 1]
# The p-term of that product has 4 terms:
# p[i, 2]*p[u, 2] - p[i, 2]*p[v, 2] - p[l, 2]*p[u, 2] + p[l, 2]*p[v, 2]
# Here it is simplified...
# p[i, 2]*p[u, 2] - p[i, 2]*p[v, 2] - p[l, 2]*p[u, 2] + p[l, 2]*p[v, 2]
#
#
# The epsilon product with order 25: e[i, 2]*e[j, 1]*e[k, 1]
# The p-term of that product has 2 terms:
# p[u, 2] - p[v, 2]
# Here it is simplified...
# p[u, 2] - p[v, 2]
#
#
# The epsilon product with order 26: e[i, 1]*e[j, 1]*e[k, 1]
# ------------------------------------- Skipping
#
#
# The epsilon product with order 27: e[l, 2]
# The p-term of that product has 16 terms:
# -p[i, 1]*p[j, 1]*p[k, 2] + p[i, 1]*p[j, 1]*p[u, 2] + p[i, 1]*p[j, 2]*p[k, 1] - p[i, 1]*p[j, 2]*p[u, 1] - p[i, 1]*p[k, 1]*p[v, 2] + p[i, 1]*p[k, 2]*p[v, 1] + p[i, 1]*p[u, 1]*p[v, 2] - p[i, 1]*p[u, 2]*p[v, 1] - p[j, 1]*p[k, 1]*p[u, 2] + p[j, 1]*p[k, 1]*p[v, 2] + p[j, 1]*p[k, 2]*p[u, 1] - p[j, 1]*p[u, 1]*p[v, 2] - p[j, 2]*p[k, 1]*p[v, 1] + p[j, 2]*p[u, 1]*p[v, 1] + p[k, 1]*p[u, 2]*p[v, 1] - p[k, 2]*p[u, 1]*p[v, 1]
# Here it is simplified...
# -p[i, 1]*p[j, 1]*p[k, 2] + p[i, 1]*p[j, 1]*p[u, 2] + p[i, 1]*p[j, 2]*p[k, 1] - p[i, 1]*p[j, 2]*p[u, 1] - p[i, 1]*p[k, 1]*p[v, 2] + p[i, 1]*p[k, 2]*p[v, 1] + p[i, 1]*p[u, 1]*p[v, 2] - p[i, 1]*p[u, 2]*p[v, 1] - p[j, 1]*p[k, 1]*p[u, 2] + p[j, 1]*p[k, 1]*p[v, 2] + p[j, 1]*p[k, 2]*p[u, 1] - p[j, 1]*p[u, 1]*p[v, 2] - p[j, 2]*p[k, 1]*p[v, 1] + p[j, 2]*p[u, 1]*p[v, 1] + p[k, 1]*p[u, 2]*p[v, 1] - p[k, 2]*p[u, 1]*p[v, 1]
#
#
# The epsilon product with order 28: e[i, 2]*e[l, 2]
# ------------------------------------- Skipping
#
#
# The epsilon product with order 29: e[i, 1]*e[l, 2]
# The p-term of that product has 8 terms:
# -p[j, 1]*p[k, 2] + p[j, 1]*p[u, 2] + p[j, 2]*p[k, 1] - p[j, 2]*p[u, 1] - p[k, 1]*p[v, 2] + p[k, 2]*p[v, 1] + p[u, 1]*p[v, 2] - p[u, 2]*p[v, 1]
# Here it is simplified...
# -p[j, 1]*p[k, 2] + p[j, 1]*p[u, 2] + p[j, 2]*p[k, 1] - p[j, 2]*p[u, 1] - p[k, 1]*p[v, 2] + p[k, 2]*p[v, 1] + p[u, 1]*p[v, 2] - p[u, 2]*p[v, 1]
#
#
# The epsilon product with order 30: e[j, 2]*e[l, 2]
# The p-term of that product has 4 terms:
# p[i, 1]*p[k, 1] - p[i, 1]*p[u, 1] - p[k, 1]*p[v, 1] + p[u, 1]*p[v, 1]
# Here it is simplified...
# p[i, 1]*p[k, 1] - p[i, 1]*p[u, 1] - p[k, 1]*p[v, 1] + p[u, 1]*p[v, 1]
#
#
# The epsilon product with order 31: e[i, 2]*e[j, 2]*e[l, 2]
# ------------------------------------- Skipping
#
#
# The epsilon product with order 32: e[i, 1]*e[j, 2]*e[l, 2]
# The p-term of that product has 2 terms:
# p[k, 1] - p[u, 1]
# Here it is simplified...
# p[k, 1] - p[u, 1]
#
#
# The epsilon product with order 33: e[j, 1]*e[l, 2]
# The p-term of that product has 6 terms:
# -p[i, 1]*p[k, 2] + p[i, 1]*p[u, 2] - p[k, 1]*p[u, 2] + p[k, 1]*p[v, 2] + p[k, 2]*p[u, 1] - p[u, 1]*p[v, 2]
# Here it is simplified...
# -p[i, 1]*p[k, 2] + p[i, 1]*p[u, 2] - p[k, 1]*p[u, 2] + p[k, 1]*p[v, 2] + p[k, 2]*p[u, 1] - p[u, 1]*p[v, 2]
#
#
# The epsilon product with order 34: e[i, 2]*e[j, 1]*e[l, 2]
# ------------------------------------- Skipping
#
#
# The epsilon product with order 35: e[i, 1]*e[j, 1]*e[l, 2]
# The p-term of that product has 2 terms:
# -p[k, 2] + p[u, 2]
# Here it is simplified...
# -p[k, 2] + p[u, 2]
#
#
# The epsilon product with order 36: e[k, 2]*e[l, 2]
# The p-term of that product has 4 terms:
# -p[i, 1]*p[j, 1] + p[i, 1]*p[v, 1] + p[j, 1]*p[u, 1] - p[u, 1]*p[v, 1]
# Here it is simplified...
# -p[i, 1]*p[j, 1] + p[i, 1]*p[v, 1] + p[j, 1]*p[u, 1] - p[u, 1]*p[v, 1]
#
#
# The epsilon product with order 37: e[i, 2]*e[k, 2]*e[l, 2]
# ------------------------------------- Skipping
#
#
# The epsilon product with order 38: e[i, 1]*e[k, 2]*e[l, 2]
# The p-term of that product has 2 terms:
# -p[j, 1] + p[v, 1]
# Here it is simplified...
# -p[j, 1] + p[v, 1]
#
#
# The epsilon product with order 39: e[j, 2]*e[k, 2]*e[l, 2]
# ------------------------------------- Skipping
#
#
# The epsilon product with order 40: e[i, 2]*e[j, 2]*e[k, 2]*e[l, 2]
# ------------------------------------- Skipping
#
#
# The epsilon product with order 41: e[i, 1]*e[j, 2]*e[k, 2]*e[l, 2]
# ------------------------------------- Skipping
#
#
# The epsilon product with order 42: e[j, 1]*e[k, 2]*e[l, 2]
# The p-term of that product has 2 terms:
# -p[i, 1] + p[u, 1]
# Here it is simplified...
# -p[i, 1] + p[u, 1]
#
#
# The epsilon product with order 43: e[i, 2]*e[j, 1]*e[k, 2]*e[l, 2]
# ------------------------------------- Skipping
#
#
# The epsilon product with order 44: e[i, 1]*e[j, 1]*e[k, 2]*e[l, 2]
# The p-term of that product has 1 terms:
# -1
# Here it is simplified...
# -1
# FOUND THE CONSTANT FACTOR!!!

# %%
print(f"The final depth is {len(pExpressions)}")

print(j)
print(j, type(j))


indexSubstitution = {i: 1, j: 2, k: 3, l: 4, u: 5, v: 6}

valueSubstitution = {
    p[1, 1]: 2,
    p[1, 2]: 9,
    p[2, 1]: 9,
    p[2, 2]: 2,
    p[3, 1]: 2,
    p[3, 2]: 4,
    p[4, 1]: 10,
    p[4, 2]: 6,
    p[5, 1]: 4,
    p[5, 2]: 42,
    p[6, 1]: 9,
    p[6, 2]: 5,
}

for t in range(0, len(pExpressions)):
    print(f"\n\n-------------------------------------------- At depth {t}")
    print(f"The p-expression is:")
    evaluatedExpression = pExpressions[t].subs(indexSubstitution)  # Step 1
    print(f"{evaluatedExpression}")
    print(f"The e-expression is:")
    print(f"{eExpressions[t]}")
# Out:
# The final depth is 35
# j
# j <class 'sympy.core.symbol.Symbol'>
#
#
# -------------------------------------------- At depth 0
# The p-expression is:
# -p[3, 1]*p[4, 1]*p[5, 2]*p[6, 2] + p[3, 1]*p[4, 1]*p[5, 2]*p[j, 2] + p[3, 1]*p[4, 1]*p[6, 2]*p[i, 2] - p[3, 1]*p[4, 1]*p[i, 2]*p[j, 2] + p[3, 1]*p[4, 2]*p[5, 2]*p[6, 1] - p[3, 1]*p[4, 2]*p[5, 2]*p[j, 1] - p[3, 1]*p[4, 2]*p[6, 1]*p[j, 2] - p[3, 1]*p[4, 2]*p[6, 2]*p[i, 1] + p[3, 1]*p[4, 2]*p[6, 2]*p[j, 1] + p[3, 1]*p[4, 2]*p[i, 1]*p[j, 2] - p[3, 1]*p[5, 2]*p[6, 1]*p[i, 2] + p[3, 1]*p[5, 2]*p[6, 2]*p[i, 1] - p[3, 1]*p[5, 2]*p[i, 1]*p[j, 2] + p[3, 1]*p[5, 2]*p[i, 2]*p[j, 1] + p[3, 1]*p[6, 1]*p[i, 2]*p[j, 2] - p[3, 1]*p[6, 2]*p[i, 2]*p[j, 1] + p[3, 2]*p[4, 1]*p[5, 1]*p[6, 2] - p[3, 2]*p[4, 1]*p[5, 1]*p[j, 2] - p[3, 2]*p[4, 1]*p[6, 1]*p[i, 2] + p[3, 2]*p[4, 1]*p[6, 1]*p[j, 2] - p[3, 2]*p[4, 1]*p[6, 2]*p[j, 1] + p[3, 2]*p[4, 1]*p[i, 2]*p[j, 1] - p[3, 2]*p[4, 2]*p[5, 1]*p[6, 1] + p[3, 2]*p[4, 2]*p[5, 1]*p[j, 1] + p[3, 2]*p[4, 2]*p[6, 1]*p[i, 1] - p[3, 2]*p[4, 2]*p[i, 1]*p[j, 1] + p[3, 2]*p[5, 1]*p[6, 1]*p[i, 2] - p[3, 2]*p[5, 1]*p[6, 2]*p[i, 1] + p[3, 2]*p[5, 1]*p[i, 1]*p[j, 2] - p[3, 2]*p[5, 1]*p[i, 2]*p[j, 1] - p[3, 2]*p[6, 1]*p[i, 1]*p[j, 2] + p[3, 2]*p[6, 2]*p[i, 1]*p[j, 1] - p[4, 1]*p[5, 1]*p[6, 2]*p[i, 2] + p[4, 1]*p[5, 1]*p[i, 2]*p[j, 2] + p[4, 1]*p[5, 2]*p[6, 1]*p[i, 2] - p[4, 1]*p[5, 2]*p[6, 1]*p[j, 2] + p[4, 1]*p[5, 2]*p[6, 2]*p[j, 1] - p[4, 1]*p[5, 2]*p[i, 2]*p[j, 1] + p[4, 2]*p[5, 1]*p[6, 1]*p[j, 2] + p[4, 2]*p[5, 1]*p[6, 2]*p[i, 1] - p[4, 2]*p[5, 1]*p[6, 2]*p[j, 1] - p[4, 2]*p[5, 1]*p[i, 1]*p[j, 2] - p[4, 2]*p[5, 2]*p[6, 1]*p[i, 1] + p[4, 2]*p[5, 2]*p[i, 1]*p[j, 1] - p[5, 1]*p[6, 1]*p[i, 2]*p[j, 2] + p[5, 1]*p[6, 2]*p[i, 2]*p[j, 1] + p[5, 2]*p[6, 1]*p[i, 1]*p[j, 2] - p[5, 2]*p[6, 2]*p[i, 1]*p[j, 1]
# The e-expression is:
# []
#
#
# -------------------------------------------- At depth 1
# The p-expression is:
# p[3, 1]*p[4, 1]*p[6, 2] - p[3, 1]*p[4, 1]*p[j, 2] - p[3, 1]*p[5, 2]*p[6, 1] + p[3, 1]*p[5, 2]*p[j, 1] + p[3, 1]*p[6, 1]*p[j, 2] - p[3, 1]*p[6, 2]*p[j, 1] - p[3, 2]*p[4, 1]*p[6, 1] + p[3, 2]*p[4, 1]*p[j, 1] + p[3, 2]*p[5, 1]*p[6, 1] - p[3, 2]*p[5, 1]*p[j, 1] - p[4, 1]*p[5, 1]*p[6, 2] + p[4, 1]*p[5, 1]*p[j, 2] + p[4, 1]*p[5, 2]*p[6, 1] - p[4, 1]*p[5, 2]*p[j, 1] - p[5, 1]*p[6, 1]*p[j, 2] + p[5, 1]*p[6, 2]*p[j, 1]
# The e-expression is:
# e[i, 2]
#
#
# -------------------------------------------- At depth 2
# The p-expression is:
# -p[3, 1]*p[4, 2]*p[6, 2] + p[3, 1]*p[4, 2]*p[j, 2] + p[3, 1]*p[5, 2]*p[6, 2] - p[3, 1]*p[5, 2]*p[j, 2] + p[3, 2]*p[4, 2]*p[6, 1] - p[3, 2]*p[4, 2]*p[j, 1] - p[3, 2]*p[5, 1]*p[6, 2] + p[3, 2]*p[5, 1]*p[j, 2] - p[3, 2]*p[6, 1]*p[j, 2] + p[3, 2]*p[6, 2]*p[j, 1] + p[4, 2]*p[5, 1]*p[6, 2] - p[4, 2]*p[5, 1]*p[j, 2] - p[4, 2]*p[5, 2]*p[6, 1] + p[4, 2]*p[5, 2]*p[j, 1] + p[5, 2]*p[6, 1]*p[j, 2] - p[5, 2]*p[6, 2]*p[j, 1]
# The e-expression is:
# e[i, 1]
#
#
# -------------------------------------------- At depth 3
# The p-expression is:
# p[3, 1]*p[4, 1]*p[5, 2] - p[3, 1]*p[4, 1]*p[i, 2] - p[3, 1]*p[4, 2]*p[6, 1] + p[3, 1]*p[4, 2]*p[i, 1] - p[3, 1]*p[5, 2]*p[i, 1] + p[3, 1]*p[6, 1]*p[i, 2] - p[3, 2]*p[4, 1]*p[5, 1] + p[3, 2]*p[4, 1]*p[6, 1] + p[3, 2]*p[5, 1]*p[i, 1] - p[3, 2]*p[6, 1]*p[i, 1] + p[4, 1]*p[5, 1]*p[i, 2] - p[4, 1]*p[5, 2]*p[6, 1] + p[4, 2]*p[5, 1]*p[6, 1] - p[4, 2]*p[5, 1]*p[i, 1] - p[5, 1]*p[6, 1]*p[i, 2] + p[5, 2]*p[6, 1]*p[i, 1]
# The e-expression is:
# e[j, 2]
#
#
# -------------------------------------------- At depth 4
# The p-expression is:
# -p[3, 1]*p[4, 1] + p[3, 1]*p[6, 1] + p[4, 1]*p[5, 1] - p[5, 1]*p[6, 1]
# The e-expression is:
# e[i, 2]*e[j, 2]
#
#
# -------------------------------------------- At depth 5
# The p-expression is:
# p[3, 1]*p[4, 2] - p[3, 1]*p[5, 2] + p[3, 2]*p[5, 1] - p[3, 2]*p[6, 1] - p[4, 2]*p[5, 1] + p[5, 2]*p[6, 1]
# The e-expression is:
# e[i, 1]*e[j, 2]
#
#
# -------------------------------------------- At depth 6
# The p-expression is:
# -p[3, 1]*p[4, 2]*p[5, 2] + p[3, 1]*p[4, 2]*p[6, 2] + p[3, 1]*p[5, 2]*p[i, 2] - p[3, 1]*p[6, 2]*p[i, 2] - p[3, 2]*p[4, 1]*p[6, 2] + p[3, 2]*p[4, 1]*p[i, 2] + p[3, 2]*p[4, 2]*p[5, 1] - p[3, 2]*p[4, 2]*p[i, 1] - p[3, 2]*p[5, 1]*p[i, 2] + p[3, 2]*p[6, 2]*p[i, 1] + p[4, 1]*p[5, 2]*p[6, 2] - p[4, 1]*p[5, 2]*p[i, 2] - p[4, 2]*p[5, 1]*p[6, 2] + p[4, 2]*p[5, 2]*p[i, 1] + p[5, 1]*p[6, 2]*p[i, 2] - p[5, 2]*p[6, 2]*p[i, 1]
# The e-expression is:
# e[j, 1]
#
#
# -------------------------------------------- At depth 7
# The p-expression is:
# p[3, 1]*p[5, 2] - p[3, 1]*p[6, 2] + p[3, 2]*p[4, 1] - p[3, 2]*p[5, 1] - p[4, 1]*p[5, 2] + p[5, 1]*p[6, 2]
# The e-expression is:
# e[i, 2]*e[j, 1]
#
#
# -------------------------------------------- At depth 8
# The p-expression is:
# -p[3, 2]*p[4, 2] + p[3, 2]*p[6, 2] + p[4, 2]*p[5, 2] - p[5, 2]*p[6, 2]
# The e-expression is:
# e[i, 1]*e[j, 1]
#
#
# -------------------------------------------- At depth 9
# The p-expression is:
# p[4, 1]*p[5, 1]*p[6, 2] - p[4, 1]*p[5, 1]*p[j, 2] - p[4, 1]*p[6, 1]*p[i, 2] + p[4, 1]*p[6, 1]*p[j, 2] - p[4, 1]*p[6, 2]*p[j, 1] + p[4, 1]*p[i, 2]*p[j, 1] - p[4, 2]*p[5, 1]*p[6, 1] + p[4, 2]*p[5, 1]*p[j, 1] + p[4, 2]*p[6, 1]*p[i, 1] - p[4, 2]*p[i, 1]*p[j, 1] + p[5, 1]*p[6, 1]*p[i, 2] - p[5, 1]*p[6, 2]*p[i, 1] + p[5, 1]*p[i, 1]*p[j, 2] - p[5, 1]*p[i, 2]*p[j, 1] - p[6, 1]*p[i, 1]*p[j, 2] + p[6, 2]*p[i, 1]*p[j, 1]
# The e-expression is:
# e[k, 2]
#
#
# -------------------------------------------- At depth 10
# The p-expression is:
# -p[4, 1]*p[6, 1] + p[4, 1]*p[j, 1] + p[5, 1]*p[6, 1] - p[5, 1]*p[j, 1]
# The e-expression is:
# e[i, 2]*e[k, 2]
#
#
# -------------------------------------------- At depth 11
# The p-expression is:
# p[4, 2]*p[6, 1] - p[4, 2]*p[j, 1] - p[5, 1]*p[6, 2] + p[5, 1]*p[j, 2] - p[6, 1]*p[j, 2] + p[6, 2]*p[j, 1]
# The e-expression is:
# e[i, 1]*e[k, 2]
#
#
# -------------------------------------------- At depth 12
# The p-expression is:
# -p[4, 1]*p[5, 1] + p[4, 1]*p[6, 1] + p[5, 1]*p[i, 1] - p[6, 1]*p[i, 1]
# The e-expression is:
# e[j, 2]*e[k, 2]
#
#
# -------------------------------------------- At depth 13
# The p-expression is:
# p[5, 1] - p[6, 1]
# The e-expression is:
# e[i, 1]*e[j, 2]*e[k, 2]
#
#
# -------------------------------------------- At depth 14
# The p-expression is:
# -p[4, 1]*p[6, 2] + p[4, 1]*p[i, 2] + p[4, 2]*p[5, 1] - p[4, 2]*p[i, 1] - p[5, 1]*p[i, 2] + p[6, 2]*p[i, 1]
# The e-expression is:
# e[j, 1]*e[k, 2]
#
#
# -------------------------------------------- At depth 15
# The p-expression is:
# p[4, 1] - p[5, 1]
# The e-expression is:
# e[i, 2]*e[j, 1]*e[k, 2]
#
#
# -------------------------------------------- At depth 16
# The p-expression is:
# -p[4, 2] + p[6, 2]
# The e-expression is:
# e[i, 1]*e[j, 1]*e[k, 2]
#
#
# -------------------------------------------- At depth 17
# The p-expression is:
# -p[4, 1]*p[5, 2]*p[6, 2] + p[4, 1]*p[5, 2]*p[j, 2] + p[4, 1]*p[6, 2]*p[i, 2] - p[4, 1]*p[i, 2]*p[j, 2] + p[4, 2]*p[5, 2]*p[6, 1] - p[4, 2]*p[5, 2]*p[j, 1] - p[4, 2]*p[6, 1]*p[j, 2] - p[4, 2]*p[6, 2]*p[i, 1] + p[4, 2]*p[6, 2]*p[j, 1] + p[4, 2]*p[i, 1]*p[j, 2] - p[5, 2]*p[6, 1]*p[i, 2] + p[5, 2]*p[6, 2]*p[i, 1] - p[5, 2]*p[i, 1]*p[j, 2] + p[5, 2]*p[i, 2]*p[j, 1] + p[6, 1]*p[i, 2]*p[j, 2] - p[6, 2]*p[i, 2]*p[j, 1]
# The e-expression is:
# e[k, 1]
#
#
# -------------------------------------------- At depth 18
# The p-expression is:
# p[4, 1]*p[6, 2] - p[4, 1]*p[j, 2] - p[5, 2]*p[6, 1] + p[5, 2]*p[j, 1] + p[6, 1]*p[j, 2] - p[6, 2]*p[j, 1]
# The e-expression is:
# e[i, 2]*e[k, 1]
#
#
# -------------------------------------------- At depth 19
# The p-expression is:
# -p[4, 2]*p[6, 2] + p[4, 2]*p[j, 2] + p[5, 2]*p[6, 2] - p[5, 2]*p[j, 2]
# The e-expression is:
# e[i, 1]*e[k, 1]
#
#
# -------------------------------------------- At depth 20
# The p-expression is:
# p[4, 1]*p[5, 2] - p[4, 1]*p[i, 2] - p[4, 2]*p[6, 1] + p[4, 2]*p[i, 1] - p[5, 2]*p[i, 1] + p[6, 1]*p[i, 2]
# The e-expression is:
# e[j, 2]*e[k, 1]
#
#
# -------------------------------------------- At depth 21
# The p-expression is:
# -p[4, 1] + p[6, 1]
# The e-expression is:
# e[i, 2]*e[j, 2]*e[k, 1]
#
#
# -------------------------------------------- At depth 22
# The p-expression is:
# p[4, 2] - p[5, 2]
# The e-expression is:
# e[i, 1]*e[j, 2]*e[k, 1]
#
#
# -------------------------------------------- At depth 23
# The p-expression is:
# -p[4, 2]*p[5, 2] + p[4, 2]*p[6, 2] + p[5, 2]*p[i, 2] - p[6, 2]*p[i, 2]
# The e-expression is:
# e[j, 1]*e[k, 1]
#
#
# -------------------------------------------- At depth 24
# The p-expression is:
# p[5, 2] - p[6, 2]
# The e-expression is:
# e[i, 2]*e[j, 1]*e[k, 1]
#
#
# -------------------------------------------- At depth 25
# The p-expression is:
# p[3, 1]*p[5, 2]*p[6, 1] - p[3, 1]*p[5, 2]*p[j, 1] - p[3, 1]*p[6, 1]*p[j, 2] - p[3, 1]*p[6, 2]*p[i, 1] + p[3, 1]*p[6, 2]*p[j, 1] + p[3, 1]*p[i, 1]*p[j, 2] - p[3, 2]*p[5, 1]*p[6, 1] + p[3, 2]*p[5, 1]*p[j, 1] + p[3, 2]*p[6, 1]*p[i, 1] - p[3, 2]*p[i, 1]*p[j, 1] + p[5, 1]*p[6, 1]*p[j, 2] + p[5, 1]*p[6, 2]*p[i, 1] - p[5, 1]*p[6, 2]*p[j, 1] - p[5, 1]*p[i, 1]*p[j, 2] - p[5, 2]*p[6, 1]*p[i, 1] + p[5, 2]*p[i, 1]*p[j, 1]
# The e-expression is:
# e[l, 2]
#
#
# -------------------------------------------- At depth 26
# The p-expression is:
# -p[3, 1]*p[6, 2] + p[3, 1]*p[j, 2] + p[3, 2]*p[6, 1] - p[3, 2]*p[j, 1] + p[5, 1]*p[6, 2] - p[5, 1]*p[j, 2] - p[5, 2]*p[6, 1] + p[5, 2]*p[j, 1]
# The e-expression is:
# e[i, 1]*e[l, 2]
#
#
# -------------------------------------------- At depth 27
# The p-expression is:
# -p[3, 1]*p[6, 1] + p[3, 1]*p[i, 1] + p[5, 1]*p[6, 1] - p[5, 1]*p[i, 1]
# The e-expression is:
# e[j, 2]*e[l, 2]
#
#
# -------------------------------------------- At depth 28
# The p-expression is:
# p[3, 1] - p[5, 1]
# The e-expression is:
# e[i, 1]*e[j, 2]*e[l, 2]
#
#
# -------------------------------------------- At depth 29
# The p-expression is:
# -p[3, 1]*p[5, 2] + p[3, 1]*p[6, 2] + p[3, 2]*p[5, 1] - p[3, 2]*p[i, 1] - p[5, 1]*p[6, 2] + p[5, 2]*p[i, 1]
# The e-expression is:
# e[j, 1]*e[l, 2]
#
#
# -------------------------------------------- At depth 30
# The p-expression is:
# -p[3, 2] + p[5, 2]
# The e-expression is:
# e[i, 1]*e[j, 1]*e[l, 2]
#
#
# -------------------------------------------- At depth 31
# The p-expression is:
# -p[5, 1]*p[6, 1] + p[5, 1]*p[j, 1] + p[6, 1]*p[i, 1] - p[i, 1]*p[j, 1]
# The e-expression is:
# e[k, 2]*e[l, 2]
#
#
# -------------------------------------------- At depth 32
# The p-expression is:
# p[6, 1] - p[j, 1]
# The e-expression is:
# e[i, 1]*e[k, 2]*e[l, 2]
#
#
# -------------------------------------------- At depth 33
# The p-expression is:
# p[5, 1] - p[i, 1]
# The e-expression is:
# e[j, 1]*e[k, 2]*e[l, 2]
#
#
# -------------------------------------------- At depth 34
# The p-expression is:
# -1
# The e-expression is:
# e[i, 1]*e[j, 1]*e[k, 2]*e[l, 2]

# %%
print(f"The final depth is {len(pExpressions)}")

indexSubstitution = {i: 1, j: 2, k: 3, l: 4, u: 5, v: 6}
valueSubstitution = {
    p[1, 1]: 2,
    p[1, 2]: 9,
    p[2, 1]: 9,
    p[2, 2]: 2,
    p[3, 1]: 2,
    p[3, 2]: 4,
    p[4, 1]: 10,
    p[4, 2]: 6,
    p[5, 1]: 4,
    p[5, 2]: 42,
    p[6, 1]: 9,
    p[6, 2]: 5,
}

for t in range(len(pExpressions)):
    print(f"\n\n-------------------------------------------- At depth {t}")
    
    # Substitute index symbols first
    partially_substituted = pExpressions[t].subs(indexSubstitution)
    print(f"After index substitution: {partially_substituted}")
    
    # Check which indexed terms are still present
    indexed_terms = [a for a in partially_substituted.atoms() if hasattr(a, 'func') and a.func == p.func]
    print(f"Indexed terms found: {indexed_terms}")
    
    # Substitute indexed terms with values
    evaluatedExpression = partially_substituted.subs(valueSubstitution)
    print(f"After value substitution: {evaluatedExpression}")
    
    # Optionally, evaluate numerically if needed:
    numeric_val = evaluatedExpression.evalf()
    print(f"Numeric evaluation: {numeric_val}")

    print(f"The e-expression is:")
    print(f"{eExpressions[t]}")
# Out:
# The final depth is 35
#
#
# -------------------------------------------- At depth 0
# After index substitution: -p[3, 1]*p[4, 1]*p[5, 2]*p[6, 2] + p[3, 1]*p[4, 1]*p[5, 2]*p[j, 2] + p[3, 1]*p[4, 1]*p[6, 2]*p[i, 2] - p[3, 1]*p[4, 1]*p[i, 2]*p[j, 2] + p[3, 1]*p[4, 2]*p[5, 2]*p[6, 1] - p[3, 1]*p[4, 2]*p[5, 2]*p[j, 1] - p[3, 1]*p[4, 2]*p[6, 1]*p[j, 2] - p[3, 1]*p[4, 2]*p[6, 2]*p[i, 1] + p[3, 1]*p[4, 2]*p[6, 2]*p[j, 1] + p[3, 1]*p[4, 2]*p[i, 1]*p[j, 2] - p[3, 1]*p[5, 2]*p[6, 1]*p[i, 2] + p[3, 1]*p[5, 2]*p[6, 2]*p[i, 1] - p[3, 1]*p[5, 2]*p[i, 1]*p[j, 2] + p[3, 1]*p[5, 2]*p[i, 2]*p[j, 1] + p[3, 1]*p[6, 1]*p[i, 2]*p[j, 2] - p[3, 1]*p[6, 2]*p[i, 2]*p[j, 1] + p[3, 2]*p[4, 1]*p[5, 1]*p[6, 2] - p[3, 2]*p[4, 1]*p[5, 1]*p[j, 2] - p[3, 2]*p[4, 1]*p[6, 1]*p[i, 2] + p[3, 2]*p[4, 1]*p[6, 1]*p[j, 2] - p[3, 2]*p[4, 1]*p[6, 2]*p[j, 1] + p[3, 2]*p[4, 1]*p[i, 2]*p[j, 1] - p[3, 2]*p[4, 2]*p[5, 1]*p[6, 1] + p[3, 2]*p[4, 2]*p[5, 1]*p[j, 1] + p[3, 2]*p[4, 2]*p[6, 1]*p[i, 1] - p[3, 2]*p[4, 2]*p[i, 1]*p[j, 1] + p[3, 2]*p[5, 1]*p[6, 1]*p[i, 2] - p[3, 2]*p[5, 1]*p[6, 2]*p[i, 1] + p[3, 2]*p[5, 1]*p[i, 1]*p[j, 2] - p[3, 2]*p[5, 1]*p[i, 2]*p[j, 1] - p[3, 2]*p[6, 1]*p[i, 1]*p[j, 2] + p[3, 2]*p[6, 2]*p[i, 1]*p[j, 1] - p[4, 1]*p[5, 1]*p[6, 2]*p[i, 2] + p[4, 1]*p[5, 1]*p[i, 2]*p[j, 2] + p[4, 1]*p[5, 2]*p[6, 1]*p[i, 2] - p[4, 1]*p[5, 2]*p[6, 1]*p[j, 2] + p[4, 1]*p[5, 2]*p[6, 2]*p[j, 1] - p[4, 1]*p[5, 2]*p[i, 2]*p[j, 1] + p[4, 2]*p[5, 1]*p[6, 1]*p[j, 2] + p[4, 2]*p[5, 1]*p[6, 2]*p[i, 1] - p[4, 2]*p[5, 1]*p[6, 2]*p[j, 1] - p[4, 2]*p[5, 1]*p[i, 1]*p[j, 2] - p[4, 2]*p[5, 2]*p[6, 1]*p[i, 1] + p[4, 2]*p[5, 2]*p[i, 1]*p[j, 1] - p[5, 1]*p[6, 1]*p[i, 2]*p[j, 2] + p[5, 1]*p[6, 2]*p[i, 2]*p[j, 1] + p[5, 2]*p[6, 1]*p[i, 1]*p[j, 2] - p[5, 2]*p[6, 2]*p[i, 1]*p[j, 1]
# Indexed terms found: []
# After value substitution: -p[3, 1]*p[4, 1]*p[5, 2]*p[6, 2] + p[3, 1]*p[4, 1]*p[5, 2]*p[j, 2] + p[3, 1]*p[4, 1]*p[6, 2]*p[i, 2] - p[3, 1]*p[4, 1]*p[i, 2]*p[j, 2] + p[3, 1]*p[4, 2]*p[5, 2]*p[6, 1] - p[3, 1]*p[4, 2]*p[5, 2]*p[j, 1] - p[3, 1]*p[4, 2]*p[6, 1]*p[j, 2] - p[3, 1]*p[4, 2]*p[6, 2]*p[i, 1] + p[3, 1]*p[4, 2]*p[6, 2]*p[j, 1] + p[3, 1]*p[4, 2]*p[i, 1]*p[j, 2] - p[3, 1]*p[5, 2]*p[6, 1]*p[i, 2] + p[3, 1]*p[5, 2]*p[6, 2]*p[i, 1] - p[3, 1]*p[5, 2]*p[i, 1]*p[j, 2] + p[3, 1]*p[5, 2]*p[i, 2]*p[j, 1] + p[3, 1]*p[6, 1]*p[i, 2]*p[j, 2] - p[3, 1]*p[6, 2]*p[i, 2]*p[j, 1] + p[3, 2]*p[4, 1]*p[5, 1]*p[6, 2] - p[3, 2]*p[4, 1]*p[5, 1]*p[j, 2] - p[3, 2]*p[4, 1]*p[6, 1]*p[i, 2] + p[3, 2]*p[4, 1]*p[6, 1]*p[j, 2] - p[3, 2]*p[4, 1]*p[6, 2]*p[j, 1] + p[3, 2]*p[4, 1]*p[i, 2]*p[j, 1] - p[3, 2]*p[4, 2]*p[5, 1]*p[6, 1] + p[3, 2]*p[4, 2]*p[5, 1]*p[j, 1] + p[3, 2]*p[4, 2]*p[6, 1]*p[i, 1] - p[3, 2]*p[4, 2]*p[i, 1]*p[j, 1] + p[3, 2]*p[5, 1]*p[6, 1]*p[i, 2] - p[3, 2]*p[5, 1]*p[6, 2]*p[i, 1] + p[3, 2]*p[5, 1]*p[i, 1]*p[j, 2] - p[3, 2]*p[5, 1]*p[i, 2]*p[j, 1] - p[3, 2]*p[6, 1]*p[i, 1]*p[j, 2] + p[3, 2]*p[6, 2]*p[i, 1]*p[j, 1] - p[4, 1]*p[5, 1]*p[6, 2]*p[i, 2] + p[4, 1]*p[5, 1]*p[i, 2]*p[j, 2] + p[4, 1]*p[5, 2]*p[6, 1]*p[i, 2] - p[4, 1]*p[5, 2]*p[6, 1]*p[j, 2] + p[4, 1]*p[5, 2]*p[6, 2]*p[j, 1] - p[4, 1]*p[5, 2]*p[i, 2]*p[j, 1] + p[4, 2]*p[5, 1]*p[6, 1]*p[j, 2] + p[4, 2]*p[5, 1]*p[6, 2]*p[i, 1] - p[4, 2]*p[5, 1]*p[6, 2]*p[j, 1] - p[4, 2]*p[5, 1]*p[i, 1]*p[j, 2] - p[4, 2]*p[5, 2]*p[6, 1]*p[i, 1] + p[4, 2]*p[5, 2]*p[i, 1]*p[j, 1] - p[5, 1]*p[6, 1]*p[i, 2]*p[j, 2] + p[5, 1]*p[6, 2]*p[i, 2]*p[j, 1] + p[5, 2]*p[6, 1]*p[i, 1]*p[j, 2] - p[5, 2]*p[6, 2]*p[i, 1]*p[j, 1]
# Numeric evaluation: -p[3, 1]*p[4, 1]*p[5, 2]*p[6, 2] + p[3, 1]*p[4, 1]*p[5, 2]*p[j, 2] + p[3, 1]*p[4, 1]*p[6, 2]*p[i, 2] - p[3, 1]*p[4, 1]*p[i, 2]*p[j, 2] + p[3, 1]*p[4, 2]*p[5, 2]*p[6, 1] - p[3, 1]*p[4, 2]*p[5, 2]*p[j, 1] - p[3, 1]*p[4, 2]*p[6, 1]*p[j, 2] - p[3, 1]*p[4, 2]*p[6, 2]*p[i, 1] + p[3, 1]*p[4, 2]*p[6, 2]*p[j, 1] + p[3, 1]*p[4, 2]*p[i, 1]*p[j, 2] - p[3, 1]*p[5, 2]*p[6, 1]*p[i, 2] + p[3, 1]*p[5, 2]*p[6, 2]*p[i, 1] - p[3, 1]*p[5, 2]*p[i, 1]*p[j, 2] + p[3, 1]*p[5, 2]*p[i, 2]*p[j, 1] + p[3, 1]*p[6, 1]*p[i, 2]*p[j, 2] - p[3, 1]*p[6, 2]*p[i, 2]*p[j, 1] + p[3, 2]*p[4, 1]*p[5, 1]*p[6, 2] - p[3, 2]*p[4, 1]*p[5, 1]*p[j, 2] - p[3, 2]*p[4, 1]*p[6, 1]*p[i, 2] + p[3, 2]*p[4, 1]*p[6, 1]*p[j, 2] - p[3, 2]*p[4, 1]*p[6, 2]*p[j, 1] + p[3, 2]*p[4, 1]*p[i, 2]*p[j, 1] - p[3, 2]*p[4, 2]*p[5, 1]*p[6, 1] + p[3, 2]*p[4, 2]*p[5, 1]*p[j, 1] + p[3, 2]*p[4, 2]*p[6, 1]*p[i, 1] - p[3, 2]*p[4, 2]*p[i, 1]*p[j, 1] + p[3, 2]*p[5, 1]*p[6, 1]*p[i, 2] - p[3, 2]*p[5, 1]*p[6, 2]*p[i, 1] + p[3, 2]*p[5, 1]*p[i, 1]*p[j, 2] - p[3, 2]*p[5, 1]*p[i, 2]*p[j, 1] - p[3, 2]*p[6, 1]*p[i, 1]*p[j, 2] + p[3, 2]*p[6, 2]*p[i, 1]*p[j, 1] - p[4, 1]*p[5, 1]*p[6, 2]*p[i, 2] + p[4, 1]*p[5, 1]*p[i, 2]*p[j, 2] + p[4, 1]*p[5, 2]*p[6, 1]*p[i, 2] - p[4, 1]*p[5, 2]*p[6, 1]*p[j, 2] + p[4, 1]*p[5, 2]*p[6, 2]*p[j, 1] - p[4, 1]*p[5, 2]*p[i, 2]*p[j, 1] + p[4, 2]*p[5, 1]*p[6, 1]*p[j, 2] + p[4, 2]*p[5, 1]*p[6, 2]*p[i, 1] - p[4, 2]*p[5, 1]*p[6, 2]*p[j, 1] - p[4, 2]*p[5, 1]*p[i, 1]*p[j, 2] - p[4, 2]*p[5, 2]*p[6, 1]*p[i, 1] + p[4, 2]*p[5, 2]*p[i, 1]*p[j, 1] - p[5, 1]*p[6, 1]*p[i, 2]*p[j, 2] + p[5, 1]*p[6, 2]*p[i, 2]*p[j, 1] + p[5, 2]*p[6, 1]*p[i, 1]*p[j, 2] - p[5, 2]*p[6, 2]*p[i, 1]*p[j, 1]
# The e-expression is:
# []
#
#
# -------------------------------------------- At depth 1
# After index substitution: p[3, 1]*p[4, 1]*p[6, 2] - p[3, 1]*p[4, 1]*p[j, 2] - p[3, 1]*p[5, 2]*p[6, 1] + p[3, 1]*p[5, 2]*p[j, 1] + p[3, 1]*p[6, 1]*p[j, 2] - p[3, 1]*p[6, 2]*p[j, 1] - p[3, 2]*p[4, 1]*p[6, 1] + p[3, 2]*p[4, 1]*p[j, 1] + p[3, 2]*p[5, 1]*p[6, 1] - p[3, 2]*p[5, 1]*p[j, 1] - p[4, 1]*p[5, 1]*p[6, 2] + p[4, 1]*p[5, 1]*p[j, 2] + p[4, 1]*p[5, 2]*p[6, 1] - p[4, 1]*p[5, 2]*p[j, 1] - p[5, 1]*p[6, 1]*p[j, 2] + p[5, 1]*p[6, 2]*p[j, 1]
# Indexed terms found: []
# After value substitution: p[3, 1]*p[4, 1]*p[6, 2] - p[3, 1]*p[4, 1]*p[j, 2] - p[3, 1]*p[5, 2]*p[6, 1] + p[3, 1]*p[5, 2]*p[j, 1] + p[3, 1]*p[6, 1]*p[j, 2] - p[3, 1]*p[6, 2]*p[j, 1] - p[3, 2]*p[4, 1]*p[6, 1] + p[3, 2]*p[4, 1]*p[j, 1] + p[3, 2]*p[5, 1]*p[6, 1] - p[3, 2]*p[5, 1]*p[j, 1] - p[4, 1]*p[5, 1]*p[6, 2] + p[4, 1]*p[5, 1]*p[j, 2] + p[4, 1]*p[5, 2]*p[6, 1] - p[4, 1]*p[5, 2]*p[j, 1] - p[5, 1]*p[6, 1]*p[j, 2] + p[5, 1]*p[6, 2]*p[j, 1]
# Numeric evaluation: p[3, 1]*p[4, 1]*p[6, 2] - p[3, 1]*p[4, 1]*p[j, 2] - p[3, 1]*p[5, 2]*p[6, 1] + p[3, 1]*p[5, 2]*p[j, 1] + p[3, 1]*p[6, 1]*p[j, 2] - p[3, 1]*p[6, 2]*p[j, 1] - p[3, 2]*p[4, 1]*p[6, 1] + p[3, 2]*p[4, 1]*p[j, 1] + p[3, 2]*p[5, 1]*p[6, 1] - p[3, 2]*p[5, 1]*p[j, 1] - p[4, 1]*p[5, 1]*p[6, 2] + p[4, 1]*p[5, 1]*p[j, 2] + p[4, 1]*p[5, 2]*p[6, 1] - p[4, 1]*p[5, 2]*p[j, 1] - p[5, 1]*p[6, 1]*p[j, 2] + p[5, 1]*p[6, 2]*p[j, 1]
# The e-expression is:
# e[i, 2]
#
#
# -------------------------------------------- At depth 2
# After index substitution: -p[3, 1]*p[4, 2]*p[6, 2] + p[3, 1]*p[4, 2]*p[j, 2] + p[3, 1]*p[5, 2]*p[6, 2] - p[3, 1]*p[5, 2]*p[j, 2] + p[3, 2]*p[4, 2]*p[6, 1] - p[3, 2]*p[4, 2]*p[j, 1] - p[3, 2]*p[5, 1]*p[6, 2] + p[3, 2]*p[5, 1]*p[j, 2] - p[3, 2]*p[6, 1]*p[j, 2] + p[3, 2]*p[6, 2]*p[j, 1] + p[4, 2]*p[5, 1]*p[6, 2] - p[4, 2]*p[5, 1]*p[j, 2] - p[4, 2]*p[5, 2]*p[6, 1] + p[4, 2]*p[5, 2]*p[j, 1] + p[5, 2]*p[6, 1]*p[j, 2] - p[5, 2]*p[6, 2]*p[j, 1]
# Indexed terms found: []
# After value substitution: -p[3, 1]*p[4, 2]*p[6, 2] + p[3, 1]*p[4, 2]*p[j, 2] + p[3, 1]*p[5, 2]*p[6, 2] - p[3, 1]*p[5, 2]*p[j, 2] + p[3, 2]*p[4, 2]*p[6, 1] - p[3, 2]*p[4, 2]*p[j, 1] - p[3, 2]*p[5, 1]*p[6, 2] + p[3, 2]*p[5, 1]*p[j, 2] - p[3, 2]*p[6, 1]*p[j, 2] + p[3, 2]*p[6, 2]*p[j, 1] + p[4, 2]*p[5, 1]*p[6, 2] - p[4, 2]*p[5, 1]*p[j, 2] - p[4, 2]*p[5, 2]*p[6, 1] + p[4, 2]*p[5, 2]*p[j, 1] + p[5, 2]*p[6, 1]*p[j, 2] - p[5, 2]*p[6, 2]*p[j, 1]
# Numeric evaluation: -p[3, 1]*p[4, 2]*p[6, 2] + p[3, 1]*p[4, 2]*p[j, 2] + p[3, 1]*p[5, 2]*p[6, 2] - p[3, 1]*p[5, 2]*p[j, 2] + p[3, 2]*p[4, 2]*p[6, 1] - p[3, 2]*p[4, 2]*p[j, 1] - p[3, 2]*p[5, 1]*p[6, 2] + p[3, 2]*p[5, 1]*p[j, 2] - p[3, 2]*p[6, 1]*p[j, 2] + p[3, 2]*p[6, 2]*p[j, 1] + p[4, 2]*p[5, 1]*p[6, 2] - p[4, 2]*p[5, 1]*p[j, 2] - p[4, 2]*p[5, 2]*p[6, 1] + p[4, 2]*p[5, 2]*p[j, 1] + p[5, 2]*p[6, 1]*p[j, 2] - p[5, 2]*p[6, 2]*p[j, 1]
# The e-expression is:
# e[i, 1]
#
#
# -------------------------------------------- At depth 3
# After index substitution: p[3, 1]*p[4, 1]*p[5, 2] - p[3, 1]*p[4, 1]*p[i, 2] - p[3, 1]*p[4, 2]*p[6, 1] + p[3, 1]*p[4, 2]*p[i, 1] - p[3, 1]*p[5, 2]*p[i, 1] + p[3, 1]*p[6, 1]*p[i, 2] - p[3, 2]*p[4, 1]*p[5, 1] + p[3, 2]*p[4, 1]*p[6, 1] + p[3, 2]*p[5, 1]*p[i, 1] - p[3, 2]*p[6, 1]*p[i, 1] + p[4, 1]*p[5, 1]*p[i, 2] - p[4, 1]*p[5, 2]*p[6, 1] + p[4, 2]*p[5, 1]*p[6, 1] - p[4, 2]*p[5, 1]*p[i, 1] - p[5, 1]*p[6, 1]*p[i, 2] + p[5, 2]*p[6, 1]*p[i, 1]
# Indexed terms found: []
# After value substitution: p[3, 1]*p[4, 1]*p[5, 2] - p[3, 1]*p[4, 1]*p[i, 2] - p[3, 1]*p[4, 2]*p[6, 1] + p[3, 1]*p[4, 2]*p[i, 1] - p[3, 1]*p[5, 2]*p[i, 1] + p[3, 1]*p[6, 1]*p[i, 2] - p[3, 2]*p[4, 1]*p[5, 1] + p[3, 2]*p[4, 1]*p[6, 1] + p[3, 2]*p[5, 1]*p[i, 1] - p[3, 2]*p[6, 1]*p[i, 1] + p[4, 1]*p[5, 1]*p[i, 2] - p[4, 1]*p[5, 2]*p[6, 1] + p[4, 2]*p[5, 1]*p[6, 1] - p[4, 2]*p[5, 1]*p[i, 1] - p[5, 1]*p[6, 1]*p[i, 2] + p[5, 2]*p[6, 1]*p[i, 1]
# Numeric evaluation: p[3, 1]*p[4, 1]*p[5, 2] - p[3, 1]*p[4, 1]*p[i, 2] - p[3, 1]*p[4, 2]*p[6, 1] + p[3, 1]*p[4, 2]*p[i, 1] - p[3, 1]*p[5, 2]*p[i, 1] + p[3, 1]*p[6, 1]*p[i, 2] - p[3, 2]*p[4, 1]*p[5, 1] + p[3, 2]*p[4, 1]*p[6, 1] + p[3, 2]*p[5, 1]*p[i, 1] - p[3, 2]*p[6, 1]*p[i, 1] + p[4, 1]*p[5, 1]*p[i, 2] - p[4, 1]*p[5, 2]*p[6, 1] + p[4, 2]*p[5, 1]*p[6, 1] - p[4, 2]*p[5, 1]*p[i, 1] - p[5, 1]*p[6, 1]*p[i, 2] + p[5, 2]*p[6, 1]*p[i, 1]
# The e-expression is:
# e[j, 2]
#
#
# -------------------------------------------- At depth 4
# After index substitution: -p[3, 1]*p[4, 1] + p[3, 1]*p[6, 1] + p[4, 1]*p[5, 1] - p[5, 1]*p[6, 1]
# Indexed terms found: []
# After value substitution: -p[3, 1]*p[4, 1] + p[3, 1]*p[6, 1] + p[4, 1]*p[5, 1] - p[5, 1]*p[6, 1]
# Numeric evaluation: -p[3, 1]*p[4, 1] + p[3, 1]*p[6, 1] + p[4, 1]*p[5, 1] - p[5, 1]*p[6, 1]
# The e-expression is:
# e[i, 2]*e[j, 2]
#
#
# -------------------------------------------- At depth 5
# After index substitution: p[3, 1]*p[4, 2] - p[3, 1]*p[5, 2] + p[3, 2]*p[5, 1] - p[3, 2]*p[6, 1] - p[4, 2]*p[5, 1] + p[5, 2]*p[6, 1]
# Indexed terms found: []
# After value substitution: p[3, 1]*p[4, 2] - p[3, 1]*p[5, 2] + p[3, 2]*p[5, 1] - p[3, 2]*p[6, 1] - p[4, 2]*p[5, 1] + p[5, 2]*p[6, 1]
# Numeric evaluation: p[3, 1]*p[4, 2] - p[3, 1]*p[5, 2] + p[3, 2]*p[5, 1] - p[3, 2]*p[6, 1] - p[4, 2]*p[5, 1] + p[5, 2]*p[6, 1]
# The e-expression is:
# e[i, 1]*e[j, 2]
#
#
# -------------------------------------------- At depth 6
# After index substitution: -p[3, 1]*p[4, 2]*p[5, 2] + p[3, 1]*p[4, 2]*p[6, 2] + p[3, 1]*p[5, 2]*p[i, 2] - p[3, 1]*p[6, 2]*p[i, 2] - p[3, 2]*p[4, 1]*p[6, 2] + p[3, 2]*p[4, 1]*p[i, 2] + p[3, 2]*p[4, 2]*p[5, 1] - p[3, 2]*p[4, 2]*p[i, 1] - p[3, 2]*p[5, 1]*p[i, 2] + p[3, 2]*p[6, 2]*p[i, 1] + p[4, 1]*p[5, 2]*p[6, 2] - p[4, 1]*p[5, 2]*p[i, 2] - p[4, 2]*p[5, 1]*p[6, 2] + p[4, 2]*p[5, 2]*p[i, 1] + p[5, 1]*p[6, 2]*p[i, 2] - p[5, 2]*p[6, 2]*p[i, 1]
# Indexed terms found: []
# After value substitution: -p[3, 1]*p[4, 2]*p[5, 2] + p[3, 1]*p[4, 2]*p[6, 2] + p[3, 1]*p[5, 2]*p[i, 2] - p[3, 1]*p[6, 2]*p[i, 2] - p[3, 2]*p[4, 1]*p[6, 2] + p[3, 2]*p[4, 1]*p[i, 2] + p[3, 2]*p[4, 2]*p[5, 1] - p[3, 2]*p[4, 2]*p[i, 1] - p[3, 2]*p[5, 1]*p[i, 2] + p[3, 2]*p[6, 2]*p[i, 1] + p[4, 1]*p[5, 2]*p[6, 2] - p[4, 1]*p[5, 2]*p[i, 2] - p[4, 2]*p[5, 1]*p[6, 2] + p[4, 2]*p[5, 2]*p[i, 1] + p[5, 1]*p[6, 2]*p[i, 2] - p[5, 2]*p[6, 2]*p[i, 1]
# Numeric evaluation: -p[3, 1]*p[4, 2]*p[5, 2] + p[3, 1]*p[4, 2]*p[6, 2] + p[3, 1]*p[5, 2]*p[i, 2] - p[3, 1]*p[6, 2]*p[i, 2] - p[3, 2]*p[4, 1]*p[6, 2] + p[3, 2]*p[4, 1]*p[i, 2] + p[3, 2]*p[4, 2]*p[5, 1] - p[3, 2]*p[4, 2]*p[i, 1] - p[3, 2]*p[5, 1]*p[i, 2] + p[3, 2]*p[6, 2]*p[i, 1] + p[4, 1]*p[5, 2]*p[6, 2] - p[4, 1]*p[5, 2]*p[i, 2] - p[4, 2]*p[5, 1]*p[6, 2] + p[4, 2]*p[5, 2]*p[i, 1] + p[5, 1]*p[6, 2]*p[i, 2] - p[5, 2]*p[6, 2]*p[i, 1]
# The e-expression is:
# e[j, 1]
#
#
# -------------------------------------------- At depth 7
# After index substitution: p[3, 1]*p[5, 2] - p[3, 1]*p[6, 2] + p[3, 2]*p[4, 1] - p[3, 2]*p[5, 1] - p[4, 1]*p[5, 2] + p[5, 1]*p[6, 2]
# Indexed terms found: []
# After value substitution: p[3, 1]*p[5, 2] - p[3, 1]*p[6, 2] + p[3, 2]*p[4, 1] - p[3, 2]*p[5, 1] - p[4, 1]*p[5, 2] + p[5, 1]*p[6, 2]
# Numeric evaluation: p[3, 1]*p[5, 2] - p[3, 1]*p[6, 2] + p[3, 2]*p[4, 1] - p[3, 2]*p[5, 1] - p[4, 1]*p[5, 2] + p[5, 1]*p[6, 2]
# The e-expression is:
# e[i, 2]*e[j, 1]
#
#
# -------------------------------------------- At depth 8
# After index substitution: -p[3, 2]*p[4, 2] + p[3, 2]*p[6, 2] + p[4, 2]*p[5, 2] - p[5, 2]*p[6, 2]
# Indexed terms found: []
# After value substitution: -p[3, 2]*p[4, 2] + p[3, 2]*p[6, 2] + p[4, 2]*p[5, 2] - p[5, 2]*p[6, 2]
# Numeric evaluation: -p[3, 2]*p[4, 2] + p[3, 2]*p[6, 2] + p[4, 2]*p[5, 2] - p[5, 2]*p[6, 2]
# The e-expression is:
# e[i, 1]*e[j, 1]
#
#
# -------------------------------------------- At depth 9
# After index substitution: p[4, 1]*p[5, 1]*p[6, 2] - p[4, 1]*p[5, 1]*p[j, 2] - p[4, 1]*p[6, 1]*p[i, 2] + p[4, 1]*p[6, 1]*p[j, 2] - p[4, 1]*p[6, 2]*p[j, 1] + p[4, 1]*p[i, 2]*p[j, 1] - p[4, 2]*p[5, 1]*p[6, 1] + p[4, 2]*p[5, 1]*p[j, 1] + p[4, 2]*p[6, 1]*p[i, 1] - p[4, 2]*p[i, 1]*p[j, 1] + p[5, 1]*p[6, 1]*p[i, 2] - p[5, 1]*p[6, 2]*p[i, 1] + p[5, 1]*p[i, 1]*p[j, 2] - p[5, 1]*p[i, 2]*p[j, 1] - p[6, 1]*p[i, 1]*p[j, 2] + p[6, 2]*p[i, 1]*p[j, 1]
# Indexed terms found: []
# After value substitution: p[4, 1]*p[5, 1]*p[6, 2] - p[4, 1]*p[5, 1]*p[j, 2] - p[4, 1]*p[6, 1]*p[i, 2] + p[4, 1]*p[6, 1]*p[j, 2] - p[4, 1]*p[6, 2]*p[j, 1] + p[4, 1]*p[i, 2]*p[j, 1] - p[4, 2]*p[5, 1]*p[6, 1] + p[4, 2]*p[5, 1]*p[j, 1] + p[4, 2]*p[6, 1]*p[i, 1] - p[4, 2]*p[i, 1]*p[j, 1] + p[5, 1]*p[6, 1]*p[i, 2] - p[5, 1]*p[6, 2]*p[i, 1] + p[5, 1]*p[i, 1]*p[j, 2] - p[5, 1]*p[i, 2]*p[j, 1] - p[6, 1]*p[i, 1]*p[j, 2] + p[6, 2]*p[i, 1]*p[j, 1]
# Numeric evaluation: p[4, 1]*p[5, 1]*p[6, 2] - p[4, 1]*p[5, 1]*p[j, 2] - p[4, 1]*p[6, 1]*p[i, 2] + p[4, 1]*p[6, 1]*p[j, 2] - p[4, 1]*p[6, 2]*p[j, 1] + p[4, 1]*p[i, 2]*p[j, 1] - p[4, 2]*p[5, 1]*p[6, 1] + p[4, 2]*p[5, 1]*p[j, 1] + p[4, 2]*p[6, 1]*p[i, 1] - p[4, 2]*p[i, 1]*p[j, 1] + p[5, 1]*p[6, 1]*p[i, 2] - p[5, 1]*p[6, 2]*p[i, 1] + p[5, 1]*p[i, 1]*p[j, 2] - p[5, 1]*p[i, 2]*p[j, 1] - p[6, 1]*p[i, 1]*p[j, 2] + p[6, 2]*p[i, 1]*p[j, 1]
# The e-expression is:
# e[k, 2]
#
#
# -------------------------------------------- At depth 10
# After index substitution: -p[4, 1]*p[6, 1] + p[4, 1]*p[j, 1] + p[5, 1]*p[6, 1] - p[5, 1]*p[j, 1]
# Indexed terms found: []
# After value substitution: -p[4, 1]*p[6, 1] + p[4, 1]*p[j, 1] + p[5, 1]*p[6, 1] - p[5, 1]*p[j, 1]
# Numeric evaluation: -p[4, 1]*p[6, 1] + p[4, 1]*p[j, 1] + p[5, 1]*p[6, 1] - p[5, 1]*p[j, 1]
# The e-expression is:
# e[i, 2]*e[k, 2]
#
#
# -------------------------------------------- At depth 11
# After index substitution: p[4, 2]*p[6, 1] - p[4, 2]*p[j, 1] - p[5, 1]*p[6, 2] + p[5, 1]*p[j, 2] - p[6, 1]*p[j, 2] + p[6, 2]*p[j, 1]
# Indexed terms found: []
# After value substitution: p[4, 2]*p[6, 1] - p[4, 2]*p[j, 1] - p[5, 1]*p[6, 2] + p[5, 1]*p[j, 2] - p[6, 1]*p[j, 2] + p[6, 2]*p[j, 1]
# Numeric evaluation: p[4, 2]*p[6, 1] - p[4, 2]*p[j, 1] - p[5, 1]*p[6, 2] + p[5, 1]*p[j, 2] - p[6, 1]*p[j, 2] + p[6, 2]*p[j, 1]
# The e-expression is:
# e[i, 1]*e[k, 2]
#
#
# -------------------------------------------- At depth 12
# After index substitution: -p[4, 1]*p[5, 1] + p[4, 1]*p[6, 1] + p[5, 1]*p[i, 1] - p[6, 1]*p[i, 1]
# Indexed terms found: []
# After value substitution: -p[4, 1]*p[5, 1] + p[4, 1]*p[6, 1] + p[5, 1]*p[i, 1] - p[6, 1]*p[i, 1]
# Numeric evaluation: -p[4, 1]*p[5, 1] + p[4, 1]*p[6, 1] + p[5, 1]*p[i, 1] - p[6, 1]*p[i, 1]
# The e-expression is:
# e[j, 2]*e[k, 2]
#
#
# -------------------------------------------- At depth 13
# After index substitution: p[5, 1] - p[6, 1]
# Indexed terms found: []
# After value substitution: p[5, 1] - p[6, 1]
# Numeric evaluation: p[5, 1] - p[6, 1]
# The e-expression is:
# e[i, 1]*e[j, 2]*e[k, 2]
#
#
# -------------------------------------------- At depth 14
# After index substitution: -p[4, 1]*p[6, 2] + p[4, 1]*p[i, 2] + p[4, 2]*p[5, 1] - p[4, 2]*p[i, 1] - p[5, 1]*p[i, 2] + p[6, 2]*p[i, 1]
# Indexed terms found: []
# After value substitution: -p[4, 1]*p[6, 2] + p[4, 1]*p[i, 2] + p[4, 2]*p[5, 1] - p[4, 2]*p[i, 1] - p[5, 1]*p[i, 2] + p[6, 2]*p[i, 1]
# Numeric evaluation: -p[4, 1]*p[6, 2] + p[4, 1]*p[i, 2] + p[4, 2]*p[5, 1] - p[4, 2]*p[i, 1] - p[5, 1]*p[i, 2] + p[6, 2]*p[i, 1]
# The e-expression is:
# e[j, 1]*e[k, 2]
#
#
# -------------------------------------------- At depth 15
# After index substitution: p[4, 1] - p[5, 1]
# Indexed terms found: []
# After value substitution: p[4, 1] - p[5, 1]
# Numeric evaluation: p[4, 1] - p[5, 1]
# The e-expression is:
# e[i, 2]*e[j, 1]*e[k, 2]
#
#
# -------------------------------------------- At depth 16
# After index substitution: -p[4, 2] + p[6, 2]
# Indexed terms found: []
# After value substitution: -p[4, 2] + p[6, 2]
# Numeric evaluation: -p[4, 2] + p[6, 2]
# The e-expression is:
# e[i, 1]*e[j, 1]*e[k, 2]
#
#
# -------------------------------------------- At depth 17
# After index substitution: -p[4, 1]*p[5, 2]*p[6, 2] + p[4, 1]*p[5, 2]*p[j, 2] + p[4, 1]*p[6, 2]*p[i, 2] - p[4, 1]*p[i, 2]*p[j, 2] + p[4, 2]*p[5, 2]*p[6, 1] - p[4, 2]*p[5, 2]*p[j, 1] - p[4, 2]*p[6, 1]*p[j, 2] - p[4, 2]*p[6, 2]*p[i, 1] + p[4, 2]*p[6, 2]*p[j, 1] + p[4, 2]*p[i, 1]*p[j, 2] - p[5, 2]*p[6, 1]*p[i, 2] + p[5, 2]*p[6, 2]*p[i, 1] - p[5, 2]*p[i, 1]*p[j, 2] + p[5, 2]*p[i, 2]*p[j, 1] + p[6, 1]*p[i, 2]*p[j, 2] - p[6, 2]*p[i, 2]*p[j, 1]
# Indexed terms found: []
# After value substitution: -p[4, 1]*p[5, 2]*p[6, 2] + p[4, 1]*p[5, 2]*p[j, 2] + p[4, 1]*p[6, 2]*p[i, 2] - p[4, 1]*p[i, 2]*p[j, 2] + p[4, 2]*p[5, 2]*p[6, 1] - p[4, 2]*p[5, 2]*p[j, 1] - p[4, 2]*p[6, 1]*p[j, 2] - p[4, 2]*p[6, 2]*p[i, 1] + p[4, 2]*p[6, 2]*p[j, 1] + p[4, 2]*p[i, 1]*p[j, 2] - p[5, 2]*p[6, 1]*p[i, 2] + p[5, 2]*p[6, 2]*p[i, 1] - p[5, 2]*p[i, 1]*p[j, 2] + p[5, 2]*p[i, 2]*p[j, 1] + p[6, 1]*p[i, 2]*p[j, 2] - p[6, 2]*p[i, 2]*p[j, 1]
# Numeric evaluation: -p[4, 1]*p[5, 2]*p[6, 2] + p[4, 1]*p[5, 2]*p[j, 2] + p[4, 1]*p[6, 2]*p[i, 2] - p[4, 1]*p[i, 2]*p[j, 2] + p[4, 2]*p[5, 2]*p[6, 1] - p[4, 2]*p[5, 2]*p[j, 1] - p[4, 2]*p[6, 1]*p[j, 2] - p[4, 2]*p[6, 2]*p[i, 1] + p[4, 2]*p[6, 2]*p[j, 1] + p[4, 2]*p[i, 1]*p[j, 2] - p[5, 2]*p[6, 1]*p[i, 2] + p[5, 2]*p[6, 2]*p[i, 1] - p[5, 2]*p[i, 1]*p[j, 2] + p[5, 2]*p[i, 2]*p[j, 1] + p[6, 1]*p[i, 2]*p[j, 2] - p[6, 2]*p[i, 2]*p[j, 1]
# The e-expression is:
# e[k, 1]
#
#
# -------------------------------------------- At depth 18
# After index substitution: p[4, 1]*p[6, 2] - p[4, 1]*p[j, 2] - p[5, 2]*p[6, 1] + p[5, 2]*p[j, 1] + p[6, 1]*p[j, 2] - p[6, 2]*p[j, 1]
# Indexed terms found: []
# After value substitution: p[4, 1]*p[6, 2] - p[4, 1]*p[j, 2] - p[5, 2]*p[6, 1] + p[5, 2]*p[j, 1] + p[6, 1]*p[j, 2] - p[6, 2]*p[j, 1]
# Numeric evaluation: p[4, 1]*p[6, 2] - p[4, 1]*p[j, 2] - p[5, 2]*p[6, 1] + p[5, 2]*p[j, 1] + p[6, 1]*p[j, 2] - p[6, 2]*p[j, 1]
# The e-expression is:
# e[i, 2]*e[k, 1]
#
#
# -------------------------------------------- At depth 19
# After index substitution: -p[4, 2]*p[6, 2] + p[4, 2]*p[j, 2] + p[5, 2]*p[6, 2] - p[5, 2]*p[j, 2]
# Indexed terms found: []
# After value substitution: -p[4, 2]*p[6, 2] + p[4, 2]*p[j, 2] + p[5, 2]*p[6, 2] - p[5, 2]*p[j, 2]
# Numeric evaluation: -p[4, 2]*p[6, 2] + p[4, 2]*p[j, 2] + p[5, 2]*p[6, 2] - p[5, 2]*p[j, 2]
# The e-expression is:
# e[i, 1]*e[k, 1]
#
#
# -------------------------------------------- At depth 20
# After index substitution: p[4, 1]*p[5, 2] - p[4, 1]*p[i, 2] - p[4, 2]*p[6, 1] + p[4, 2]*p[i, 1] - p[5, 2]*p[i, 1] + p[6, 1]*p[i, 2]
# Indexed terms found: []
# After value substitution: p[4, 1]*p[5, 2] - p[4, 1]*p[i, 2] - p[4, 2]*p[6, 1] + p[4, 2]*p[i, 1] - p[5, 2]*p[i, 1] + p[6, 1]*p[i, 2]
# Numeric evaluation: p[4, 1]*p[5, 2] - p[4, 1]*p[i, 2] - p[4, 2]*p[6, 1] + p[4, 2]*p[i, 1] - p[5, 2]*p[i, 1] + p[6, 1]*p[i, 2]
# The e-expression is:
# e[j, 2]*e[k, 1]
#
#
# -------------------------------------------- At depth 21
# After index substitution: -p[4, 1] + p[6, 1]
# Indexed terms found: []
# After value substitution: -p[4, 1] + p[6, 1]
# Numeric evaluation: -p[4, 1] + p[6, 1]
# The e-expression is:
# e[i, 2]*e[j, 2]*e[k, 1]
#
#
# -------------------------------------------- At depth 22
# After index substitution: p[4, 2] - p[5, 2]
# Indexed terms found: []
# After value substitution: p[4, 2] - p[5, 2]
# Numeric evaluation: p[4, 2] - p[5, 2]
# The e-expression is:
# e[i, 1]*e[j, 2]*e[k, 1]
#
#
# -------------------------------------------- At depth 23
# After index substitution: -p[4, 2]*p[5, 2] + p[4, 2]*p[6, 2] + p[5, 2]*p[i, 2] - p[6, 2]*p[i, 2]
# Indexed terms found: []
# After value substitution: -p[4, 2]*p[5, 2] + p[4, 2]*p[6, 2] + p[5, 2]*p[i, 2] - p[6, 2]*p[i, 2]
# Numeric evaluation: -p[4, 2]*p[5, 2] + p[4, 2]*p[6, 2] + p[5, 2]*p[i, 2] - p[6, 2]*p[i, 2]
# The e-expression is:
# e[j, 1]*e[k, 1]
#
#
# -------------------------------------------- At depth 24
# After index substitution: p[5, 2] - p[6, 2]
# Indexed terms found: []
# After value substitution: p[5, 2] - p[6, 2]
# Numeric evaluation: p[5, 2] - p[6, 2]
# The e-expression is:
# e[i, 2]*e[j, 1]*e[k, 1]
#
#
# -------------------------------------------- At depth 25
# After index substitution: p[3, 1]*p[5, 2]*p[6, 1] - p[3, 1]*p[5, 2]*p[j, 1] - p[3, 1]*p[6, 1]*p[j, 2] - p[3, 1]*p[6, 2]*p[i, 1] + p[3, 1]*p[6, 2]*p[j, 1] + p[3, 1]*p[i, 1]*p[j, 2] - p[3, 2]*p[5, 1]*p[6, 1] + p[3, 2]*p[5, 1]*p[j, 1] + p[3, 2]*p[6, 1]*p[i, 1] - p[3, 2]*p[i, 1]*p[j, 1] + p[5, 1]*p[6, 1]*p[j, 2] + p[5, 1]*p[6, 2]*p[i, 1] - p[5, 1]*p[6, 2]*p[j, 1] - p[5, 1]*p[i, 1]*p[j, 2] - p[5, 2]*p[6, 1]*p[i, 1] + p[5, 2]*p[i, 1]*p[j, 1]
# Indexed terms found: []
# After value substitution: p[3, 1]*p[5, 2]*p[6, 1] - p[3, 1]*p[5, 2]*p[j, 1] - p[3, 1]*p[6, 1]*p[j, 2] - p[3, 1]*p[6, 2]*p[i, 1] + p[3, 1]*p[6, 2]*p[j, 1] + p[3, 1]*p[i, 1]*p[j, 2] - p[3, 2]*p[5, 1]*p[6, 1] + p[3, 2]*p[5, 1]*p[j, 1] + p[3, 2]*p[6, 1]*p[i, 1] - p[3, 2]*p[i, 1]*p[j, 1] + p[5, 1]*p[6, 1]*p[j, 2] + p[5, 1]*p[6, 2]*p[i, 1] - p[5, 1]*p[6, 2]*p[j, 1] - p[5, 1]*p[i, 1]*p[j, 2] - p[5, 2]*p[6, 1]*p[i, 1] + p[5, 2]*p[i, 1]*p[j, 1]
# Numeric evaluation: p[3, 1]*p[5, 2]*p[6, 1] - p[3, 1]*p[5, 2]*p[j, 1] - p[3, 1]*p[6, 1]*p[j, 2] - p[3, 1]*p[6, 2]*p[i, 1] + p[3, 1]*p[6, 2]*p[j, 1] + p[3, 1]*p[i, 1]*p[j, 2] - p[3, 2]*p[5, 1]*p[6, 1] + p[3, 2]*p[5, 1]*p[j, 1] + p[3, 2]*p[6, 1]*p[i, 1] - p[3, 2]*p[i, 1]*p[j, 1] + p[5, 1]*p[6, 1]*p[j, 2] + p[5, 1]*p[6, 2]*p[i, 1] - p[5, 1]*p[6, 2]*p[j, 1] - p[5, 1]*p[i, 1]*p[j, 2] - p[5, 2]*p[6, 1]*p[i, 1] + p[5, 2]*p[i, 1]*p[j, 1]
# The e-expression is:
# e[l, 2]
#
#
# -------------------------------------------- At depth 26
# After index substitution: -p[3, 1]*p[6, 2] + p[3, 1]*p[j, 2] + p[3, 2]*p[6, 1] - p[3, 2]*p[j, 1] + p[5, 1]*p[6, 2] - p[5, 1]*p[j, 2] - p[5, 2]*p[6, 1] + p[5, 2]*p[j, 1]
# Indexed terms found: []
# After value substitution: -p[3, 1]*p[6, 2] + p[3, 1]*p[j, 2] + p[3, 2]*p[6, 1] - p[3, 2]*p[j, 1] + p[5, 1]*p[6, 2] - p[5, 1]*p[j, 2] - p[5, 2]*p[6, 1] + p[5, 2]*p[j, 1]
# Numeric evaluation: -p[3, 1]*p[6, 2] + p[3, 1]*p[j, 2] + p[3, 2]*p[6, 1] - p[3, 2]*p[j, 1] + p[5, 1]*p[6, 2] - p[5, 1]*p[j, 2] - p[5, 2]*p[6, 1] + p[5, 2]*p[j, 1]
# The e-expression is:
# e[i, 1]*e[l, 2]
#
#
# -------------------------------------------- At depth 27
# After index substitution: -p[3, 1]*p[6, 1] + p[3, 1]*p[i, 1] + p[5, 1]*p[6, 1] - p[5, 1]*p[i, 1]
# Indexed terms found: []
# After value substitution: -p[3, 1]*p[6, 1] + p[3, 1]*p[i, 1] + p[5, 1]*p[6, 1] - p[5, 1]*p[i, 1]
# Numeric evaluation: -p[3, 1]*p[6, 1] + p[3, 1]*p[i, 1] + p[5, 1]*p[6, 1] - p[5, 1]*p[i, 1]
# The e-expression is:
# e[j, 2]*e[l, 2]
#
#
# -------------------------------------------- At depth 28
# After index substitution: p[3, 1] - p[5, 1]
# Indexed terms found: []
# After value substitution: p[3, 1] - p[5, 1]
# Numeric evaluation: p[3, 1] - p[5, 1]
# The e-expression is:
# e[i, 1]*e[j, 2]*e[l, 2]
#
#
# -------------------------------------------- At depth 29
# After index substitution: -p[3, 1]*p[5, 2] + p[3, 1]*p[6, 2] + p[3, 2]*p[5, 1] - p[3, 2]*p[i, 1] - p[5, 1]*p[6, 2] + p[5, 2]*p[i, 1]
# Indexed terms found: []
# After value substitution: -p[3, 1]*p[5, 2] + p[3, 1]*p[6, 2] + p[3, 2]*p[5, 1] - p[3, 2]*p[i, 1] - p[5, 1]*p[6, 2] + p[5, 2]*p[i, 1]
# Numeric evaluation: -p[3, 1]*p[5, 2] + p[3, 1]*p[6, 2] + p[3, 2]*p[5, 1] - p[3, 2]*p[i, 1] - p[5, 1]*p[6, 2] + p[5, 2]*p[i, 1]
# The e-expression is:
# e[j, 1]*e[l, 2]
#
#
# -------------------------------------------- At depth 30
# After index substitution: -p[3, 2] + p[5, 2]
# Indexed terms found: []
# After value substitution: -p[3, 2] + p[5, 2]
# Numeric evaluation: -p[3, 2] + p[5, 2]
# The e-expression is:
# e[i, 1]*e[j, 1]*e[l, 2]
#
#
# -------------------------------------------- At depth 31
# After index substitution: -p[5, 1]*p[6, 1] + p[5, 1]*p[j, 1] + p[6, 1]*p[i, 1] - p[i, 1]*p[j, 1]
# Indexed terms found: []
# After value substitution: -p[5, 1]*p[6, 1] + p[5, 1]*p[j, 1] + p[6, 1]*p[i, 1] - p[i, 1]*p[j, 1]
# Numeric evaluation: -p[5, 1]*p[6, 1] + p[5, 1]*p[j, 1] + p[6, 1]*p[i, 1] - p[i, 1]*p[j, 1]
# The e-expression is:
# e[k, 2]*e[l, 2]
#
#
# -------------------------------------------- At depth 32
# After index substitution: p[6, 1] - p[j, 1]
# Indexed terms found: []
# After value substitution: p[6, 1] - p[j, 1]
# Numeric evaluation: p[6, 1] - p[j, 1]
# The e-expression is:
# e[i, 1]*e[k, 2]*e[l, 2]
#
#
# -------------------------------------------- At depth 33
# After index substitution: p[5, 1] - p[i, 1]
# Indexed terms found: []
# After value substitution: p[5, 1] - p[i, 1]
# Numeric evaluation: p[5, 1] - p[i, 1]
# The e-expression is:
# e[j, 1]*e[k, 2]*e[l, 2]
#
#
# -------------------------------------------- At depth 34
# After index substitution: -1
# Indexed terms found: []
# After value substitution: -1
# Numeric evaluation: -1.00000000000000
# The e-expression is:
# e[i, 1]*e[j, 1]*e[k, 2]*e[l, 2]
